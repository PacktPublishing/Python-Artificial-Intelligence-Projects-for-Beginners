# %%
import gensim, logging

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim.models.doc2vec import LabeledSentence
from gensim.models import Doc2Vec

# %%
with open("sentiment labelled sentences/yelp_labelled.txt") as f:
    for item_no, line in enumerate(f):
        print(item_no, line)
# Out:
# 0 Wow... Loved this place.	1
#
# 1 Crust is not good.	0
#
# 2 Not tasty and the texture was just nasty.	0
#
# 3 Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.	1
#
# 4 The selection on the menu was great and so were the prices.	1
#
# 5 Now I am getting angry and I want my damn pho.	0
#
# 6 Honeslty it didn't taste THAT fresh.)	0
#
# 7 The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.	0
#
# 8 The fries were great too.	1
#
# 9 A great touch.	1
#
# 10 Service was very prompt.	1
#
# 11 Would not go back.	0
#
# 12 The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.	0
#
# 13 I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!	1
#
# 14 I was disgusted because I was pretty sure that was human hair.	0
#
# 15 I was shocked because no signs indicate cash only.	0
#
# 16 Highly recommended.	1
#
# 17 Waitress was a little slow in service.	0
#
# 18 This place is not worth your time, let alone Vegas.	0
#
# 19 did not like at all.	0
#
# 20 The Burrittos Blah!	0
#
# 21 The food, amazing.	1
#
# 22 Service is also cute.	1
#
# 23 I could care less... The interior is just beautiful.	1
#
# 24 So they performed.	1
#
# 25 That's right....the red velvet cake.....ohhh this stuff is so good.	1
#
# 26 - They never brought a salad we asked for.	0
#
# 27 This hole in the wall has great Mexican street tacos, and friendly staff.	1
#
# 28 Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.	0
#
# 29 The worst was the salmon sashimi.	0
#
# 30 Also there are combos like a burger, fries, and beer for 23 which is a decent deal.	1
#
# 31 This was like the final blow!	0
#
# 32 I found this place by accident and I could not be happier.	1
#
# 33 seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.	0
#
# 34 Overall, I like this place a lot.	1
#
# 35 The only redeeming quality of the restaurant was that it was very inexpensive.	1
#
# 36 Ample portions and good prices.	1
#
# 37 Poor service, the waiter made me feel like I was stupid every time he came to the table.	0
#
# 38 My first visit to Hiro was a delight!	1
#
# 39 Service sucks.	0
#
# 40 The shrimp tender and moist.	1
#
# 41 There is not a deal good enough that would drag me into that establishment again.	0
#
# 42 Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick.	0
#
# 43 On a positive note, our server was very attentive and provided great service.	1
#
# 44 Frozen pucks of disgust, with some of the worst people behind the register.	0
#
# 45 The only thing I did like was the prime rib and dessert section.	1
#
# 46 It's too bad the food is so damn generic.	0
#
# 47 The burger is good beef, cooked just right.	1
#
# 48 If you want a sandwich just go to any Firehouse!!!!!	1
#
# 49 My side Greek salad with the Greek dressing was so tasty, and the pita and hummus was very refreshing.	1
#
# 50 We ordered the duck rare and it was pink and tender on the inside with a nice char on the outside.	1
#
# 51 He came running after us when he realized my husband had left his sunglasses on the table.	1
#
# 52 Their chow mein is so good!	1
#
# 53 They have horrible attitudes towards customers, and talk down to each one when customers don't enjoy their food.	0
#
# 54 The portion was huge!	1
#
# 55 Loved it...friendly servers, great food, wonderful and imaginative menu.	1
#
# 56 The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant.	0
#
# 57 Not much seafood and like 5 strings of pasta at the bottom.	0
#
# 58 The salad had just the right amount of sauce to not over power the scallop, which was perfectly cooked.	1
#
# 59 The ripped banana was not only ripped, but petrified and tasteless.	0
#
# 60 At least think to refill my water before I struggle to wave you over for 10 minutes.	0
#
# 61 This place receives stars for their APPETIZERS!!!	1
#
# 62 The cocktails are all handmade and delicious.	1
#
# 63 We'd definitely go back here again.	1
#
# 64 We are so glad we found this place.	1
#
# 65 Great food and service, huge portions and they give a military discount.	1
#
# 66 Always a great time at Dos Gringos!	1
#
# 67 Update.....went back for a second time and it was still just as amazing	1
#
# 68 We got the food and apparently they have never heard of salt and the batter on the fish was chewy.	0
#
# 69 A great way to finish a great.	1
#
# 70 The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected.	1
#
# 71 - Really, really good rice, all the time.	1
#
# 72 The service was meh.	0
#
# 73 It took over 30 min to get their milkshake, which was nothing more than chocolate milk.	0
#
# 74 I guess I should have known that this place would suck, because it is inside of the Excalibur, but I didn't use my common sense.	0
#
# 75 The scallop dish is quite appalling for value as well.	0
#
# 76 2 times - Very Bad Customer Service !	0
#
# 77 The sweet potato fries were very good and seasoned well.	1
#
# 78 Today is the second time I've been to their lunch buffet and it was pretty good.	1
#
# 79 There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company.	0
#
# 80 Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up.	0
#
# 81 walked in and the place smelled like an old grease trap and only 2 others there eating.	0
#
# 82 The turkey and roast beef were bland.	0
#
# 83 This place has it!	1
#
# 84 The pan cakes everyone are raving about taste like a sugary disaster tailored to the palate of a six year old.	0
#
# 85 I love the Pho and the spring rolls oh so yummy you have to try.	1
#
# 86 The poor batter to meat ratio made the chicken tenders very unsatisfying.	0
#
# 87 All I have to say is the food was amazing!!!	1
#
# 88 Omelets are to die for!	1
#
# 89 Everything was fresh and delicious!	1
#
# 90 In summary, this was a largely disappointing dining experience.	0
#
# 91 It's like a really sexy party in your mouth, where you're outrageously flirting with the hottest person at the party.	1
#
# 92 Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN!	0
#
# 93 Best breakfast buffet!!!	1
#
# 94 say bye bye to your tip lady!	0
#
# 95 We'll never go again.	0
#
# 96 Will be back again!	1
#
# 97 Food arrived quickly!	1
#
# 98 It was not good.	0
#
# 99 On the up side, their cafe serves really good food.	1
#
# 100 Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go!	1
#
# 101 The only good thing was our waiter, he was very helpful and kept the bloddy mary's coming.	1
#
# 102 Best Buffet in town, for the price you cannot beat it.	1
#
# 103 I LOVED their mussels cooked in this wine reduction, the duck was tender, and their potato dishes were delicious.	1
#
# 104 This is one of the better buffets that I have been to.	1
#
# 105 So we went to Tigerlilly and had a fantastic afternoon!	1
#
# 106 The food was delicious, our bartender was attentive and personable AND we got a great deal!	1
#
# 107 The ambience is wonderful and there is music playing.	1
#
# 108 Will go back next trip out.	1
#
# 109 Sooooo good!!	1
#
# 110 REAL sushi lovers, let's be honest - Yama is not that good.	0
#
# 111 At least 40min passed in between us ordering and the food arriving, and it wasn't that busy.	0
#
# 112 This is a really fantastic Thai restaurant which is definitely worth a visit.	1
#
# 113 Nice, spicy and tender.	1
#
# 114 Good prices.	1
#
# 115 Check it out.	1
#
# 116 It was pretty gross!	0
#
# 117 I've had better atmosphere.	0
#
# 118 Kind of hard to mess up a steak but they did.	0
#
# 119 Although I very much liked the look and sound of this place, the actual experience was a bit disappointing.	0
#
# 120 I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine.	0
#
# 121 Worst service to boot, but that is the least of their worries.	0
#
# 122 Service was fine and the waitress was friendly.	1
#
# 123 The guys all had steaks, and our steak loving son who has had steak at the best and worst places said it was the best steak he's ever eaten.	1
#
# 124 We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night.	1
#
# 125 Host staff were, for lack of a better word, BITCHES!	0
#
# 126 Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that...	0
#
# 127 Phenomenal food, service and ambiance.	1
#
# 128 I wouldn't return.	0
#
# 129 Definitely worth venturing off the strip for the pork belly, will return next time I'm in Vegas.	1
#
# 130 This place is way too overpriced for mediocre food.	0
#
# 131 Penne vodka excellent!	1
#
# 132 They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers.	1
#
# 133 The management is rude.	0
#
# 134 Delicious NYC bagels, good selections of cream cheese, real Lox with capers even.	1
#
# 135 Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations.	1
#
# 136 I had a seriously solid breakfast here.	1
#
# 137 This is one of the best bars with food in Vegas.	1
#
# 138 He was extremely rude and really, there are so many other restaurants I would love to dine at during a weekend in Vegas.	0
#
# 139 My drink was never empty and he made some really great menu suggestions.	1
#
# 140 Don't do it!!!!	0
#
# 141 The waiter wasn't helpful or friendly and rarely checked on us.	0
#
# 142 My husband and I ate lunch here and were very disappointed with the food and service.	0
#
# 143 And the red curry had so much bamboo shoots and wasn't very tasty to me.	0
#
# 144 Nice blanket of moz over top but i feel like this was done to cover up the subpar food.	1
#
# 145 The bathrooms are clean and the place itself is well decorated.	1
#
# 146 The menu is always changing, food quality is going down & service is extremely slow.	0
#
# 147 The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace.	0
#
# 148 I give it 2 thumbs down	0
#
# 149 We watched our waiter pay a lot more attention to other tables and ignore us.	0
#
# 150 My fiancé and I came in the middle of the day and we were greeted and seated right away.	1
#
# 151 This is a great restaurant at the Mandalay Bay.	1
#
# 152 We waited for forty five minutes in vain.	0
#
# 153 Crostini that came with the salad was stale.	0
#
# 154 Some highlights : Great quality nigiri here!	1
#
# 155 the staff is friendly and the joint is always clean.	1
#
# 156 this was a different cut than the piece the other day but still wonderful and tender s well as well flavored.	1
#
# 157 I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago.	1
#
# 158 this place is good.	1
#
# 159 Unfortunately, we must have hit the bakery on leftover day because everything we ordered was STALE.	0
#
# 160 I came back today since they relocated and still not impressed.	0
#
# 161 I was seated immediately.	1
#
# 162 Their menu is diverse, and reasonably priced.	1
#
# 163 Avoid at all cost!	0
#
# 164 Restaurant is always full but never a wait.	1
#
# 165 DELICIOUS!!	1
#
# 166 This place is hands-down one of the best places to eat in the Phoenix metro area.	1
#
# 167 So don't go there if you are looking for good food...	0
#
# 168 I've never been treated so bad.	0
#
# 169 Bacon is hella salty.	1
#
# 170 We also ordered the spinach and avocado salad; the ingredients were sad and the dressing literally had zero taste.	0
#
# 171 This really is how Vegas fine dining used to be, right down to the menus handed to the ladies that have no prices listed.	1
#
# 172 The waitresses are very friendly.	1
#
# 173 Lordy, the Khao Soi is a dish that is not to be missed for curry lovers!	1
#
# 174 Everything on the menu is terrific and we were also thrilled that they made amazing accommodations for our vegetarian daughter.	1
#
# 175 Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back.	0
#
# 176 The service here leaves a lot to be desired.	0
#
# 177 The atmosphere is modern and hip, while maintaining a touch of coziness.	1
#
# 178 Not a weekly haunt, but definitely a place to come back to every once in a while.	1
#
# 179 We literally sat there for 20 minutes with no one asking to take our order.	0
#
# 180 The burger had absolutely no flavor - the meat itself was totally bland, the burger was overcooked and there was no charcoal flavor.	0
#
# 181 I also decided not to send it back because our waitress looked like she was on the verge of having a heart attack.	0
#
# 182 I dressed up to be treated so rudely!	0
#
# 183 It was probably dirt.	0
#
# 184 Love this place, hits the spot when I want something healthy but not lacking in quantity or flavor.	1
#
# 185 I ordered the Lemon raspberry ice cocktail which was also incredible.	1
#
# 186 The food sucked, which we expected but it sucked more than we could have imagined.	0
#
# 187 Interesting decor.	1
#
# 188 What I really like there is the crepe station.	1
#
# 189 Also were served hot bread and butter, and home made potato chips with bacon bits on top....very original and very good.	1
#
# 190 you can watch them preparing the delicious food!)	1
#
# 191 Both of the egg rolls were fantastic.	1
#
# 192 When my order arrived, one of the gyros was missing.	0
#
# 193 I had a salad with the wings, and some ice cream for dessert and left feeling quite satisfied.	1
#
# 194 I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine.	0
#
# 195 The best place to go for a tasty bowl of Pho!	1
#
# 196 The live music on Fridays totally blows.	0
#
# 197 I've never been more insulted or felt disrespected.	0
#
# 198 Very friendly staff.	1
#
# 199 It is worth the drive.	1
#
# 200 I had heard good things about this place, but it exceeding every hope I could have dreamed of.	1
#
# 201 Food was great and so was the serivce!	1
#
# 202 The warm beer didn't help.	0
#
# 203 Great brunch spot.	1
#
# 204 Service is friendly and inviting.	1
#
# 205 Very good lunch spot.	1
#
# 206 I've lived here since 1979 and this was the first (and last) time I've stepped foot into this place.	0
#
# 207 The WORST EXPERIENCE EVER.	0
#
# 208 Must have been an off night at this place.	0
#
# 209 The sides are delish - mixed mushrooms, yukon gold puree, white corn - beateous.	1
#
# 210 If that bug never showed up I would have given a 4 for sure, but on the other side of the wall where this bug was climbing was the kitchen.	0
#
# 211 For about 10 minutes, we we're waiting for her salad when we realized that it wasn't coming any time soon.	0
#
# 212 My friend loved the salmon tartar.	1
#
# 213 Won't go back.	0
#
# 214 Extremely Tasty!	1
#
# 215 Waitress was good though!	1
#
# 216 Soggy and not good.	0
#
# 217 The Jamaican mojitos are delicious.	1
#
# 218 Which are small and not worth the price.	0
#
# 219 - the food is rich so order accordingly.	1
#
# 220 The shower area is outside so you can only rinse, not take a full shower, unless you don't mind being nude for everyone to see!	0
#
# 221 The service was a bit lacking.	0
#
# 222 Lobster Bisque, Bussell Sprouts, Risotto, Filet ALL needed salt and pepper..and of course there is none at the tables.	0
#
# 223 Hopefully this bodes for them going out of business and someone who can cook can come in.	0
#
# 224 It was either too cold, not enough flavor or just bad.	0
#
# 225 I loved the bacon wrapped dates.	1
#
# 226 This is an unbelievable BARGAIN!	1
#
# 227 The folks at Otto always make us feel so welcome and special.	1
#
# 228 As for the "mains," also uninspired.	0
#
# 229 This is the place where I first had pho and it was amazing!!	1
#
# 230 This wonderful experience made this place a must-stop whenever we are in town again.	1
#
# 231 If the food isn't bad enough for you, then enjoy dealing with the world's worst/annoying drunk people.	0
#
# 232 Very very fun chef.	1
#
# 233 Ordered a double cheeseburger & got a single patty that was falling apart (picture uploaded) Yeah, still sucks.	0
#
# 234 Great place to have a couple drinks and watch any and all sporting events as the walls are covered with TV's.	1
#
# 235 If it were possible to give them zero stars, they'd have it.	0
#
# 236 The descriptions said "yum yum sauce" and another said "eel sauce", yet another said "spicy mayo"...well NONE of the rolls had sauces on them.	0
#
# 237 I'd say that would be the hardest decision... Honestly, all of M's dishes taste how they are supposed to taste (amazing).	1
#
# 238 If she had not rolled the eyes we may have stayed... Not sure if we will go back and try it again.	0
#
# 239 Everyone is very attentive, providing excellent customer service.	1
#
# 240 Horrible - don't waste your time and money.	0
#
# 241 Now this dish was quite flavourful.	1
#
# 242 By this time our side of the restaurant was almost empty so there was no excuse.	0
#
# 243 (It wasn't busy either) Also, the building was FREEZING cold.	0
#
# 244 like the other reviewer said "you couldn't pay me to eat at this place again."	0
#
# 245 -Drinks took close to 30 minutes to come out at one point.	0
#
# 246 Seriously flavorful delights, folks.	1
#
# 247 Much better than the other AYCE sushi place I went to in Vegas.	1
#
# 248 The lighting is just dark enough to set the mood.	1
#
# 249 Based on the sub-par service I received and no effort to show their gratitude for my business I won't be going back.	0
#
# 250 Owner's are really great people.!	1
#
# 251 There is nothing privileged about working/eating there.	0
#
# 252 The Greek dressing was very creamy and flavorful.	1
#
# 253 Overall, I don't think that I would take my parents to this place again because they made most of the similar complaints that I silently felt too.	0
#
# 254 Now the pizza itself was good the peanut sauce was very tasty.	1
#
# 255 We had 7 at our table and the service was pretty fast.	1
#
# 256 Fantastic service here.	1
#
# 257 I as well would've given godfathers zero stars if possible.	0
#
# 258 They know how to make them here.	1
#
# 259 very tough and very short on flavor!	0
#
# 260 I hope this place sticks around.	1
#
# 261 I have been in more than a few bars in Vegas, and do not ever recall being charged for tap water.	0
#
# 262 The restaurant atmosphere was exquisite.	1
#
# 263 Good service, very clean, and inexpensive, to boot!	1
#
# 264 The seafood was fresh and generous in portion.	1
#
# 265 Plus, it's only 8 bucks.	1
#
# 266 The service was not up to par, either.	0
#
# 267 Thus far, have only visited twice and the food was absolutely delicious each time.	1
#
# 268 Just as good as when I had it more than a year ago!	1
#
# 269 For a self proclaimed coffee cafe, I was wildly disappointed.	0
#
# 270 The Veggitarian platter is out of this world!	1
#
# 271 You cant go wrong with any of the food here.	1
#
# 272 You can't beat that.	1
#
# 273 Stopped by this place while in Madison for the Ironman, very friendly, kind staff.	1
#
# 274 The chefs were friendly and did a good job.	1
#
# 275 I've had better, not only from dedicated boba tea spots, but even from Jenni Pho.	0
#
# 276 I liked the patio and the service was outstanding.	1
#
# 277 The goat taco didn't skimp on the meat and wow what FLAVOR!	1
#
# 278 I think not again	0
#
# 279 I had the mac salad and it was pretty bland so I will not be getting that again.	0
#
# 280 I went to Bachi Burger on a friend's recommendation and was not disappointed.	1
#
# 281 Service stinks here!	0
#
# 282 I waited and waited.	0
#
# 283 This place is not quality sushi, it is not a quality restaurant.	0
#
# 284 I would definitely recommend the wings as well as the pizza.	1
#
# 285 Great Pizza and Salads!	1
#
# 286 Things that went wrong: - They burned the saganaki.	0
#
# 287 We waited an hour for what was a breakfast I could have done 100 times better at home.	0
#
# 288 This place is amazing!	1
#
# 289 I hate to disagree with my fellow Yelpers, but my husband and I were so disappointed with this place.	0
#
# 290 Waited 2 hours & never got either of our pizzas as many other around us who came in later did!	0
#
# 291 Just don't know why they were so slow.	0
#
# 292 The staff is great, the food is delish, and they have an incredible beer selection.	1
#
# 293 I live in the neighborhood so I am disappointed I won't be back here, because it is a convenient location.	0
#
# 294 I didn't know pulled pork could be soooo delicious.	1
#
# 295 You get incredibly fresh fish, prepared with care.	1
#
# 296 Before I go in to why I gave a 1 star rating please know that this was my third time eating at Bachi burger before writing a review.	0
#
# 297 I love the fact that everything on their menu is worth it.	1
#
# 298 Never again will I be dining at this place!	0
#
# 299 The food was excellent and service was very good.	1
#
# 300 Good beer & drink selection and good food selection.	1
#
# 301 Please stay away from the shrimp stir fried noodles.	0
#
# 302 The potato chip order was sad... I could probably count how many chips were in that box and it was probably around 12.	0
#
# 303 Food was really boring.	0
#
# 304 Good Service-check!	1
#
# 305 This greedy corporation will NEVER see another dime from me!	0
#
# 306 Will never, ever go back.	0
#
# 307 As much as I'd like to go back, I can't get passed the atrocious service and will never return.	0
#
# 308 In the summer, you can dine in a charming outdoor patio - so very delightful.	1
#
# 309 I did not expect this to be so good!	1
#
# 310 Fantastic food!	1
#
# 311 She ordered a toasted English muffin that came out untoasted.	0
#
# 312 The food was very good.	1
#
# 313 Never going back.	0
#
# 314 Great food for the price, which is very high quality and house made.	1
#
# 315 The bus boy on the other hand was so rude.	0
#
# 316 By this point, my friends and I had basically figured out this place was a joke and didn't mind making it publicly and loudly known.	0
#
# 317 Back to good BBQ, lighter fare, reasonable pricing and tell the public they are back to the old ways.	1
#
# 318 And considering the two of us left there very full and happy for about $20, you just can't go wrong.	1
#
# 319 All the bread is made in-house!	1
#
# 320 The only downside is the service.	0
#
# 321 Also, the fries are without a doubt the worst fries I've ever had.	0
#
# 322 Service was exceptional and food was a good as all the reviews.	1
#
# 323 A couple of months later, I returned and had an amazing meal.	1
#
# 324 Favorite place in town for shawarrrrrrma!!!!!!	1
#
# 325 The black eyed peas and sweet potatoes... UNREAL!	1
#
# 326 You won't be disappointed.	1
#
# 327 They could serve it with just the vinaigrette and it may make for a better overall dish, but it was still very good.	1
#
# 328 I go to far too many places and I've never seen any restaurant that serves a 1 egg breakfast, especially for $4.00.	0
#
# 329 When my mom and I got home she immediately got sick and she only had a few bites of salad.	0
#
# 330 The servers are not pleasant to deal with and they don't always honor Pizza Hut coupons.	0
#
# 331 Both of them were truly unbelievably good, and I am so glad we went back.	1
#
# 332 We had fantastic service, and were pleased by the atmosphere.	1
#
# 333 Everything was gross.	0
#
# 334 I love this place.	1
#
# 335 Great service and food.	1
#
# 336 First - the bathrooms at this location were dirty- Seat covers were not replenished & just plain yucky!!!	0
#
# 337 The burger... I got the "Gold Standard" a $17 burger and was kind of disappointed.	0
#
# 338 OMG, the food was delicioso!	1
#
# 339 There is nothing authentic about this place.	0
#
# 340 the spaghetti is nothing special whatsoever.	0
#
# 341 Of all the dishes, the salmon was the best, but all were great.	1
#
# 342 The vegetables are so fresh and the sauce feels like authentic Thai.	1
#
# 343 It's worth driving up from Tucson!	1
#
# 344 The selection was probably the worst I've seen in Vegas.....there was none.	0
#
# 345 Pretty good beer selection too.	1
#
# 346 This place is like Chipotle, but BETTER.	1
#
# 347 Classy/warm atmosphere, fun and fresh appetizers, succulent steaks (Baseball steak!!!!!	1
#
# 348 5 stars for the brick oven bread app!	1
#
# 349 I have eaten here multiple times, and each time the food was delicious.	1
#
# 350 We sat another ten minutes and finally gave up and left.	0
#
# 351 He was terrible!	0
#
# 352 Everyone is treated equally special.	1
#
# 353 It shouldn't take 30 min for pancakes and eggs.	0
#
# 354 It was delicious!!!	1
#
# 355 On the good side, the staff was genuinely pleasant and enthusiastic - a real treat.	1
#
# 356 Sadly, Gordon Ramsey's Steak is a place we shall sharply avoid during our next trip to Vegas.	0
#
# 357 As always the evening was wonderful and the food delicious!	1
#
# 358 Best fish I've ever had in my life!	1
#
# 359 (The bathroom is just next door and very nice.)	1
#
# 360 The buffet is small and all the food they offered was BLAND.	0
#
# 361 This is an Outstanding little restaurant with some of the Best Food I have ever tasted.	1
#
# 362 Pretty cool I would say.	1
#
# 363 Definitely a turn off for me & i doubt I'll be back unless someone else is buying.	0
#
# 364 Server did a great job handling our large rowdy table.	1
#
# 365 I find wasting food to be despicable, but this just wasn't food.	0
#
# 366 My wife had the Lobster Bisque soup which was lukewarm.	0
#
# 367 Would come back again if I had a sushi craving while in Vegas.	1
#
# 368 The staff are great, the ambiance is great.	1
#
# 369 He deserves 5 stars.	1
#
# 370 I left with a stomach ache and felt sick the rest of the day.	0
#
# 371 They dropped more than the ball.	0
#
# 372 The dining space is tiny, but elegantly decorated and comfortable.	1
#
# 373 They will customize your order any way you'd like, my usual is Eggplant with Green Bean stir fry, love it!	1
#
# 374 And the beans and rice were mediocre at best.	0
#
# 375 Best tacos in town by far!!	1
#
# 376 I took back my money and got outta there.	0
#
# 377 In an interesting part of town, this place is amazing.	1
#
# 378 RUDE & INCONSIDERATE MANAGEMENT.	0
#
# 379 The staff are now not as friendly, the wait times for being served are horrible, no one even says hi for the first 10 minutes.	0
#
# 380 I won't be back.	0
#
# 381 They have great dinners.	1
#
# 382 The service was outshining & I definitely recommend the Halibut.	1
#
# 383 The food was terrible.	0
#
# 384 WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED.	0
#
# 385 I don't recommend unless your car breaks down in front of it and you are starving.	0
#
# 386 I will come back here every time I'm in Vegas.	1
#
# 387 This place deserves one star and 90% has to do with the food.	0
#
# 388 This is a disgrace.	0
#
# 389 Def coming back to bowl next time	1
#
# 390 If you want healthy authentic or ethic food, try this place.	1
#
# 391 I will continue to come here on ladies night andddd date night ... highly recommend this place to anyone who is in the area (;	1
#
# 392 I have been here several times in the past, and the experience has always been great.	1
#
# 393 We walked away stuffed and happy about our first Vegas buffet experience.	1
#
# 394 Service was excellent and prices are pretty reasonable considering this is Vegas and located inside the Crystals shopping mall by Aria.	1
#
# 395 To summarize... the food was incredible, nay, transcendant... but nothing brings me joy quite like the memory of the pneumatic condiment dispenser.	1
#
# 396 I'm probably one of the few people to ever go to Ians and not like it.	0
#
# 397 Kids pizza is always a hit too with lots of great side dish options for the kiddos!	1
#
# 398 Service is perfect and the family atmosphere is nice to see.	1
#
# 399 Cooked to perfection and the service was impeccable.	1
#
# 400 This one is simply a disappointment.	0
#
# 401 Overall, I was very disappointed with the quality of food at Bouchon.	0
#
# 402 I don't have to be an accountant to know I'm getting screwed!	0
#
# 403 Great place to eat, reminds me of the little mom and pop shops in the San Francisco Bay Area.	1
#
# 404 Today was my first taste of a Buldogis Gourmet Hot Dog and I have to tell you it was more than I ever thought possible.	1
#
# 405 Left very frustrated.	0
#
# 406 I'll definitely be in soon again.	1
#
# 407 Food was really good and I got full petty fast.	1
#
# 408 Service was fantastic.	1
#
# 409 TOTAL WASTE OF TIME.	0
#
# 410 I don't know what kind it is but they have the best iced tea.	1
#
# 411 Come hungry, leave happy and stuffed!	1
#
# 412 For service, I give them no stars.	0
#
# 413 I can assure you that you won't be disappointed.	1
#
# 414 I can take a little bad service but the food sucks.	0
#
# 415 Gave up trying to eat any of the crust (teeth still sore).	0
#
# 416 But now I was completely grossed out.	0
#
# 417 I really enjoyed eating here.	1
#
# 418 First time going but I think I will quickly become a regular.	1
#
# 419 Our server was very nice, and even though he looked a little overwhelmed with all of our needs, he stayed professional and friendly until the end.	1
#
# 420 From what my dinner companions told me...everything was very fresh with nice texture and taste.	1
#
# 421 On the ground, right next to our table was a large, smeared, been-stepped-in-and-tracked-everywhere pile of green bird poop.	0
#
# 422 Furthermore, you can't even find hours of operation on the website!	0
#
# 423 We've tried to like this place but after 10+ times I think we're done with them.	0
#
# 424 What a mistake that was!	0
#
# 425 No complaints!	1
#
# 426 This is some seriously good pizza and I'm an expert/connisseur on the topic.	1
#
# 427 Waiter was a jerk.	0
#
# 428 Strike 2, who wants to be rushed.	0
#
# 429 These are the nicest restaurant owners I've ever come across.	1
#
# 430 I never come again.	0
#
# 431 We loved the biscuits!!!	1
#
# 432 Service is quick and friendly.	1
#
# 433 Ordered an appetizer and took 40 minutes and then the pizza another 10 minutes.	0
#
# 434 So absolutley fantastic.	1
#
# 435 It was a huge awkward 1.5lb piece of cow that was 3/4ths gristle and fat.	0
#
# 436 definitely will come back here again.	1
#
# 437 I like Steiners because it's dark and it feels like a bar.	1
#
# 438 Wow very spicy but delicious.	1
#
# 439 If you're not familiar, check it out.	1
#
# 440 I'll take my business dinner dollars elsewhere.	0
#
# 441 I'd love to go back.	1
#
# 442 Anyway, this FS restaurant has a wonderful breakfast/lunch.	1
#
# 443 Nothing special.	0
#
# 444 Each day of the week they have a different deal and it's all so delicious!	1
#
# 445 Not to mention the combination of pears, almonds and bacon is a big winner!	1
#
# 446 Will not be back.	0
#
# 447 Sauce was tasteless.	0
#
# 448 The food is delicious and just spicy enough, so be sure to ask for spicier if you prefer it that way.	1
#
# 449 My ribeye steak was cooked perfectly and had great mesquite flavor.	1
#
# 450 I don't think we'll be going back anytime soon.	0
#
# 451 Food was so gooodd.	1
#
# 452 I am far from a sushi connoisseur but I can definitely tell the difference between good food and bad food and this was certainly bad food.	0
#
# 453 I was so insulted.	0
#
# 454 The last 3 times I had lunch here has been bad.	0
#
# 455 The chicken wings contained the driest chicken meat I have ever eaten.	0
#
# 456 The food was very good and I enjoyed every mouthful, an enjoyable relaxed venue for couples small family groups etc.	1
#
# 457 Nargile - I think you are great.	1
#
# 458 Best tater tots in the southwest.	1
#
# 459 We loved the place.	1
#
# 460 Definitely not worth the $3 I paid.	0
#
# 461 The vanilla ice cream was creamy and smooth while the profiterole (choux) pastry was fresh enough.	1
#
# 462 Im in AZ all the time and now have my new spot.	1
#
# 463 The manager was the worst.	0
#
# 464 The inside is really quite nice and very clean.	1
#
# 465 The food was outstanding and the prices were very reasonable.	1
#
# 466 I don't think I'll be running back to Carly's anytime soon for food.	0
#
# 467 This is was due to the fact that it took 20 minutes to be acknowledged, then another 35 minutes to get our food...and they kept forgetting things.	0
#
# 468 Love the margaritas, too!	1
#
# 469 This was my first and only Vegas buffet and it did not disappoint.	1
#
# 470 Very good, though!	1
#
# 471 The one down note is the ventilation could use some upgrading.	0
#
# 472 Great pork sandwich.	1
#
# 473 Don't waste your time here.	0
#
# 474 Total letdown, I would much rather just go to the Camelback Flower Shop and Cartel Coffee.	0
#
# 475 Third, the cheese on my friend's burger was cold.	0
#
# 476 We enjoy their pizza and brunch.	1
#
# 477 The steaks are all well trimmed and also perfectly cooked.	1
#
# 478 We had a group of 70+ when we claimed we would only have 40 and they handled us beautifully.	1
#
# 479 I LOVED it!	1
#
# 480 We asked for the bill to leave without eating and they didn't bring that either.	0
#
# 481 This place is a jewel in Las Vegas, and exactly what I've been hoping to find in nearly ten years living here.	1
#
# 482 Seafood was limited to boiled shrimp and crab legs but the crab legs definitely did not taste fresh.	0
#
# 483 The selection of food was not the best.	0
#
# 484 Delicious and I will absolutely be back!	1
#
# 485 This isn't a small family restaurant, this is a fine dining establishment.	1
#
# 486 They had a toro tartare with a cavier that was extraordinary and I liked the thinly sliced wagyu with white truffle.	1
#
# 487 I dont think I will be back for a very long time.	0
#
# 488 It was attached to a gas station, and that is rarely a good sign.	0
#
# 489 How awesome is that.	1
#
# 490 I will be back many times soon.	1
#
# 491 The menu had so much good stuff on it i could not decide!	1
#
# 492 Worse of all, he humiliated his worker right in front of me..Bunch of horrible name callings.	0
#
# 493 CONCLUSION: Very filling meals.	1
#
# 494 Their daily specials are always a hit with my group.	1
#
# 495 And then tragedy struck.	0
#
# 496 The pancake was also really good and pretty large at that.	1
#
# 497 This was my first crawfish experience, and it was delicious!	1
#
# 498 Their monster chicken fried steak and eggs is my all time favorite.	1
#
# 499 Waitress was sweet and funny.	1
#
# 500 I also had to taste my Mom's multi-grain pumpkin pancakes with pecan butter and they were amazing, fluffy, and delicious!	1
#
# 501 I'd rather eat airline food, seriously.	0
#
# 502 Cant say enough good things about this place.	1
#
# 503 The ambiance was incredible.	1
#
# 504 The waitress and manager are so friendly.	1
#
# 505 I would not recommend this place.	0
#
# 506 Overall I wasn't very impressed with Noca.	0
#
# 507 My gyro was basically lettuce only.	0
#
# 508 Terrible service!	0
#
# 509 Thoroughly disappointed!	0
#
# 510 I don't each much pasta, but I love the homemade /hand made pastas and thin pizzas here.	1
#
# 511 Give it a try, you will be happy you did.	1
#
# 512 By far the BEST cheesecurds we have ever had!	1
#
# 513 Reasonably priced also!	1
#
# 514 Everything was perfect the night we were in.	1
#
# 515 The food is very good for your typical bar food.	1
#
# 516 it was a drive to get there.	0
#
# 517 At first glance it is a lovely bakery cafe - nice ambiance, clean, friendly staff.	1
#
# 518 Anyway, I do not think i will go back there.	0
#
# 519 Point your finger at any item on the menu, order it and you won't be disappointed.	1
#
# 520 Oh this is such a thing of beauty, this restaurant.	1
#
# 521 If you haven't gone here GO NOW!	1
#
# 522 A greasy, unhealthy meal.	0
#
# 523 first time there and might just be the last.	0
#
# 524 Those burgers were amazing.	1
#
# 525 Similarly, the delivery man did not say a word of apology when our food was 45 minutes late.	0
#
# 526 And it was way to expensive.	0
#
# 527 Be sure to order dessert, even if you need to pack it to-go - the tiramisu and cannoli are both to die for.	1
#
# 528 This was my first time and I can't wait until the next.	1
#
# 529 The bartender was also nice.	1
#
# 530 Everything was good and tasty!	1
#
# 531 This place is two thumbs up....way up.	1
#
# 532 The best place in Vegas for breakfast (just check out a Sat, or Sun.	1
#
# 533 If you love authentic Mexican food and want a whole bunch of interesting, yet delicious meats to choose from, you need to try this place.	1
#
# 534 Terrible management.	0
#
# 535 An excellent new restaurant by an experienced Frenchman.	1
#
# 536 If there were zero stars I would give it zero stars.	0
#
# 537 Great steak, great sides, great wine, amazing desserts.	1
#
# 538 Worst martini ever!	0
#
# 539 The steak and the shrimp are in my opinion the best entrees at GC.	1
#
# 540 I had the opportunity today to sample your amazing pizzas!	1
#
# 541 We waited for thirty minutes to be seated (although there were 8 vacant tables and we were the only folks waiting).	0
#
# 542 The yellowtail carpaccio was melt in your mouth fresh.	1
#
# 543 I won't try going back there even if it's empty.	0
#
# 544 No, I'm going to eat the potato that I found some strangers hair in it.	0
#
# 545 Just spicy enough.. Perfect actually.	1
#
# 546 Last night was my second time dining here and I was so happy I decided to go back!	1
#
# 547 not even a "hello, we will be right with you."	0
#
# 548 The desserts were a bit strange.	0
#
# 549 My boyfriend and I came here for the first time on a recent trip to Vegas and could not have been more pleased with the quality of food and service.	1
#
# 550 I really do recommend this place, you can go wrong with this donut place!	1
#
# 551 Nice ambiance.	1
#
# 552 I would recommend saving room for this!	1
#
# 553 I guess maybe we went on an off night but it was disgraceful.	0
#
# 554 However, my recent experience at this particular location was not so good.	0
#
# 555 I know this is not like the other restaurants at all, something is very off here!	0
#
# 556 AVOID THIS ESTABLISHMENT!	0
#
# 557 I think this restaurant suffers from not trying hard enough.	0
#
# 558 All of the tapas dishes were delicious!	1
#
# 559 I *heart* this place.	1
#
# 560 My salad had a bland vinegrette on the baby greens and hearts of Palm.	0
#
# 561 After two I felt disgusting.	0
#
# 562 A good time!	1
#
# 563 I believe that this place is a great stop for those with a huge belly and hankering for sushi.	1
#
# 564 Generous portions and great taste.	1
#
# 565 I will never go back to this place and will never ever recommended this place to anyone!	0
#
# 566 The servers went back and forth several times, not even so much as an "Are you being helped?"	0
#
# 567 Food was delicious!	1
#
# 568 AN HOUR... seriously?	0
#
# 569 I consider this theft.	0
#
# 570 Eew... This location needs a complete overhaul.	0
#
# 571 We recently witnessed her poor quality of management towards other guests as well.	0
#
# 572 Waited and waited and waited.	0
#
# 573 He also came back to check on us regularly, excellent service.	1
#
# 574 Our server was super nice and checked on us many times.	1
#
# 575 The pizza tasted old, super chewy in not a good way.	0
#
# 576 I swung in to give them a try but was deeply disappointed.	0
#
# 577 Service was good and the company was better!	1
#
# 578 The staff are also very friendly and efficient.	1
#
# 579 As for the service: I'm a fan, because it's quick and you're being served by some nice folks.	1
#
# 580 Boy was that sucker dry!!.	0
#
# 581 Over rated.	0
#
# 582 If you look for authentic Thai food, go else where.	0
#
# 583 Their steaks are 100% recommended!	1
#
# 584 After I pulled up my car I waited for another 15 minutes before being acknowledged.	0
#
# 585 Great food and great service in a clean and friendly setting.	1
#
# 586 All in all, I can assure you I'll be back.	1
#
# 587 I hate those things as much as cheap quality black olives.	0
#
# 588 My breakfast was perpared great, with a beautiful presentation of 3 giant slices of Toast, lightly dusted with powdered sugar.	1
#
# 589 The kids play area is NASTY!	0
#
# 590 Great place fo take out or eat in.	1
#
# 591 The waitress was friendly and happy to accomodate for vegan/veggie options.	1
#
# 592 OMG I felt like I had never eaten Thai food until this dish.	1
#
# 593 It was extremely "crumby" and pretty tasteless.	0
#
# 594 It was a pale color instead of nice and char and has NO flavor.	0
#
# 595 The croutons also taste homemade which is an extra plus.	1
#
# 596 I got home to see the driest damn wings ever!	0
#
# 597 It'll be a regular stop on my trips to Phoenix!	1
#
# 598 I really enjoyed Crema Café before they expanded; I even told friends they had the BEST breakfast.	1
#
# 599 Not good for the money.	0
#
# 600 I miss it and wish they had one in Philadelphia!	1
#
# 601 We got sitting fairly fast, but, ended up waiting 40 minutes just to place our order, another 30 minutes before the food arrived.	0
#
# 602 They also have the best cheese crisp in town.	1
#
# 603 Good value, great food, great service.	1
#
# 604 Couldn't ask for a more satisfying meal.	1
#
# 605 The food is good.	1
#
# 606 It was awesome.	1
#
# 607 I just wanted to leave.	0
#
# 608 We made the drive all the way from North Scottsdale... and I was not one bit disappointed!	1
#
# 609 I will not be eating there again.	0
#
# 610 !....THE OWNERS REALLY REALLY need to quit being soooooo cheap let them wrap my freaking sandwich in two papers not one!	0
#
# 611 I checked out this place a couple years ago and was not impressed.	0
#
# 612 The chicken I got was definitely reheated and was only ok, the wedges were cold and soggy.	0
#
# 613 Sorry, I will not be getting food from here anytime soon :(	0
#
# 614 An absolute must visit!	1
#
# 615 The cow tongue and cheek tacos are amazing.	1
#
# 616 My friend did not like his Bloody Mary.	0
#
# 617 Despite how hard I rate businesses, its actually rare for me to give a 1 star.	0
#
# 618 They really want to make your experience a good one.	1
#
# 619 I will not return.	0
#
# 620 I had the chicken Pho and it tasted very bland.	0
#
# 621 Very disappointing!!!	0
#
# 622 The grilled chicken was so tender and yellow from the saffron seasoning.	1
#
# 623 a drive thru means you do not want to wait around for half an hour for your food, but somehow when we end up going here they make us wait and wait.	0
#
# 624 Pretty awesome place.	1
#
# 625 Ambience is perfect.	1
#
# 626 Best of luck to the rude and non-customer service focused new management.	0
#
# 627 Any grandmother can make a roasted chicken better than this one.	0
#
# 628 I asked multiple times for the wine list and after some time of being ignored I went to the hostess and got one myself.	0
#
# 629 The staff is always super friendly and helpful, which is especially cool when you bring two small boys and a baby!	1
#
# 630 Four stars for the food & the guy in the blue shirt for his great vibe & still letting us in to eat !	1
#
# 631 The roast beef sandwich tasted really good!	1
#
# 632 Same evening, him and I are both drastically sick.	0
#
# 633 High-quality chicken on the chicken Caesar salad.	1
#
# 634 Ordered burger rare came in we'll done.	0
#
# 635 We were promptly greeted and seated.	1
#
# 636 Tried to go here for lunch and it was a madhouse.	0
#
# 637 I was proven dead wrong by this sushi bar, not only because the quality is great, but the service is fast and the food, impeccable.	1
#
# 638 After waiting an hour and being seated, I was not in the greatest of moods.	0
#
# 639 This is a good joint.	1
#
# 640 The Macarons here are insanely good.	1
#
# 641 I'm not eating here!	0
#
# 642 Our waiter was very attentive, friendly, and informative.	1
#
# 643 Maybe if they weren't cold they would have been somewhat edible.	0
#
# 644 This place has a lot of promise but fails to deliver.	0
#
# 645 Very bad Experience!	0
#
# 646 What a mistake.	0
#
# 647 Food was average at best.	0
#
# 648 Great food.	1
#
# 649 We won't be going back anytime soon!	0
#
# 650 Very Very Disappointed ordered the $35 Big Bay Plater.	0
#
# 651 Great place to relax and have an awesome burger and beer.	1
#
# 652 It is PERFECT for a sit-down family meal or get together with a few friends.	1
#
# 653 Not much flavor to them, and very poorly constructed.	0
#
# 654 The patio seating was very comfortable.	1
#
# 655 The fried rice was dry as well.	0
#
# 656 Hands down my favorite Italian restaurant!	1
#
# 657 That just SCREAMS "LEGIT" in my book...somethat's also pretty rare here in Vegas.	1
#
# 658 It was just not a fun experience.	1
#
# 659 The atmosphere was great with a lovely duo of violinists playing songs we requested.	1
#
# 660 I personally love the hummus, pita, baklava, falafels and Baba Ganoush (it's amazing what they do with eggplant!).	1
#
# 661 Very convenient, since we were staying at the MGM!	1
#
# 662 The owners are super friendly and the staff is courteous.	1
#
# 663 Both great!	1
#
# 664 Eclectic selection.	1
#
# 665 The sweet potato tots were good but the onion rings were perfection or as close as I have had.	1
#
# 666 The staff was very attentive.	1
#
# 667 And the chef was generous with his time (even came around twice so we can take pictures with him).	1
#
# 668 The owner used to work at Nobu, so this place is really similar for half the price.	1
#
# 669 Google mediocre and I imagine Smashburger will pop up.	0
#
# 670 dont go here.	0
#
# 671 I promise they won't disappoint.	1
#
# 672 As a sushi lover avoid this place by all means.	0
#
# 673 What a great double cheeseburger!	1
#
# 674 Awesome service and food.	1
#
# 675 A fantastic neighborhood gem !!!	1
#
# 676 I can't wait to go back.	1
#
# 677 The plantains were the worst I've ever tasted.	0
#
# 678 It's a great place and I highly recommend it.	1
#
# 679 Service was slow and not attentive.	0
#
# 680 I gave it 5 stars then, and I'm giving it 5 stars now.	1
#
# 681 Your staff spends more time talking to themselves than me.	0
#
# 682 Dessert: Panna Cotta was amazing.	1
#
# 683 Very good food, great atmosphere.1	1
#
# 684 Damn good steak.	1
#
# 685 Total brunch fail.	0
#
# 686 Prices are very reasonable, flavors are spot on, the sauce is home made, and the slaw is not drenched in mayo.	1
#
# 687 The decor is nice, and the piano music soundtrack is pleasant.	1
#
# 688 The steak was amazing...rge fillet relleno was the best seafood plate i have ever had!	1
#
# 689 Good food , good service .	1
#
# 690 It was absolutely amazing.	1
#
# 691 I probably won't be back, to be honest.	0
#
# 692 will definitely be back!	1
#
# 693 The sergeant pepper beef sandwich with auju sauce is an excellent sandwich as well.	1
#
# 694 Hawaiian Breeze, Mango Magic, and Pineapple Delight are the smoothies that I've tried so far and they're all good.	1
#
# 695 Went for lunch - service was slow.	0
#
# 696 We had so much to say about the place before we walked in that he expected it to be amazing, but was quickly disappointed.	0
#
# 697 I was mortified.	0
#
# 698 Needless to say, we will never be back here again.	0
#
# 699 Anyways, The food was definitely not filling at all, and for the price you pay you should expect more.	0
#
# 700 The chips that came out were dripping with grease, and mostly not edible.	0
#
# 701 I wasn't really impressed with Strip Steak.	0
#
# 702 Have been going since 2007 and every meal has been awesome!!	1
#
# 703 Our server was very nice and attentive as were the other serving staff.	1
#
# 704 The cashier was friendly and even brought the food out to me.	1
#
# 705 I work in the hospitality industry in Paradise Valley and have refrained from recommending Cibo any longer.	0
#
# 706 The atmosphere here is fun.	1
#
# 707 Would not recommend to others.	0
#
# 708 Service is quick and even "to go" orders are just like we like it!	1
#
# 709 I mean really, how do you get so famous for your fish and chips when it's so terrible!?!	0
#
# 710 That said, our mouths and bellies were still quite pleased.	1
#
# 711 Not my thing.	0
#
# 712 2 Thumbs Up!!	1
#
# 713 If you are reading this please don't go there.	0
#
# 714 I loved the grilled pizza, reminded me of legit Italian pizza.	1
#
# 715 Only Pros : Large seating area/ Nice bar area/ Great simple drink menu/ The BEST brick oven pizza with homemade dough!	1
#
# 716 They have a really nice atmosphere.	1
#
# 717 Tonight I had the Elk Filet special...and it sucked.	0
#
# 718 After one bite, I was hooked.	1
#
# 719 We ordered some old classics and some new dishes after going there a few times and were sorely disappointed with everything.	0
#
# 720 Cute, quaint, simple, honest.	1
#
# 721 The chicken was deliciously seasoned and had the perfect fry on the outside and moist chicken on the inside.	1
#
# 722 The food was great as always, compliments to the chef.	1
#
# 723 Special thanks to Dylan T. for the recommendation on what to order :) All yummy for my tummy.	1
#
# 724 Awesome selection of beer.	1
#
# 725 Great food and awesome service!	1
#
# 726 One nice thing was that they added gratuity on the bill since our party was larger than 6 or 8, and they didn't expect more tip than that.	1
#
# 727 A FLY was in my apple juice.. A FLY!!!!!!!!	0
#
# 728 The Han Nan Chicken was also very tasty.	1
#
# 729 As for the service, I thought it was good.	1
#
# 730 The food was barely lukewarm, so it must have been sitting waiting for the server to bring it out to us.	0
#
# 731 Ryan's Bar is definitely one Edinburgh establishment I won't be revisiting.	0
#
# 732 Nicest Chinese restaurant I've been in a while.	1
#
# 733 Overall, I like there food and the service.	1
#
# 734 They also now serve Indian naan bread with hummus and some spicy pine nut sauce that was out of this world.	1
#
# ...
#
# 769 * Both the Hot & Sour & the Egg Flower Soups were absolutely 5 Stars!	1
#
# 770 My sashimi was poor quality being soggy and tasteless.	0
#
# 771 Great time - family dinner on a Sunday night.	1
#
# 772 the food is not tasty at all, not to say its "real traditional Hunan style".	0
#
# 773 What did bother me, was the slow service.	0
#
# 774 The flair bartenders are absolutely amazing!	1
#
# 775 Their frozen margaritas are WAY too sugary for my taste.	0
#
# 776 These were so good we ordered them twice.	1
#
# 777 So in a nutshell: 1) The restaraunt smells like a combination of a dirty fish market and a sewer.	0
#
# 778 My girlfriend's veal was very bad.	0
#
# 779 Unfortunately, it was not good.	0
#
# 780 I had a pretty satifying experience.	1
#
# 781 Join the club and get awesome offers via email.	1
#
# 782 Perfect for someone (me) who only likes beer ice cold, or in this case, even colder.	1
#
# 783 Bland and flavorless is a good way of describing the barely tepid meat.	0
#
# 784 The chains, which I'm no fan of, beat this place easily.	0
#
# 785 The nachos are a MUST HAVE!	1
#
# 786 We will not be coming back.	0
#
# 787 I don't have very many words to say about this place, but it does everything pretty well.	1
#
# 788 The staff is super nice and very quick even with the crazy crowds of the downtown juries, lawyers, and court staff.	1
#
# 789 Great atmosphere, friendly and fast service.	1
#
# 790 When I received my Pita it was huge it did have a lot of meat in it so thumbs up there.	1
#
# 791 Once your food arrives it's meh.	0
#
# 792 Paying $7.85 for a hot dog and fries that looks like it came out of a kid's meal at the Wienerschnitzel is not my idea of a good meal.	0
#
# 793 The classic Maine Lobster Roll was fantastic.	1
#
# 794 My brother in law who works at the mall ate here same day, and guess what he was sick all night too.	0
#
# 795 So good I am going to have to review this place twice - once hereas a tribute to the place and once as a tribute to an event held here last night.	1
#
# 796 The chips and salsa were really good, the salsa was very fresh.	1
#
# 797 This place is great!!!!!!!!!!!!!!	1
#
# 798 Mediocre food.	0
#
# 799 Once you get inside you'll be impressed with the place.	1
#
# 800 I'm super pissd.	0
#
# 801 And service was super friendly.	1
#
# 802 Why are these sad little vegetables so overcooked?	0
#
# 803 This place was such a nice surprise!	1
#
# 804 They were golden-crispy and delicious.	1
#
# 805 I had high hopes for this place since the burgers are cooked over a charcoal grill, but unfortunately the taste fell flat, way flat.	0
#
# 806 I could eat their bruschetta all day it is devine.	1
#
# 807 Not a single employee came out to see if we were OK or even needed a water refill once they finally served us our food.	0
#
# 808 Lastly, the mozzarella sticks, they were the best thing we ordered.	1
#
# 809 The first time I ever came here I had an amazing experience, I still tell people how awesome the duck was.	1
#
# 810 The server was very negligent of our needs and made us feel very unwelcome... I would not suggest this place!	0
#
# 811 The service was terrible though.	0
#
# 812 This place is overpriced, not consistent with their boba, and it really is OVERPRICED!	0
#
# 813 It was packed!!	0
#
# 814 I love this place.	1
#
# 815 I can say that the desserts were yummy.	1
#
# 816 The food was terrible.	0
#
# 817 The seasonal fruit was fresh white peach puree.	1
#
# 818 It kept getting worse and worse so now I'm officially done.	0
#
# 819 This place should honestly be blown up.	0
#
# 820 But I definitely would not eat here again.	0
#
# 821 Do not waste your money here!	0
#
# 822 I love that they put their food in nice plastic containers as opposed to cramming it in little paper takeout boxes.	1
#
# 823 The crêpe was delicate and thin and moist.	1
#
# 824 Awful service.	0
#
# 825 Won't ever go here again.	0
#
# 826 Food quality has been horrible.	0
#
# 827 For that price I can think of a few place I would have much rather gone.	0
#
# 828 The service here is fair at best.	0
#
# 829 I do love sushi, but I found Kabuki to be over-priced, over-hip and under-services.	0
#
# 830 Do yourself a favor and stay away from this dish.	0
#
# 831 Very poor service.	0
#
# 832 No one at the table thought the food was above average or worth the wait that we had for it.	0
#
# 833 Best service and food ever, Maria our server was so good and friendly she made our day.	1
#
# 834 They were excellent.	1
#
# 835 I paid the bill but did not tip because I felt the server did a terrible job.	0
#
# 836 Just had lunch here and had a great experience.	1
#
# 837 I have never had such bland food which surprised me considering the article we read focused so much on their spices and flavor.	0
#
# 838 Food is way overpriced and portions are fucking small.	0
#
# 839 I recently tried Caballero's and I have been back every week since!	1
#
# 840 for 40 bucks a head, i really expect better food.	0
#
# 841 The food came out at a good pace.	1
#
# 842 I ate there twice on my last visit, and especially enjoyed the salmon salad.	1
#
# 843 I won't be back.	0
#
# 844 We could not believe how dirty the oysters were!	0
#
# 845 This place deserves no stars.	0
#
# 846 I would not recommend this place.	0
#
# 847 In fact I'm going to round up to 4 stars, just because she was so awesome.	1
#
# 848 To my disbelief, each dish qualified as the worst version of these foods I have ever tasted.	0
#
# 849 Bad day or not, I have a very low tolerance for rude customer service people, it is your job to be nice and polite, wash dishes otherwise!!	0
#
# 850 the potatoes were great and so was the biscuit.	1
#
# 851 I probably would not go here again.	0
#
# 852 So flavorful and has just the perfect amount of heat.	1
#
# 853 The price is reasonable and the service is great.	1
#
# 854 The Wife hated her meal (coconut shrimp), and our friends really did not enjoy their meals, either.	0
#
# 855 My fella got the huevos rancheros and they didn't look too appealing.	0
#
# 856 Went in for happy hour, great list of wines.	1
#
# 857 Some may say this buffet is pricey but I think you get what you pay for and this place you are getting quite a lot!	1
#
# 858 I probably won't be coming back here.	0
#
# 859 Worst food/service I've had in a while.	0
#
# 860 This place is pretty good, nice little vibe in the restaurant.	1
#
# 861 Talk about great customer service of course we will be back.	1
#
# 862 Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil.	0
#
# 863 I love their fries and their beans.	1
#
# 864 Always a pleasure dealing with him.	1
#
# 865 They have a plethora of salads and sandwiches, and everything I've tried gets my seal of approval.	1
#
# 866 This place is awesome if you want something light and healthy during the summer.	1
#
# 867 For sushi on the Strip, this is the place to go.	1
#
# 868 The service was great, even the manager came and helped with our table.	1
#
# 869 The feel of the dining room was more college cooking course than high class dining and the service was slow at best.	0
#
# 870 I started this review with two stars, but I'm editing it to give it only one.	0
#
# 871 this is the worst sushi i have ever eat besides Costco's.	0
#
# 872 All in all an excellent restaurant highlighted by great service, a unique menu, and a beautiful setting.	1
#
# 873 My boyfriend and i sat at the bar and had a completely delightful experience.	1
#
# 874 Weird vibe from owners.	0
#
# 875 There was hardly any meat.	0
#
# 876 I've had better bagels from the grocery store.	0
#
# 877 Go To Place for Gyros.	1
#
# 878 I love the owner/chef, his one authentic Japanese cool dude!	1
#
# 879 Now the burgers aren't as good, the pizza which used to be amazing is doughy and flavorless.	0
#
# 880 I found a six inch long piece of wire in my salsa.	0
#
# 881 The service was terrible, food was mediocre.	0
#
# 882 We definately enjoyed ourselves.	1
#
# 883 I ordered Albondigas soup - which was just warm - and tasted like tomato soup with frozen meatballs.	0
#
# 884 On three different occasions I asked for well done or medium well, and all three times I got the bloodiest piece of meat on my plate.	0
#
# 885 I had about two bites and refused to eat anymore.	0
#
# 886 The service was extremely slow.	0
#
# 887 After 20 minutes wait, I got a table.	0
#
# 888 Seriously killer hot chai latte.	1
#
# 889 No allergy warnings on the menu, and the waitress had absolutely no clue as to which meals did or did not contain peanuts.	0
#
# 890 My boyfriend tried the Mediterranean Chicken Salad and fell in love.	1
#
# 891 Their rotating beers on tap is also a highlight of this place.	1
#
# 892 Pricing is a bit of a concern at Mellow Mushroom.	0
#
# 893 Worst Thai ever.	0
#
# 894 If you stay in Vegas you must get breakfast here at least once.	1
#
# 895 I want to first say our server was great and we had perfect service.	1
#
# 896 The pizza selections are good.	1
#
# 897 I had strawberry tea, which was good.	1
#
# 898 Highly unprofessional and rude to a loyal patron!	0
#
# 899 Overall, a great experience.	1
#
# 900 Spend your money elsewhere.	0
#
# 901 Their regular toasted bread was equally satisfying with the occasional pats of butter... Mmmm...!	1
#
# 902 The Buffet at Bellagio was far from what I anticipated.	0
#
# 903 And the drinks are WEAK, people!	0
#
# 904 -My order was not correct.	0
#
# 905 Also, I feel like the chips are bought, not made in house.	0
#
# 906 After the disappointing dinner we went elsewhere for dessert.	0
#
# 907 The chips and sals a here is amazing!!!!!!!!!!!!!!!!!!!	1
#
# 908 We won't be returning.	0
#
# 909 This is my new fav Vegas buffet spot.	1
#
# 910 I seriously cannot believe that the owner has so many unexperienced employees that all are running around like chickens with their heads cut off.	0
#
# 911 Very, very sad.	0
#
# 912 i felt insulted and disrespected, how could you talk and judge another human being like that?	0
#
# 913 How can you call yourself a steakhouse if you can't properly cook a steak, I don't understand!	0
#
# 914 I'm not impressed with the concept or the food.	0
#
# 915 The only thing I wasn't too crazy about was their guacamole as I don't like it puréed.	0
#
# 916 There is really nothing for me at postinos, hope your experience is better	0
#
# 917 I got food poisoning here at the buffet.	0
#
# 918 They brought a fresh batch of fries and I was thinking yay something warm but no!	0
#
# 919 What SHOULD have been a hilarious, yummy Christmas Eve dinner to remember was the biggest fail of the entire trip for us.	0
#
# 920 Needless to say, I won't be going back anytime soon.	0
#
# 921 This place is disgusting!	0
#
# 922 Every time I eat here, I see caring teamwork to a professional degree.	1
#
# 923 The RI style calamari was a joke.	0
#
# 924 However, there was so much garlic in the fondue, it was barely edible.	0
#
# 925 I could barely stomach the meal, but didn't complain because it was a business lunch.	0
#
# 926 It was so bad, I had lost the heart to finish it.	0
#
# 927 It also took her forever to bring us the check when we asked for it.	0
#
# 928 We aren't ones to make a scene at restaurants but I just don't get it...definitely lost the love after this one!	0
#
# 929 Disappointing experience.	0
#
# 930 The food is about on par with Denny's, which is to say, not good at all.	0
#
# 931 If you want to wait for mediocre food and downright terrible service, then this is the place for you.	0
#
# 932 WAAAAAAyyyyyyyyyy over rated is all I am saying.	0
#
# 933 We won't be going back.	0
#
# 934 The place was fairly clean but the food simply wasn't worth it.	0
#
# 935 This place lacked style!!	0
#
# 936 The sangria was about half of a glass wine full and was $12, ridiculous.	0
#
# 937 Don't bother coming here.	0
#
# 938 The meat was pretty dry, I had the sliced brisket and pulled pork.	0
#
# 939 The building itself seems pretty neat; the bathroom is pretty trippy, but I wouldn't eat here again.	0
#
# 940 It was equally awful.	0
#
# 941 Probably not in a hurry to go back.	0
#
# 942 very slow at seating even with reservation.	0
#
# 943 Not good by any stretch of the imagination.	0
#
# 944 The cashew cream sauce was bland and the vegetables were undercooked.	0
#
# 945 The chipolte ranch dipping sause was tasteless, seemed thin and watered down with no heat.	0
#
# 946 It was a bit too sweet, not really spicy enough, and lacked flavor.	0
#
# 947 I was VERY disappointed!!	0
#
# 948 This place is horrible and way overpriced.	0
#
# 949 Maybe it's just their Vegetarian fare, but I've been twice and I thought it was average at best.	0
#
# 950 It wasn't busy at all and now we know why.	0
#
# 951 The tables outside are also dirty a lot of the time and the workers are not always friendly and helpful with the menu.	0
#
# 952 The ambiance here did not feel like a buffet setting, but more of a douchey indoor garden for tea and biscuits.	0
#
# 953 Con: spotty service.	0
#
# 954 The fries were not hot, and neither was my burger.	0
# 955 But then they came back cold.	0
#
# 956 Then our food came out, disappointment ensued.	0
#
# 957 The real disappointment was our waiter.	0
#
# 958 My husband said she was very rude... did not even apologize for the bad food or anything.	0
#
# 959 The only reason to eat here would be to fill up before a night of binge drinking just to get some carbs in your stomach.	0
#
# 960 Insults, profound deuchebaggery, and had to go outside for a smoke break while serving just to solidify it.	0
#
# 961 If someone orders two tacos don't' you think it may be part of customer service to ask if it is combo or ala cart?	0
#
# 962 She was quite disappointed although some blame needs to be placed at her door.	0
#
# 963 After all the rave reviews I couldn't wait to eat here......what a disappointment!	0
#
# 964 Del Taco is pretty nasty and should be avoided if possible.	0
#
# 965 It's NOT hard to make a decent hamburger.	0
#
# 966 But I don't like it.	0
#
# 967 Hell no will I go back	0
#
# 968 We've have gotten a much better service from the pizza place next door than the services we received from this restaurant.	0
#
# 969 I don't know what the big deal is about this place, but I won't be back "ya'all".	0
#
# 970 I immediately said I wanted to talk to the manager but I did not want to talk to the guy who was doing shots of fireball behind the bar.	0
#
# 971 The ambiance isn't much better.	0
#
# 972 Unfortunately, it only set us up for disapppointment with our entrees.	0
#
# 973 The food wasn't good.	0
#
# 974 Your servers suck, wait, correction, our server Heimer sucked.	0
#
# 975 What happened next was pretty....off putting.	0
#
# 976 too bad cause I know it's family owned, I really wanted to like this place.	0
#
# 977 Overpriced for what you are getting.	0
#
# 978 I vomited in the bathroom mid lunch.	0
#
# 979 I kept looking at the time and it had soon become 35 minutes, yet still no food.	0
#
# 980 I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list.	0
#
# 981 We started with the tuna sashimi which was brownish in color and obviously wasn't fresh.	0
#
# 982 Food was below average.	0
#
# 983 It sure does beat the nachos at the movies but I would expect a little bit more coming from a restaurant.	0
#
# 984 All in all, Ha Long Bay was a bit of a flop.	0
#
# 985 The problem I have is that they charge $11.99 for a sandwich that is no bigger than a Subway sub (which offers better and more amount of vegetables).	0
#
# 986 Shrimp- When I unwrapped it (I live only 1/2 a mile from Brushfire) it was literally ice cold.	0
#
# 987 It lacked flavor, seemed undercooked, and dry.	0
#
# 988 It really is impressive that the place hasn't closed down.	0
#
# 989 I would avoid this place if you are staying in the Mirage.	0
#
# 990 The refried beans that came with my meal were dried out and crusty and the food was bland.	0
#
# 991 Spend your money and time some place else.	0
#
# 992 A lady at the table next to us found a live green caterpillar In her salad.	0
#
# 993 the presentation of the food was awful.	0
#
# 994 I can't tell you how disappointed I was.	0
#
# 995 I think food should have flavor and texture and both were lacking.	0
#
# 996 Appetite instantly gone.	0
#
# 997 Overall I was not impressed and would not go back.	0
#
# 998 The whole experience was underwhelming, and I think we'll just go to Ninja Sushi next time.	0
#
# 999 Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check.	0

# %%
sentences = []
sentiments = []
with open("sentiment labelled sentences/yelp_labelled.txt") as f:
    for item_no, line in enumerate(f):
        line_split = line.strip().split('\t')
        sentences.append((line_split[0], "yelp_%d" % item_no))
        sentiments.append(int(line_split[1]))

# %%
len(sentences), sentences
# Out:
# (3000,
#  [('Wow... Loved this place.', 'yelp_0'),
#   ('Crust is not good.', 'yelp_1'),
#   ('Not tasty and the texture was just nasty.', 'yelp_2'),
#   ('Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#    'yelp_3'),
#   ('The selection on the menu was great and so were the prices.', 'yelp_4'),
#   ('Now I am getting angry and I want my damn pho.', 'yelp_5'),
#   ("Honeslty it didn't taste THAT fresh.)", 'yelp_6'),
#   ('The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#    'yelp_7'),
#   ('The fries were great too.', 'yelp_8'),
#   ('A great touch.', 'yelp_9'),
#   ('Service was very prompt.', 'yelp_10'),
#   ('Would not go back.', 'yelp_11'),
#   ('The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.',
#    'yelp_12'),
#   ('I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!', 'yelp_13'),
#   ('I was disgusted because I was pretty sure that was human hair.',
#    'yelp_14'),
#   ('I was shocked because no signs indicate cash only.', 'yelp_15'),
#   ('Highly recommended.', 'yelp_16'),
#   ('Waitress was a little slow in service.', 'yelp_17'),
#   ('This place is not worth your time, let alone Vegas.', 'yelp_18'),
#   ('did not like at all.', 'yelp_19'),
#   ('The Burrittos Blah!', 'yelp_20'),
#   ('The food, amazing.', 'yelp_21'),
#   ('Service is also cute.', 'yelp_22'),
#   ('I could care less... The interior is just beautiful.', 'yelp_23'),
#   ('So they performed.', 'yelp_24'),
#   ("That's right....the red velvet cake.....ohhh this stuff is so good.",
#    'yelp_25'),
#   ('- They never brought a salad we asked for.', 'yelp_26'),
#   ('This hole in the wall has great Mexican street tacos, and friendly staff.',
#    'yelp_27'),
#   ('Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.',
#    'yelp_28'),
#   ('The worst was the salmon sashimi.', 'yelp_29'),
#   ('Also there are combos like a burger, fries, and beer for 23 which is a decent deal.',
#    'yelp_30'),
#   ('This was like the final blow!', 'yelp_31'),
#   ('I found this place by accident and I could not be happier.', 'yelp_32'),
#   ('seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.',
#    'yelp_33'),
#   ('Overall, I like this place a lot.', 'yelp_34'),
#   ('The only redeeming quality of the restaurant was that it was very inexpensive.',
#    'yelp_35'),
#   ('Ample portions and good prices.', 'yelp_36'),
#   ('Poor service, the waiter made me feel like I was stupid every time he came to the table.',
#    'yelp_37'),
#   ('My first visit to Hiro was a delight!', 'yelp_38'),
#   ('Service sucks.', 'yelp_39'),
#   ('The shrimp tender and moist.', 'yelp_40'),
#   ('There is not a deal good enough that would drag me into that establishment again.',
#    'yelp_41'),
#   ("Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick.",
#    'yelp_42'),
#   ('On a positive note, our server was very attentive and provided great service.',
#    'yelp_43'),
#   ('Frozen pucks of disgust, with some of the worst people behind the register.',
#    'yelp_44'),
#   ('The only thing I did like was the prime rib and dessert section.',
#    'yelp_45'),
#   ("It's too bad the food is so damn generic.", 'yelp_46'),
#   ('The burger is good beef, cooked just right.', 'yelp_47'),
#   ('If you want a sandwich just go to any Firehouse!!!!!', 'yelp_48'),
#   ('My side Greek salad with the Greek dressing was so tasty, and the pita and hummus was very refreshing.',
#    'yelp_49'),
#   ('We ordered the duck rare and it was pink and tender on the inside with a nice char on the outside.',
#    'yelp_50'),
#   ('He came running after us when he realized my husband had left his sunglasses on the table.',
#    'yelp_51'),
#   ('Their chow mein is so good!', 'yelp_52'),
#   ("They have horrible attitudes towards customers, and talk down to each one when customers don't enjoy their food.",
#    'yelp_53'),
#   ('The portion was huge!', 'yelp_54'),
#   ('Loved it...friendly servers, great food, wonderful and imaginative menu.',
#    'yelp_55'),
#   ('The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant.',
#    'yelp_56'),
#   ('Not much seafood and like 5 strings of pasta at the bottom.', 'yelp_57'),
#   ('The salad had just the right amount of sauce to not over power the scallop, which was perfectly cooked.',
#    'yelp_58'),
#   ('The ripped banana was not only ripped, but petrified and tasteless.',
#    'yelp_59'),
#   ('At least think to refill my water before I struggle to wave you over for 10 minutes.',
#    'yelp_60'),
#   ('This place receives stars for their APPETIZERS!!!', 'yelp_61'),
#   ('The cocktails are all handmade and delicious.', 'yelp_62'),
#   ("We'd definitely go back here again.", 'yelp_63'),
#   ('We are so glad we found this place.', 'yelp_64'),
#   ('Great food and service, huge portions and they give a military discount.',
#    'yelp_65'),
#   ('Always a great time at Dos Gringos!', 'yelp_66'),
#   ('Update.....went back for a second time and it was still just as amazing',
#    'yelp_67'),
#   ('We got the food and apparently they have never heard of salt and the batter on the fish was chewy.',
#    'yelp_68'),
#   ('A great way to finish a great.', 'yelp_69'),
#   ('The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected.',
#    'yelp_70'),
#   ('- Really, really good rice, all the time.', 'yelp_71'),
#   ('The service was meh.', 'yelp_72'),
#   ('It took over 30 min to get their milkshake, which was nothing more than chocolate milk.',
#    'yelp_73'),
#   ("I guess I should have known that this place would suck, because it is inside of the Excalibur, but I didn't use my common sense.",
#    'yelp_74'),
#   ('The scallop dish is quite appalling for value as well.', 'yelp_75'),
#   ('2 times - Very Bad Customer Service !', 'yelp_76'),
#   ('The sweet potato fries were very good and seasoned well.', 'yelp_77'),
#   ("Today is the second time I've been to their lunch buffet and it was pretty good.",
#    'yelp_78'),
#   ('There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company.',
#    'yelp_79'),
#   ("Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up.",
#    'yelp_80'),
#   ('walked in and the place smelled like an old grease trap and only 2 others there eating.',
#    'yelp_81'),
#   ('The turkey and roast beef were bland.', 'yelp_82'),
#   ('This place has it!', 'yelp_83'),
#   ('The pan cakes everyone are raving about taste like a sugary disaster tailored to the palate of a six year old.',
#    'yelp_84'),
#   ('I love the Pho and the spring rolls oh so yummy you have to try.',
#    'yelp_85'),
#   ('The poor batter to meat ratio made the chicken tenders very unsatisfying.',
#    'yelp_86'),
#   ('All I have to say is the food was amazing!!!', 'yelp_87'),
#   ('Omelets are to die for!', 'yelp_88'),
#   ('Everything was fresh and delicious!', 'yelp_89'),
#   ('In summary, this was a largely disappointing dining experience.',
#    'yelp_90'),
#   ("It's like a really sexy party in your mouth, where you're outrageously flirting with the hottest person at the party.",
#    'yelp_91'),
#   ('Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN!',
#    'yelp_92'),
#   ('Best breakfast buffet!!!', 'yelp_93'),
#   ('say bye bye to your tip lady!', 'yelp_94'),
#   ("We'll never go again.", 'yelp_95'),
#   ('Will be back again!', 'yelp_96'),
#   ('Food arrived quickly!', 'yelp_97'),
#   ('It was not good.', 'yelp_98'),
#   ('On the up side, their cafe serves really good food.', 'yelp_99'),
#   ('Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go!',
#    'yelp_100'),
#   ("The only good thing was our waiter, he was very helpful and kept the bloddy mary's coming.",
#    'yelp_101'),
#   ('Best Buffet in town, for the price you cannot beat it.', 'yelp_102'),
#   ('I LOVED their mussels cooked in this wine reduction, the duck was tender, and their potato dishes were delicious.',
#    'yelp_103'),
#   ('This is one of the better buffets that I have been to.', 'yelp_104'),
#   ('So we went to Tigerlilly and had a fantastic afternoon!', 'yelp_105'),
#   ('The food was delicious, our bartender was attentive and personable AND we got a great deal!',
#    'yelp_106'),
#   ('The ambience is wonderful and there is music playing.', 'yelp_107'),
#   ('Will go back next trip out.', 'yelp_108'),
#   ('Sooooo good!!', 'yelp_109'),
#   ("REAL sushi lovers, let's be honest - Yama is not that good.", 'yelp_110'),
#   ("At least 40min passed in between us ordering and the food arriving, and it wasn't that busy.",
#    'yelp_111'),
#   ('This is a really fantastic Thai restaurant which is definitely worth a visit.',
#    'yelp_112'),
#   ('Nice, spicy and tender.', 'yelp_113'),
#   ('Good prices.', 'yelp_114'),
#   ('Check it out.', 'yelp_115'),
#   ('It was pretty gross!', 'yelp_116'),
#   ("I've had better atmosphere.", 'yelp_117'),
#   ('Kind of hard to mess up a steak but they did.', 'yelp_118'),
#   ('Although I very much liked the look and sound of this place, the actual experience was a bit disappointing.',
#    'yelp_119'),
#   ("I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine.",
#    'yelp_120'),
#   ('Worst service to boot, but that is the least of their worries.',
#    'yelp_121'),
#   ('Service was fine and the waitress was friendly.', 'yelp_122'),
#   ("The guys all had steaks, and our steak loving son who has had steak at the best and worst places said it was the best steak he's ever eaten.",
#    'yelp_123'),
#   ("We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night.",
#    'yelp_124'),
#   ('Host staff were, for lack of a better word, BITCHES!', 'yelp_125'),
#   ("Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that...",
#    'yelp_126'),
#   ('Phenomenal food, service and ambiance.', 'yelp_127'),
#   ("I wouldn't return.", 'yelp_128'),
#   ("Definitely worth venturing off the strip for the pork belly, will return next time I'm in Vegas.",
#    'yelp_129'),
#   ('This place is way too overpriced for mediocre food.', 'yelp_130'),
#   ('Penne vodka excellent!', 'yelp_131'),
#   ('They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers.',
#    'yelp_132'),
#   ('The management is rude.', 'yelp_133'),
#   ('Delicious NYC bagels, good selections of cream cheese, real Lox with capers even.',
#    'yelp_134'),
#   ("Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations.",
#    'yelp_135'),
#   ('I had a seriously solid breakfast here.', 'yelp_136'),
#   ('This is one of the best bars with food in Vegas.', 'yelp_137'),
#   ('He was extremely rude and really, there are so many other restaurants I would love to dine at during a weekend in Vegas.',
#    'yelp_138'),
#   ('My drink was never empty and he made some really great menu suggestions.',
#    'yelp_139'),
#   ("Don't do it!!!!", 'yelp_140'),
#   ("The waiter wasn't helpful or friendly and rarely checked on us.",
#    'yelp_141'),
#   ('My husband and I ate lunch here and were very disappointed with the food and service.',
#    'yelp_142'),
#   ("And the red curry had so much bamboo shoots and wasn't very tasty to me.",
#    'yelp_143'),
#   ('Nice blanket of moz over top but i feel like this was done to cover up the subpar food.',
#    'yelp_144'),
#   ('The bathrooms are clean and the place itself is well decorated.',
#    'yelp_145'),
#   ('The menu is always changing, food quality is going down & service is extremely slow.',
#    'yelp_146'),
#   ('The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace.',
#    'yelp_147'),
#   ('I give it 2 thumbs down', 'yelp_148'),
#   ('We watched our waiter pay a lot more attention to other tables and ignore us.',
#    'yelp_149'),
#   ('My fiancé and I came in the middle of the day and we were greeted and seated right away.',
#    'yelp_150'),
#   ('This is a great restaurant at the Mandalay Bay.', 'yelp_151'),
#   ('We waited for forty five minutes in vain.', 'yelp_152'),
#   ('Crostini that came with the salad was stale.', 'yelp_153'),
#   ('Some highlights : Great quality nigiri here!', 'yelp_154'),
#   ('the staff is friendly and the joint is always clean.', 'yelp_155'),
#   ('this was a different cut than the piece the other day but still wonderful and tender s well as well flavored.',
#    'yelp_156'),
#   ("I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago.",
#    'yelp_157'),
#   ('this place is good.', 'yelp_158'),
#   ('Unfortunately, we must have hit the bakery on leftover day because everything we ordered was STALE.',
#    'yelp_159'),
#   ('I came back today since they relocated and still not impressed.',
#    'yelp_160'),
#   ('I was seated immediately.', 'yelp_161'),
#   ('Their menu is diverse, and reasonably priced.', 'yelp_162'),
#   ('Avoid at all cost!', 'yelp_163'),
#   ('Restaurant is always full but never a wait.', 'yelp_164'),
#   ('DELICIOUS!!', 'yelp_165'),
#   ('This place is hands-down one of the best places to eat in the Phoenix metro area.',
#    'yelp_166'),
#   ("So don't go there if you are looking for good food...", 'yelp_167'),
#   ("I've never been treated so bad.", 'yelp_168'),
#   ('Bacon is hella salty.', 'yelp_169'),
#   ('We also ordered the spinach and avocado salad; the ingredients were sad and the dressing literally had zero taste.',
#    'yelp_170'),
#   ('This really is how Vegas fine dining used to be, right down to the menus handed to the ladies that have no prices listed.',
#    'yelp_171'),
#   ('The waitresses are very friendly.', 'yelp_172'),
#   ('Lordy, the Khao Soi is a dish that is not to be missed for curry lovers!',
#    'yelp_173'),
#   ('Everything on the menu is terrific and we were also thrilled that they made amazing accommodations for our vegetarian daughter.',
#    'yelp_174'),
#   ("Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back.",
#    'yelp_175'),
#   ('The service here leaves a lot to be desired.', 'yelp_176'),
#   ('The atmosphere is modern and hip, while maintaining a touch of coziness.',
#    'yelp_177'),
#   ('Not a weekly haunt, but definitely a place to come back to every once in a while.',
#    'yelp_178'),
#   ('We literally sat there for 20 minutes with no one asking to take our order.',
#    'yelp_179'),
#   ('The burger had absolutely no flavor - the meat itself was totally bland, the burger was overcooked and there was no charcoal flavor.',
#    'yelp_180'),
#   ('I also decided not to send it back because our waitress looked like she was on the verge of having a heart attack.',
#    'yelp_181'),
#   ('I dressed up to be treated so rudely!', 'yelp_182'),
#   ('It was probably dirt.', 'yelp_183'),
#   ('Love this place, hits the spot when I want something healthy but not lacking in quantity or flavor.',
#    'yelp_184'),
#   ('I ordered the Lemon raspberry ice cocktail which was also incredible.',
#    'yelp_185'),
#   ('The food sucked, which we expected but it sucked more than we could have imagined.',
#    'yelp_186'),
#   ('Interesting decor.', 'yelp_187'),
#   ('What I really like there is the crepe station.', 'yelp_188'),
#   ('Also were served hot bread and butter, and home made potato chips with bacon bits on top....very original and very good.',
#    'yelp_189'),
#   ('you can watch them preparing the delicious food!)', 'yelp_190'),
#   ('Both of the egg rolls were fantastic.', 'yelp_191'),
#   ('When my order arrived, one of the gyros was missing.', 'yelp_192'),
#   ('I had a salad with the wings, and some ice cream for dessert and left feeling quite satisfied.',
#    'yelp_193'),
#   ("I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine.",
#    'yelp_194'),
#   ('The best place to go for a tasty bowl of Pho!', 'yelp_195'),
#   ('The live music on Fridays totally blows.', 'yelp_196'),
#   ("I've never been more insulted or felt disrespected.", 'yelp_197'),
#   ('Very friendly staff.', 'yelp_198'),
#   ('It is worth the drive.', 'yelp_199'),
#   ('I had heard good things about this place, but it exceeding every hope I could have dreamed of.',
#    'yelp_200'),
#   ('Food was great and so was the serivce!', 'yelp_201'),
#   ("The warm beer didn't help.", 'yelp_202'),
#   ('Great brunch spot.', 'yelp_203'),
#   ('Service is friendly and inviting.', 'yelp_204'),
#   ('Very good lunch spot.', 'yelp_205'),
#   ("I've lived here since 1979 and this was the first (and last) time I've stepped foot into this place.",
#    'yelp_206'),
#   ('The WORST EXPERIENCE EVER.', 'yelp_207'),
#   ('Must have been an off night at this place.', 'yelp_208'),
#   ('The sides are delish - mixed mushrooms, yukon gold puree, white corn - beateous.',
#    'yelp_209'),
#   ('If that bug never showed up I would have given a 4 for sure, but on the other side of the wall where this bug was climbing was the kitchen.',
#    'yelp_210'),
#   ("For about 10 minutes, we we're waiting for her salad when we realized that it wasn't coming any time soon.",
#    'yelp_211'),
#   ('My friend loved the salmon tartar.', 'yelp_212'),
#   ("Won't go back.", 'yelp_213'),
#   ('Extremely Tasty!', 'yelp_214'),
#   ('Waitress was good though!', 'yelp_215'),
#   ('Soggy and not good.', 'yelp_216'),
#   ('The Jamaican mojitos are delicious.', 'yelp_217'),
#   ('Which are small and not worth the price.', 'yelp_218'),
#   ('- the food is rich so order accordingly.', 'yelp_219'),
#   ("The shower area is outside so you can only rinse, not take a full shower, unless you don't mind being nude for everyone to see!",
#    'yelp_220'),
#   ('The service was a bit lacking.', 'yelp_221'),
#   ('Lobster Bisque, Bussell Sprouts, Risotto, Filet ALL needed salt and pepper..and of course there is none at the tables.',
#    'yelp_222'),
#   ('Hopefully this bodes for them going out of business and someone who can cook can come in.',
#    'yelp_223'),
#   ('It was either too cold, not enough flavor or just bad.', 'yelp_224'),
#   ('I loved the bacon wrapped dates.', 'yelp_225'),
#   ('This is an unbelievable BARGAIN!', 'yelp_226'),
#   ('The folks at Otto always make us feel so welcome and special.',
#    'yelp_227'),
#   ('As for the "mains," also uninspired.', 'yelp_228'),
#   ('This is the place where I first had pho and it was amazing!!', 'yelp_229'),
#   ('This wonderful experience made this place a must-stop whenever we are in town again.',
#    'yelp_230'),
#   ("If the food isn't bad enough for you, then enjoy dealing with the world's worst/annoying drunk people.",
#    'yelp_231'),
#   ('Very very fun chef.', 'yelp_232'),
#   ('Ordered a double cheeseburger & got a single patty that was falling apart (picture uploaded) Yeah, still sucks.',
#    'yelp_233'),
#   ("Great place to have a couple drinks and watch any and all sporting events as the walls are covered with TV's.",
#    'yelp_234'),
#   ("If it were possible to give them zero stars, they'd have it.", 'yelp_235'),
#   ('The descriptions said "yum yum sauce" and another said "eel sauce", yet another said "spicy mayo"...well NONE of the rolls had sauces on them.',
#    'yelp_236'),
#   ("I'd say that would be the hardest decision... Honestly, all of M's dishes taste how they are supposed to taste (amazing).",
#    'yelp_237'),
#   ('If she had not rolled the eyes we may have stayed... Not sure if we will go back and try it again.',
#    'yelp_238'),
#   ('Everyone is very attentive, providing excellent customer service.',
#    'yelp_239'),
#   ("Horrible - don't waste your time and money.", 'yelp_240'),
#   ('Now this dish was quite flavourful.', 'yelp_241'),
#   ('By this time our side of the restaurant was almost empty so there was no excuse.',
#    'yelp_242'),
#   ("(It wasn't busy either) Also, the building was FREEZING cold.",
#    'yelp_243'),
#   ('like the other reviewer said "you couldn\'t pay me to eat at this place again."',
#    'yelp_244'),
#   ('-Drinks took close to 30 minutes to come out at one point.', 'yelp_245'),
#   ('Seriously flavorful delights, folks.', 'yelp_246'),
#   ('Much better than the other AYCE sushi place I went to in Vegas.',
#    'yelp_247'),
#   ('The lighting is just dark enough to set the mood.', 'yelp_248'),
#   ("Based on the sub-par service I received and no effort to show their gratitude for my business I won't be going back.",
#    'yelp_249'),
#   ("Owner's are really great people.!", 'yelp_250'),
#   ('There is nothing privileged about working/eating there.', 'yelp_251'),
#   ('The Greek dressing was very creamy and flavorful.', 'yelp_252'),
#   ("Overall, I don't think that I would take my parents to this place again because they made most of the similar complaints that I silently felt too.",
#    'yelp_253'),
#   ('Now the pizza itself was good the peanut sauce was very tasty.',
#    'yelp_254'),
#   ('We had 7 at our table and the service was pretty fast.', 'yelp_255'),
#   ('Fantastic service here.', 'yelp_256'),
#   ("I as well would've given godfathers zero stars if possible.", 'yelp_257'),
#   ('They know how to make them here.', 'yelp_258'),
#   ('very tough and very short on flavor!', 'yelp_259'),
#   ('I hope this place sticks around.', 'yelp_260'),
#   ('I have been in more than a few bars in Vegas, and do not ever recall being charged for tap water.',
#    'yelp_261'),
#   ('The restaurant atmosphere was exquisite.', 'yelp_262'),
#   ('Good service, very clean, and inexpensive, to boot!', 'yelp_263'),
#   ('The seafood was fresh and generous in portion.', 'yelp_264'),
#   ("Plus, it's only 8 bucks.", 'yelp_265'),
#   ('The service was not up to par, either.', 'yelp_266'),
#   ('Thus far, have only visited twice and the food was absolutely delicious each time.',
#    'yelp_267'),
#   ('Just as good as when I had it more than a year ago!', 'yelp_268'),
#   ('For a self proclaimed coffee cafe, I was wildly disappointed.',
#    'yelp_269'),
#   ('The Veggitarian platter is out of this world!', 'yelp_270'),
#   ('You cant go wrong with any of the food here.', 'yelp_271'),
#   ("You can't beat that.", 'yelp_272'),
#   ('Stopped by this place while in Madison for the Ironman, very friendly, kind staff.',
#    'yelp_273'),
#   ('The chefs were friendly and did a good job.', 'yelp_274'),
#   ("I've had better, not only from dedicated boba tea spots, but even from Jenni Pho.",
#    'yelp_275'),
#   ('I liked the patio and the service was outstanding.', 'yelp_276'),
#   ("The goat taco didn't skimp on the meat and wow what FLAVOR!", 'yelp_277'),
#   ('I think not again', 'yelp_278'),
#   ('I had the mac salad and it was pretty bland so I will not be getting that again.',
#    'yelp_279'),
#   ("I went to Bachi Burger on a friend's recommendation and was not disappointed.",
#    'yelp_280'),
#   ('Service stinks here!', 'yelp_281'),
#   ('I waited and waited.', 'yelp_282'),
#   ('This place is not quality sushi, it is not a quality restaurant.',
#    'yelp_283'),
#   ('I would definitely recommend the wings as well as the pizza.', 'yelp_284'),
#   ('Great Pizza and Salads!', 'yelp_285'),
#   ('Things that went wrong: - They burned the saganaki.', 'yelp_286'),
#   ('We waited an hour for what was a breakfast I could have done 100 times better at home.',
#    'yelp_287'),
#   ('This place is amazing!', 'yelp_288'),
#   ('I hate to disagree with my fellow Yelpers, but my husband and I were so disappointed with this place.',
#    'yelp_289'),
#   ('Waited 2 hours & never got either of our pizzas as many other around us who came in later did!',
#    'yelp_290'),
#   ("Just don't know why they were so slow.", 'yelp_291'),
#   ('The staff is great, the food is delish, and they have an incredible beer selection.',
#    'yelp_292'),
#   ("I live in the neighborhood so I am disappointed I won't be back here, because it is a convenient location.",
#    'yelp_293'),
#   ("I didn't know pulled pork could be soooo delicious.", 'yelp_294'),
#   ('You get incredibly fresh fish, prepared with care.', 'yelp_295'),
#   ('Before I go in to why I gave a 1 star rating please know that this was my third time eating at Bachi burger before writing a review.',
#    'yelp_296'),
#   ('I love the fact that everything on their menu is worth it.', 'yelp_297'),
#   ('Never again will I be dining at this place!', 'yelp_298'),
#   ('The food was excellent and service was very good.', 'yelp_299'),
#   ('Good beer & drink selection and good food selection.', 'yelp_300'),
#   ('Please stay away from the shrimp stir fried noodles.', 'yelp_301'),
#   ('The potato chip order was sad... I could probably count how many chips were in that box and it was probably around 12.',
#    'yelp_302'),
#   ('Food was really boring.', 'yelp_303'),
#   ('Good Service-check!', 'yelp_304'),
#   ('This greedy corporation will NEVER see another dime from me!', 'yelp_305'),
#   ('Will never, ever go back.', 'yelp_306'),
#   ("As much as I'd like to go back, I can't get passed the atrocious service and will never return.",
#    'yelp_307'),
#   ('In the summer, you can dine in a charming outdoor patio - so very delightful.',
#    'yelp_308'),
#   ('I did not expect this to be so good!', 'yelp_309'),
#   ('Fantastic food!', 'yelp_310'),
#   ('She ordered a toasted English muffin that came out untoasted.',
#    'yelp_311'),
#   ('The food was very good.', 'yelp_312'),
#   ('Never going back.', 'yelp_313'),
#   ('Great food for the price, which is very high quality and house made.',
#    'yelp_314'),
#   ('The bus boy on the other hand was so rude.', 'yelp_315'),
#   ("By this point, my friends and I had basically figured out this place was a joke and didn't mind making it publicly and loudly known.",
#    'yelp_316'),
#   ('Back to good BBQ, lighter fare, reasonable pricing and tell the public they are back to the old ways.',
#    'yelp_317'),
#   ("And considering the two of us left there very full and happy for about $20, you just can't go wrong.",
#    'yelp_318'),
#   ('All the bread is made in-house!', 'yelp_319'),
#   ('The only downside is the service.', 'yelp_320'),
#   ("Also, the fries are without a doubt the worst fries I've ever had.",
#    'yelp_321'),
#   ('Service was exceptional and food was a good as all the reviews.',
#    'yelp_322'),
#   ('A couple of months later, I returned and had an amazing meal.',
#    'yelp_323'),
#   ('Favorite place in town for shawarrrrrrma!!!!!!', 'yelp_324'),
#   ('The black eyed peas and sweet potatoes... UNREAL!', 'yelp_325'),
#   ("You won't be disappointed.", 'yelp_326'),
#   ('They could serve it with just the vinaigrette and it may make for a better overall dish, but it was still very good.',
#    'yelp_327'),
#   ("I go to far too many places and I've never seen any restaurant that serves a 1 egg breakfast, especially for $4.00.",
#    'yelp_328'),
#   ('When my mom and I got home she immediately got sick and she only had a few bites of salad.',
#    'yelp_329'),
#   ("The servers are not pleasant to deal with and they don't always honor Pizza Hut coupons.",
#    'yelp_330'),
#   ('Both of them were truly unbelievably good, and I am so glad we went back.',
#    'yelp_331'),
#   ('We had fantastic service, and were pleased by the atmosphere.',
#    'yelp_332'),
#   ('Everything was gross.', 'yelp_333'),
#   ('I love this place.', 'yelp_334'),
#   ('Great service and food.', 'yelp_335'),
#   ('First - the bathrooms at this location were dirty- Seat covers were not replenished & just plain yucky!!!',
#    'yelp_336'),
#   ('The burger... I got the "Gold Standard" a $17 burger and was kind of disappointed.',
#    'yelp_337'),
#   ('OMG, the food was delicioso!', 'yelp_338'),
#   ('There is nothing authentic about this place.', 'yelp_339'),
#   ('the spaghetti is nothing special whatsoever.', 'yelp_340'),
#   ('Of all the dishes, the salmon was the best, but all were great.',
#    'yelp_341'),
#   ('The vegetables are so fresh and the sauce feels like authentic Thai.',
#    'yelp_342'),
#   ("It's worth driving up from Tucson!", 'yelp_343'),
#   ("The selection was probably the worst I've seen in Vegas.....there was none.",
#    'yelp_344'),
#   ('Pretty good beer selection too.', 'yelp_345'),
#   ('This place is like Chipotle, but BETTER.', 'yelp_346'),
#   ('Classy/warm atmosphere, fun and fresh appetizers, succulent steaks (Baseball steak!!!!!',
#    'yelp_347'),
#   ('5 stars for the brick oven bread app!', 'yelp_348'),
#   ('I have eaten here multiple times, and each time the food was delicious.',
#    'yelp_349'),
#   ('We sat another ten minutes and finally gave up and left.', 'yelp_350'),
#   ('He was terrible!', 'yelp_351'),
#   ('Everyone is treated equally special.', 'yelp_352'),
#   ("It shouldn't take 30 min for pancakes and eggs.", 'yelp_353'),
#   ('It was delicious!!!', 'yelp_354'),
#   ('On the good side, the staff was genuinely pleasant and enthusiastic - a real treat.',
#    'yelp_355'),
#   ("Sadly, Gordon Ramsey's Steak is a place we shall sharply avoid during our next trip to Vegas.",
#    'yelp_356'),
#   ('As always the evening was wonderful and the food delicious!', 'yelp_357'),
#   ("Best fish I've ever had in my life!", 'yelp_358'),
#   ('(The bathroom is just next door and very nice.)', 'yelp_359'),
#   ('The buffet is small and all the food they offered was BLAND.', 'yelp_360'),
#   ('This is an Outstanding little restaurant with some of the Best Food I have ever tasted.',
#    'yelp_361'),
#   ('Pretty cool I would say.', 'yelp_362'),
#   ("Definitely a turn off for me & i doubt I'll be back unless someone else is buying.",
#    'yelp_363'),
#   ('Server did a great job handling our large rowdy table.', 'yelp_364'),
#   ("I find wasting food to be despicable, but this just wasn't food.",
#    'yelp_365'),
#   ('My wife had the Lobster Bisque soup which was lukewarm.', 'yelp_366'),
#   ('Would come back again if I had a sushi craving while in Vegas.',
#    'yelp_367'),
#   ('The staff are great, the ambiance is great.', 'yelp_368'),
#   ('He deserves 5 stars.', 'yelp_369'),
#   ('I left with a stomach ache and felt sick the rest of the day.',
#    'yelp_370'),
#   ('They dropped more than the ball.', 'yelp_371'),
#   ('The dining space is tiny, but elegantly decorated and comfortable.',
#    'yelp_372'),
#   ("They will customize your order any way you'd like, my usual is Eggplant with Green Bean stir fry, love it!",
#    'yelp_373'),
#   ('And the beans and rice were mediocre at best.', 'yelp_374'),
#   ('Best tacos in town by far!!', 'yelp_375'),
#   ('I took back my money and got outta there.', 'yelp_376'),
#   ('In an interesting part of town, this place is amazing.', 'yelp_377'),
#   ('RUDE & INCONSIDERATE MANAGEMENT.', 'yelp_378'),
#   ('The staff are now not as friendly, the wait times for being served are horrible, no one even says hi for the first 10 minutes.',
#    'yelp_379'),
#   ("I won't be back.", 'yelp_380'),
#   ('They have great dinners.', 'yelp_381'),
#   ('The service was outshining & I definitely recommend the Halibut.',
#    'yelp_382'),
#   ('The food was terrible.', 'yelp_383'),
#   ('WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED.',
#    'yelp_384'),
#   ("I don't recommend unless your car breaks down in front of it and you are starving.",
#    'yelp_385'),
#   ("I will come back here every time I'm in Vegas.", 'yelp_386'),
#   ('This place deserves one star and 90% has to do with the food.',
#    'yelp_387'),
#   ('This is a disgrace.', 'yelp_388'),
#   ('Def coming back to bowl next time', 'yelp_389'),
#   ('If you want healthy authentic or ethic food, try this place.', 'yelp_390'),
#   ('I will continue to come here on ladies night andddd date night ... highly recommend this place to anyone who is in the area (;',
#    'yelp_391'),
#   ('I have been here several times in the past, and the experience has always been great.',
#    'yelp_392'),
#   ('We walked away stuffed and happy about our first Vegas buffet experience.',
#    'yelp_393'),
#   ('Service was excellent and prices are pretty reasonable considering this is Vegas and located inside the Crystals shopping mall by Aria.',
#    'yelp_394'),
#   ('To summarize... the food was incredible, nay, transcendant... but nothing brings me joy quite like the memory of the pneumatic condiment dispenser.',
#    'yelp_395'),
#   ("I'm probably one of the few people to ever go to Ians and not like it.",
#    'yelp_396'),
#   ('Kids pizza is always a hit too with lots of great side dish options for the kiddos!',
#    'yelp_397'),
#   ('Service is perfect and the family atmosphere is nice to see.', 'yelp_398'),
#   ('Cooked to perfection and the service was impeccable.', 'yelp_399'),
#   ('This one is simply a disappointment.', 'yelp_400'),
#   ('Overall, I was very disappointed with the quality of food at Bouchon.',
#    'yelp_401'),
#   ("I don't have to be an accountant to know I'm getting screwed!",
#    'yelp_402'),
#   ('Great place to eat, reminds me of the little mom and pop shops in the San Francisco Bay Area.',
#    'yelp_403'),
#   ('Today was my first taste of a Buldogis Gourmet Hot Dog and I have to tell you it was more than I ever thought possible.',
#    'yelp_404'),
#   ('Left very frustrated.', 'yelp_405'),
#   ("I'll definitely be in soon again.", 'yelp_406'),
#   ('Food was really good and I got full petty fast.', 'yelp_407'),
#   ('Service was fantastic.', 'yelp_408'),
#   ('TOTAL WASTE OF TIME.', 'yelp_409'),
#   ("I don't know what kind it is but they have the best iced tea.",
#    'yelp_410'),
#   ('Come hungry, leave happy and stuffed!', 'yelp_411'),
#   ('For service, I give them no stars.', 'yelp_412'),
#   ("I can assure you that you won't be disappointed.", 'yelp_413'),
#   ('I can take a little bad service but the food sucks.', 'yelp_414'),
#   ('Gave up trying to eat any of the crust (teeth still sore).', 'yelp_415'),
#   ('But now I was completely grossed out.', 'yelp_416'),
#   ('I really enjoyed eating here.', 'yelp_417'),
#   ('First time going but I think I will quickly become a regular.',
#    'yelp_418'),
#   ('Our server was very nice, and even though he looked a little overwhelmed with all of our needs, he stayed professional and friendly until the end.',
#    'yelp_419'),
#   ('From what my dinner companions told me...everything was very fresh with nice texture and taste.',
#    'yelp_420'),
#   ('On the ground, right next to our table was a large, smeared, been-stepped-in-and-tracked-everywhere pile of green bird poop.',
#    'yelp_421'),
#   ("Furthermore, you can't even find hours of operation on the website!",
#    'yelp_422'),
#   ("We've tried to like this place but after 10+ times I think we're done with them.",
#    'yelp_423'),
#   ('What a mistake that was!', 'yelp_424'),
#   ('No complaints!', 'yelp_425'),
#   ("This is some seriously good pizza and I'm an expert/connisseur on the topic.",
#    'yelp_426'),
#   ('Waiter was a jerk.', 'yelp_427'),
#   ('Strike 2, who wants to be rushed.', 'yelp_428'),
#   ("These are the nicest restaurant owners I've ever come across.",
#    'yelp_429'),
#   ('I never come again.', 'yelp_430'),
#   ('We loved the biscuits!!!', 'yelp_431'),
#   ('Service is quick and friendly.', 'yelp_432'),
#   ('Ordered an appetizer and took 40 minutes and then the pizza another 10 minutes.',
#    'yelp_433'),
#   ('So absolutley fantastic.', 'yelp_434'),
#   ('It was a huge awkward 1.5lb piece of cow that was 3/4ths gristle and fat.',
#    'yelp_435'),
#   ('definitely will come back here again.', 'yelp_436'),
#   ("I like Steiners because it's dark and it feels like a bar.", 'yelp_437'),
#   ('Wow very spicy but delicious.', 'yelp_438'),
#   ("If you're not familiar, check it out.", 'yelp_439'),
#   ("I'll take my business dinner dollars elsewhere.", 'yelp_440'),
#   ("I'd love to go back.", 'yelp_441'),
#   ('Anyway, this FS restaurant has a wonderful breakfast/lunch.', 'yelp_442'),
#   ('Nothing special.', 'yelp_443'),
#   ("Each day of the week they have a different deal and it's all so delicious!",
#    'yelp_444'),
#   ('Not to mention the combination of pears, almonds and bacon is a big winner!',
#    'yelp_445'),
#   ('Will not be back.', 'yelp_446'),
#   ('Sauce was tasteless.', 'yelp_447'),
#   ('The food is delicious and just spicy enough, so be sure to ask for spicier if you prefer it that way.',
#    'yelp_448'),
#   ('My ribeye steak was cooked perfectly and had great mesquite flavor.',
#    'yelp_449'),
#   ("I don't think we'll be going back anytime soon.", 'yelp_450'),
#   ('Food was so gooodd.', 'yelp_451'),
#   ('I am far from a sushi connoisseur but I can definitely tell the difference between good food and bad food and this was certainly bad food.',
#    'yelp_452'),
#   ('I was so insulted.', 'yelp_453'),
#   ('The last 3 times I had lunch here has been bad.', 'yelp_454'),
#   ('The chicken wings contained the driest chicken meat I have ever eaten.',
#    'yelp_455'),
#   ('The food was very good and I enjoyed every mouthful, an enjoyable relaxed venue for couples small family groups etc.',
#    'yelp_456'),
#   ('Nargile - I think you are great.', 'yelp_457'),
#   ('Best tater tots in the southwest.', 'yelp_458'),
#   ('We loved the place.', 'yelp_459'),
#   ('Definitely not worth the $3 I paid.', 'yelp_460'),
#   ('The vanilla ice cream was creamy and smooth while the profiterole (choux) pastry was fresh enough.',
#    'yelp_461'),
#   ('Im in AZ all the time and now have my new spot.', 'yelp_462'),
#   ('The manager was the worst.', 'yelp_463'),
#   ('The inside is really quite nice and very clean.', 'yelp_464'),
#   ('The food was outstanding and the prices were very reasonable.',
#    'yelp_465'),
#   ("I don't think I'll be running back to Carly's anytime soon for food.",
#    'yelp_466'),
#   ('This is was due to the fact that it took 20 minutes to be acknowledged, then another 35 minutes to get our food...and they kept forgetting things.',
#    'yelp_467'),
#   ('Love the margaritas, too!', 'yelp_468'),
#   ('This was my first and only Vegas buffet and it did not disappoint.',
#    'yelp_469'),
#   ('Very good, though!', 'yelp_470'),
#   ('The one down note is the ventilation could use some upgrading.',
#    'yelp_471'),
#   ('Great pork sandwich.', 'yelp_472'),
#   ("Don't waste your time here.", 'yelp_473'),
#   ('Total letdown, I would much rather just go to the Camelback Flower Shop and Cartel Coffee.',
#    'yelp_474'),
#   ("Third, the cheese on my friend's burger was cold.", 'yelp_475'),
#   ('We enjoy their pizza and brunch.', 'yelp_476'),
#   ('The steaks are all well trimmed and also perfectly cooked.', 'yelp_477'),
#   ('We had a group of 70+ when we claimed we would only have 40 and they handled us beautifully.',
#    'yelp_478'),
#   ('I LOVED it!', 'yelp_479'),
#   ("We asked for the bill to leave without eating and they didn't bring that either.",
#    'yelp_480'),
#   ("This place is a jewel in Las Vegas, and exactly what I've been hoping to find in nearly ten years living here.",
#    'yelp_481'),
#   ('Seafood was limited to boiled shrimp and crab legs but the crab legs definitely did not taste fresh.',
#    'yelp_482'),
#   ('The selection of food was not the best.', 'yelp_483'),
#   ('Delicious and I will absolutely be back!', 'yelp_484'),
#   ("This isn't a small family restaurant, this is a fine dining establishment.",
#    'yelp_485'),
#   ('They had a toro tartare with a cavier that was extraordinary and I liked the thinly sliced wagyu with white truffle.',
#    'yelp_486'),
#   ('I dont think I will be back for a very long time.', 'yelp_487'),
#   ('It was attached to a gas station, and that is rarely a good sign.',
#    'yelp_488'),
#   ('How awesome is that.', 'yelp_489'),
#   ('I will be back many times soon.', 'yelp_490'),
#   ('The menu had so much good stuff on it i could not decide!', 'yelp_491'),
#   ('Worse of all, he humiliated his worker right in front of me..Bunch of horrible name callings.',
#    'yelp_492'),
#   ('CONCLUSION: Very filling meals.', 'yelp_493'),
#   ('Their daily specials are always a hit with my group.', 'yelp_494'),
#   ('And then tragedy struck.', 'yelp_495'),
#   ('The pancake was also really good and pretty large at that.', 'yelp_496'),
#   ('This was my first crawfish experience, and it was delicious!', 'yelp_497'),
#   ('Their monster chicken fried steak and eggs is my all time favorite.',
#    'yelp_498'),
#   ('Waitress was sweet and funny.', 'yelp_499'),
#   ("I also had to taste my Mom's multi-grain pumpkin pancakes with pecan butter and they were amazing, fluffy, and delicious!",
#    'yelp_500'),
#   ("I'd rather eat airline food, seriously.", 'yelp_501'),
#   ('Cant say enough good things about this place.', 'yelp_502'),
#   ('The ambiance was incredible.', 'yelp_503'),
#   ('The waitress and manager are so friendly.', 'yelp_504'),
#   ('I would not recommend this place.', 'yelp_505'),
#   ("Overall I wasn't very impressed with Noca.", 'yelp_506'),
#   ('My gyro was basically lettuce only.', 'yelp_507'),
#   ('Terrible service!', 'yelp_508'),
#   ('Thoroughly disappointed!', 'yelp_509'),
#   ("I don't each much pasta, but I love the homemade /hand made pastas and thin pizzas here.",
#    'yelp_510'),
#   ('Give it a try, you will be happy you did.', 'yelp_511'),
#   ('By far the BEST cheesecurds we have ever had!', 'yelp_512'),
#   ('Reasonably priced also!', 'yelp_513'),
#   ('Everything was perfect the night we were in.', 'yelp_514'),
#   ('The food is very good for your typical bar food.', 'yelp_515'),
#   ('it was a drive to get there.', 'yelp_516'),
#   ('At first glance it is a lovely bakery cafe - nice ambiance, clean, friendly staff.',
#    'yelp_517'),
#   ('Anyway, I do not think i will go back there.', 'yelp_518'),
#   ("Point your finger at any item on the menu, order it and you won't be disappointed.",
#    'yelp_519'),
#   ('Oh this is such a thing of beauty, this restaurant.', 'yelp_520'),
#   ("If you haven't gone here GO NOW!", 'yelp_521'),
#   ('A greasy, unhealthy meal.', 'yelp_522'),
#   ('first time there and might just be the last.', 'yelp_523'),
#   ('Those burgers were amazing.', 'yelp_524'),
#   ('Similarly, the delivery man did not say a word of apology when our food was 45 minutes late.',
#    'yelp_525'),
#   ('And it was way to expensive.', 'yelp_526'),
#   ('Be sure to order dessert, even if you need to pack it to-go - the tiramisu and cannoli are both to die for.',
#    'yelp_527'),
#   ("This was my first time and I can't wait until the next.", 'yelp_528'),
#   ('The bartender was also nice.', 'yelp_529'),
#   ('Everything was good and tasty!', 'yelp_530'),
#   ('This place is two thumbs up....way up.', 'yelp_531'),
#   ('The best place in Vegas for breakfast (just check out a Sat, or Sun.',
#    'yelp_532'),
#   ('If you love authentic Mexican food and want a whole bunch of interesting, yet delicious meats to choose from, you need to try this place.',
#    'yelp_533'),
#   ('Terrible management.', 'yelp_534'),
#   ('An excellent new restaurant by an experienced Frenchman.', 'yelp_535'),
#   ('If there were zero stars I would give it zero stars.', 'yelp_536'),
#   ('Great steak, great sides, great wine, amazing desserts.', 'yelp_537'),
#   ('Worst martini ever!', 'yelp_538'),
#   ('The steak and the shrimp are in my opinion the best entrees at GC.',
#    'yelp_539'),
#   ('I had the opportunity today to sample your amazing pizzas!', 'yelp_540'),
#   ('We waited for thirty minutes to be seated (although there were 8 vacant tables and we were the only folks waiting).',
#    'yelp_541'),
#   ('The yellowtail carpaccio was melt in your mouth fresh.', 'yelp_542'),
#   ("I won't try going back there even if it's empty.", 'yelp_543'),
#   ("No, I'm going to eat the potato that I found some strangers hair in it.",
#    'yelp_544'),
#   ('Just spicy enough.. Perfect actually.', 'yelp_545'),
#   ('Last night was my second time dining here and I was so happy I decided to go back!',
#    'yelp_546'),
#   ('not even a "hello, we will be right with you."', 'yelp_547'),
#   ('The desserts were a bit strange.', 'yelp_548'),
#   ('My boyfriend and I came here for the first time on a recent trip to Vegas and could not have been more pleased with the quality of food and service.',
#    'yelp_549'),
#   ('I really do recommend this place, you can go wrong with this donut place!',
#    'yelp_550'),
#   ('Nice ambiance.', 'yelp_551'),
#   ('I would recommend saving room for this!', 'yelp_552'),
#   ('I guess maybe we went on an off night but it was disgraceful.',
#    'yelp_553'),
#   ('However, my recent experience at this particular location was not so good.',
#    'yelp_554'),
#   ('I know this is not like the other restaurants at all, something is very off here!',
#    'yelp_555'),
#   ('AVOID THIS ESTABLISHMENT!', 'yelp_556'),
#   ('I think this restaurant suffers from not trying hard enough.', 'yelp_557'),
#   ('All of the tapas dishes were delicious!', 'yelp_558'),
#   ('I *heart* this place.', 'yelp_559'),
#   ('My salad had a bland vinegrette on the baby greens and hearts of Palm.',
#    'yelp_560'),
#   ('After two I felt disgusting.', 'yelp_561'),
#   ('A good time!', 'yelp_562'),
#   ('I believe that this place is a great stop for those with a huge belly and hankering for sushi.',
#    'yelp_563'),
#   ('Generous portions and great taste.', 'yelp_564'),
#   ('I will never go back to this place and will never ever recommended this place to anyone!',
#    'yelp_565'),
#   ('The servers went back and forth several times, not even so much as an "Are you being helped?"',
#    'yelp_566'),
#   ('Food was delicious!', 'yelp_567'),
#   ('AN HOUR... seriously?', 'yelp_568'),
#   ('I consider this theft.', 'yelp_569'),
#   ('Eew... This location needs a complete overhaul.', 'yelp_570'),
#   ('We recently witnessed her poor quality of management towards other guests as well.',
#    'yelp_571'),
#   ('Waited and waited and waited.', 'yelp_572'),
#   ('He also came back to check on us regularly, excellent service.',
#    'yelp_573'),
#   ('Our server was super nice and checked on us many times.', 'yelp_574'),
#   ('The pizza tasted old, super chewy in not a good way.', 'yelp_575'),
#   ('I swung in to give them a try but was deeply disappointed.', 'yelp_576'),
#   ('Service was good and the company was better!', 'yelp_577'),
#   ('The staff are also very friendly and efficient.', 'yelp_578'),
#   ("As for the service: I'm a fan, because it's quick and you're being served by some nice folks.",
#    'yelp_579'),
#   ('Boy was that sucker dry!!.', 'yelp_580'),
#   ('Over rated.', 'yelp_581'),
#   ('If you look for authentic Thai food, go else where.', 'yelp_582'),
#   ('Their steaks are 100% recommended!', 'yelp_583'),
#   ('After I pulled up my car I waited for another 15 minutes before being acknowledged.',
#    'yelp_584'),
#   ('Great food and great service in a clean and friendly setting.',
#    'yelp_585'),
#   ("All in all, I can assure you I'll be back.", 'yelp_586'),
#   ('I hate those things as much as cheap quality black olives.', 'yelp_587'),
#   ('My breakfast was perpared great, with a beautiful presentation of 3 giant slices of Toast, lightly dusted with powdered sugar.',
#    'yelp_588'),
#   ('The kids play area is NASTY!', 'yelp_589'),
#   ('Great place fo take out or eat in.', 'yelp_590'),
#   ('The waitress was friendly and happy to accomodate for vegan/veggie options.',
#    'yelp_591'),
#   ('OMG I felt like I had never eaten Thai food until this dish.', 'yelp_592'),
#   ('It was extremely "crumby" and pretty tasteless.', 'yelp_593'),
#   ('It was a pale color instead of nice and char and has NO flavor.',
#    'yelp_594'),
#   ('The croutons also taste homemade which is an extra plus.', 'yelp_595'),
#   ('I got home to see the driest damn wings ever!', 'yelp_596'),
#   ("It'll be a regular stop on my trips to Phoenix!", 'yelp_597'),
#   ('I really enjoyed Crema Café before they expanded; I even told friends they had the BEST breakfast.',
#    'yelp_598'),
#   ('Not good for the money.', 'yelp_599'),
#   ('I miss it and wish they had one in Philadelphia!', 'yelp_600'),
#   ('We got sitting fairly fast, but, ended up waiting 40 minutes just to place our order, another 30 minutes before the food arrived.',
#    'yelp_601'),
#   ('They also have the best cheese crisp in town.', 'yelp_602'),
#   ('Good value, great food, great service.', 'yelp_603'),
#   ("Couldn't ask for a more satisfying meal.", 'yelp_604'),
#   ('The food is good.', 'yelp_605'),
#   ('It was awesome.', 'yelp_606'),
#   ('I just wanted to leave.', 'yelp_607'),
#   ('We made the drive all the way from North Scottsdale... and I was not one bit disappointed!',
#    'yelp_608'),
# ...
#    'yelp_807'),
#   ('Lastly, the mozzarella sticks, they were the best thing we ordered.',
#    'yelp_808'),
#   ('The first time I ever came here I had an amazing experience, I still tell people how awesome the duck was.',
#    'yelp_809'),
#   ('The server was very negligent of our needs and made us feel very unwelcome... I would not suggest this place!',
#    'yelp_810'),
#   ('The service was terrible though.', 'yelp_811'),
#   ('This place is overpriced, not consistent with their boba, and it really is OVERPRICED!',
#    'yelp_812'),
#   ('It was packed!!', 'yelp_813'),
#   ('I love this place.', 'yelp_814'),
#   ('I can say that the desserts were yummy.', 'yelp_815'),
#   ('The food was terrible.', 'yelp_816'),
#   ('The seasonal fruit was fresh white peach puree.', 'yelp_817'),
#   ("It kept getting worse and worse so now I'm officially done.", 'yelp_818'),
#   ('This place should honestly be blown up.', 'yelp_819'),
#   ('But I definitely would not eat here again.', 'yelp_820'),
#   ('Do not waste your money here!', 'yelp_821'),
#   ('I love that they put their food in nice plastic containers as opposed to cramming it in little paper takeout boxes.',
#    'yelp_822'),
#   ('The crêpe was delicate and thin and moist.', 'yelp_823'),
#   ('Awful service.', 'yelp_824'),
#   ("Won't ever go here again.", 'yelp_825'),
#   ('Food quality has been horrible.', 'yelp_826'),
#   ('For that price I can think of a few place I would have much rather gone.',
#    'yelp_827'),
#   ('The service here is fair at best.', 'yelp_828'),
#   ('I do love sushi, but I found Kabuki to be over-priced, over-hip and under-services.',
#    'yelp_829'),
#   ('Do yourself a favor and stay away from this dish.', 'yelp_830'),
#   ('Very poor service.', 'yelp_831'),
#   ('No one at the table thought the food was above average or worth the wait that we had for it.',
#    'yelp_832'),
#   ('Best service and food ever, Maria our server was so good and friendly she made our day.',
#    'yelp_833'),
#   ('They were excellent.', 'yelp_834'),
#   ('I paid the bill but did not tip because I felt the server did a terrible job.',
#    'yelp_835'),
#   ('Just had lunch here and had a great experience.', 'yelp_836'),
#   ('I have never had such bland food which surprised me considering the article we read focused so much on their spices and flavor.',
#    'yelp_837'),
#   ('Food is way overpriced and portions are fucking small.', 'yelp_838'),
#   ("I recently tried Caballero's and I have been back every week since!",
#    'yelp_839'),
#   ('for 40 bucks a head, i really expect better food.', 'yelp_840'),
#   ('The food came out at a good pace.', 'yelp_841'),
#   ('I ate there twice on my last visit, and especially enjoyed the salmon salad.',
#    'yelp_842'),
#   ("I won't be back.", 'yelp_843'),
#   ('We could not believe how dirty the oysters were!', 'yelp_844'),
#   ('This place deserves no stars.', 'yelp_845'),
#   ('I would not recommend this place.', 'yelp_846'),
#   ("In fact I'm going to round up to 4 stars, just because she was so awesome.",
#    'yelp_847'),
#   ('To my disbelief, each dish qualified as the worst version of these foods I have ever tasted.',
#    'yelp_848'),
#   ('Bad day or not, I have a very low tolerance for rude customer service people, it is your job to be nice and polite, wash dishes otherwise!!',
#    'yelp_849'),
#   ('the potatoes were great and so was the biscuit.', 'yelp_850'),
#   ('I probably would not go here again.', 'yelp_851'),
#   ('So flavorful and has just the perfect amount of heat.', 'yelp_852'),
#   ('The price is reasonable and the service is great.', 'yelp_853'),
#   ('The Wife hated her meal (coconut shrimp), and our friends really did not enjoy their meals, either.',
#    'yelp_854'),
#   ("My fella got the huevos rancheros and they didn't look too appealing.",
#    'yelp_855'),
#   ('Went in for happy hour, great list of wines.', 'yelp_856'),
#   ('Some may say this buffet is pricey but I think you get what you pay for and this place you are getting quite a lot!',
#    'yelp_857'),
#   ("I probably won't be coming back here.", 'yelp_858'),
#   ("Worst food/service I've had in a while.", 'yelp_859'),
#   ('This place is pretty good, nice little vibe in the restaurant.',
#    'yelp_860'),
#   ('Talk about great customer service of course we will be back.', 'yelp_861'),
#   ('Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil.',
#    'yelp_862'),
#   ('I love their fries and their beans.', 'yelp_863'),
#   ('Always a pleasure dealing with him.', 'yelp_864'),
#   ("They have a plethora of salads and sandwiches, and everything I've tried gets my seal of approval.",
#    'yelp_865'),
#   ('This place is awesome if you want something light and healthy during the summer.',
#    'yelp_866'),
#   ('For sushi on the Strip, this is the place to go.', 'yelp_867'),
#   ('The service was great, even the manager came and helped with our table.',
#    'yelp_868'),
#   ('The feel of the dining room was more college cooking course than high class dining and the service was slow at best.',
#    'yelp_869'),
#   ("I started this review with two stars, but I'm editing it to give it only one.",
#    'yelp_870'),
#   ("this is the worst sushi i have ever eat besides Costco's.", 'yelp_871'),
#   ('All in all an excellent restaurant highlighted by great service, a unique menu, and a beautiful setting.',
#    'yelp_872'),
#   ('My boyfriend and i sat at the bar and had a completely delightful experience.',
#    'yelp_873'),
#   ('Weird vibe from owners.', 'yelp_874'),
#   ('There was hardly any meat.', 'yelp_875'),
#   ("I've had better bagels from the grocery store.", 'yelp_876'),
#   ('Go To Place for Gyros.', 'yelp_877'),
#   ('I love the owner/chef, his one authentic Japanese cool dude!', 'yelp_878'),
#   ("Now the burgers aren't as good, the pizza which used to be amazing is doughy and flavorless.",
#    'yelp_879'),
#   ('I found a six inch long piece of wire in my salsa.', 'yelp_880'),
#   ('The service was terrible, food was mediocre.', 'yelp_881'),
#   ('We definately enjoyed ourselves.', 'yelp_882'),
#   ('I ordered Albondigas soup - which was just warm - and tasted like tomato soup with frozen meatballs.',
#    'yelp_883'),
#   ('On three different occasions I asked for well done or medium well, and all three times I got the bloodiest piece of meat on my plate.',
#    'yelp_884'),
#   ('I had about two bites and refused to eat anymore.', 'yelp_885'),
#   ('The service was extremely slow.', 'yelp_886'),
#   ('After 20 minutes wait, I got a table.', 'yelp_887'),
#   ('Seriously killer hot chai latte.', 'yelp_888'),
#   ('No allergy warnings on the menu, and the waitress had absolutely no clue as to which meals did or did not contain peanuts.',
#    'yelp_889'),
#   ('My boyfriend tried the Mediterranean Chicken Salad and fell in love.',
#    'yelp_890'),
#   ('Their rotating beers on tap is also a highlight of this place.',
#    'yelp_891'),
#   ('Pricing is a bit of a concern at Mellow Mushroom.', 'yelp_892'),
#   ('Worst Thai ever.', 'yelp_893'),
#   ('If you stay in Vegas you must get breakfast here at least once.',
#    'yelp_894'),
#   ('I want to first say our server was great and we had perfect service.',
#    'yelp_895'),
#   ('The pizza selections are good.', 'yelp_896'),
#   ('I had strawberry tea, which was good.', 'yelp_897'),
#   ('Highly unprofessional and rude to a loyal patron!', 'yelp_898'),
#   ('Overall, a great experience.', 'yelp_899'),
#   ('Spend your money elsewhere.', 'yelp_900'),
#   ('Their regular toasted bread was equally satisfying with the occasional pats of butter... Mmmm...!',
#    'yelp_901'),
#   ('The Buffet at Bellagio was far from what I anticipated.', 'yelp_902'),
#   ('And the drinks are WEAK, people!', 'yelp_903'),
#   ('-My order was not correct.', 'yelp_904'),
#   ('Also, I feel like the chips are bought, not made in house.', 'yelp_905'),
#   ('After the disappointing dinner we went elsewhere for dessert.',
#    'yelp_906'),
#   ('The chips and sals a here is amazing!!!!!!!!!!!!!!!!!!!', 'yelp_907'),
#   ("We won't be returning.", 'yelp_908'),
#   ('This is my new fav Vegas buffet spot.', 'yelp_909'),
#   ('I seriously cannot believe that the owner has so many unexperienced employees that all are running around like chickens with their heads cut off.',
#    'yelp_910'),
#   ('Very, very sad.', 'yelp_911'),
#   ('i felt insulted and disrespected, how could you talk and judge another human being like that?',
#    'yelp_912'),
#   ("How can you call yourself a steakhouse if you can't properly cook a steak, I don't understand!",
#    'yelp_913'),
#   ("I'm not impressed with the concept or the food.", 'yelp_914'),
#   ("The only thing I wasn't too crazy about was their guacamole as I don't like it puréed.",
#    'yelp_915'),
#   ('There is really nothing for me at postinos, hope your experience is better',
#    'yelp_916'),
#   ('I got food poisoning here at the buffet.', 'yelp_917'),
#   ('They brought a fresh batch of fries and I was thinking yay something warm but no!',
#    'yelp_918'),
#   ('What SHOULD have been a hilarious, yummy Christmas Eve dinner to remember was the biggest fail of the entire trip for us.',
#    'yelp_919'),
#   ("Needless to say, I won't be going back anytime soon.", 'yelp_920'),
#   ('This place is disgusting!', 'yelp_921'),
#   ('Every time I eat here, I see caring teamwork to a professional degree.',
#    'yelp_922'),
#   ('The RI style calamari was a joke.', 'yelp_923'),
#   ('However, there was so much garlic in the fondue, it was barely edible.',
#    'yelp_924'),
#   ("I could barely stomach the meal, but didn't complain because it was a business lunch.",
#    'yelp_925'),
#   ('It was so bad, I had lost the heart to finish it.', 'yelp_926'),
#   ('It also took her forever to bring us the check when we asked for it.',
#    'yelp_927'),
#   ("We aren't ones to make a scene at restaurants but I just don't get it...definitely lost the love after this one!",
#    'yelp_928'),
#   ('Disappointing experience.', 'yelp_929'),
#   ("The food is about on par with Denny's, which is to say, not good at all.",
#    'yelp_930'),
#   ('If you want to wait for mediocre food and downright terrible service, then this is the place for you.',
#    'yelp_931'),
#   ('WAAAAAAyyyyyyyyyy over rated is all I am saying.', 'yelp_932'),
#   ("We won't be going back.", 'yelp_933'),
#   ("The place was fairly clean but the food simply wasn't worth it.",
#    'yelp_934'),
#   ('This place lacked style!!', 'yelp_935'),
#   ('The sangria was about half of a glass wine full and was $12, ridiculous.',
#    'yelp_936'),
#   ("Don't bother coming here.", 'yelp_937'),
#   ('The meat was pretty dry, I had the sliced brisket and pulled pork.',
#    'yelp_938'),
#   ("The building itself seems pretty neat; the bathroom is pretty trippy, but I wouldn't eat here again.",
#    'yelp_939'),
#   ('It was equally awful.', 'yelp_940'),
#   ('Probably not in a hurry to go back.', 'yelp_941'),
#   ('very slow at seating even with reservation.', 'yelp_942'),
#   ('Not good by any stretch of the imagination.', 'yelp_943'),
#   ('The cashew cream sauce was bland and the vegetables were undercooked.',
#    'yelp_944'),
#   ('The chipolte ranch dipping sause was tasteless, seemed thin and watered down with no heat.',
#    'yelp_945'),
#   ('It was a bit too sweet, not really spicy enough, and lacked flavor.',
#    'yelp_946'),
#   ('I was VERY disappointed!!', 'yelp_947'),
#   ('This place is horrible and way overpriced.', 'yelp_948'),
#   ("Maybe it's just their Vegetarian fare, but I've been twice and I thought it was average at best.",
#    'yelp_949'),
#   ("It wasn't busy at all and now we know why.", 'yelp_950'),
#   ('The tables outside are also dirty a lot of the time and the workers are not always friendly and helpful with the menu.',
#    'yelp_951'),
#   ('The ambiance here did not feel like a buffet setting, but more of a douchey indoor garden for tea and biscuits.',
#    'yelp_952'),
#   ('Con: spotty service.', 'yelp_953'),
#   ('The fries were not hot, and neither was my burger.', 'yelp_954'),
#   ('But then they came back cold.', 'yelp_955'),
#   ('Then our food came out, disappointment ensued.', 'yelp_956'),
#   ('The real disappointment was our waiter.', 'yelp_957'),
#   ('My husband said she was very rude... did not even apologize for the bad food or anything.',
#    'yelp_958'),
#   ('The only reason to eat here would be to fill up before a night of binge drinking just to get some carbs in your stomach.',
#    'yelp_959'),
#   ('Insults, profound deuchebaggery, and had to go outside for a smoke break while serving just to solidify it.',
#    'yelp_960'),
#   ("If someone orders two tacos don't' you think it may be part of customer service to ask if it is combo or ala cart?",
#    'yelp_961'),
#   ('She was quite disappointed although some blame needs to be placed at her door.',
#    'yelp_962'),
#   ("After all the rave reviews I couldn't wait to eat here......what a disappointment!",
#    'yelp_963'),
#   ('Del Taco is pretty nasty and should be avoided if possible.', 'yelp_964'),
#   ("It's NOT hard to make a decent hamburger.", 'yelp_965'),
#   ("But I don't like it.", 'yelp_966'),
#   ('Hell no will I go back', 'yelp_967'),
#   ("We've have gotten a much better service from the pizza place next door than the services we received from this restaurant.",
#    'yelp_968'),
#   ('I don\'t know what the big deal is about this place, but I won\'t be back "ya\'all".',
#    'yelp_969'),
#   ('I immediately said I wanted to talk to the manager but I did not want to talk to the guy who was doing shots of fireball behind the bar.',
#    'yelp_970'),
#   ("The ambiance isn't much better.", 'yelp_971'),
#   ('Unfortunately, it only set us up for disapppointment with our entrees.',
#    'yelp_972'),
#   ("The food wasn't good.", 'yelp_973'),
#   ('Your servers suck, wait, correction, our server Heimer sucked.',
#    'yelp_974'),
#   ('What happened next was pretty....off putting.', 'yelp_975'),
#   ("too bad cause I know it's family owned, I really wanted to like this place.",
#    'yelp_976'),
#   ('Overpriced for what you are getting.', 'yelp_977'),
#   ('I vomited in the bathroom mid lunch.', 'yelp_978'),
#   ('I kept looking at the time and it had soon become 35 minutes, yet still no food.',
#    'yelp_979'),
#   ('I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list.',
#    'yelp_980'),
#   ("We started with the tuna sashimi which was brownish in color and obviously wasn't fresh.",
#    'yelp_981'),
#   ('Food was below average.', 'yelp_982'),
#   ('It sure does beat the nachos at the movies but I would expect a little bit more coming from a restaurant.',
#    'yelp_983'),
#   ('All in all, Ha Long Bay was a bit of a flop.', 'yelp_984'),
#   ('The problem I have is that they charge $11.99 for a sandwich that is no bigger than a Subway sub (which offers better and more amount of vegetables).',
#    'yelp_985'),
#   ('Shrimp- When I unwrapped it (I live only 1/2 a mile from Brushfire) it was literally ice cold.',
#    'yelp_986'),
#   ('It lacked flavor, seemed undercooked, and dry.', 'yelp_987'),
#   ("It really is impressive that the place hasn't closed down.", 'yelp_988'),
#   ('I would avoid this place if you are staying in the Mirage.', 'yelp_989'),
#   ('The refried beans that came with my meal were dried out and crusty and the food was bland.',
#    'yelp_990'),
#   ('Spend your money and time some place else.', 'yelp_991'),
#   ('A lady at the table next to us found a live green caterpillar In her salad.',
#    'yelp_992'),
#   ('the presentation of the food was awful.', 'yelp_993'),
#   ("I can't tell you how disappointed I was.", 'yelp_994'),
#   ('I think food should have flavor and texture and both were lacking.',
#    'yelp_995'),
#   ('Appetite instantly gone.', 'yelp_996'),
#   ('Overall I was not impressed and would not go back.', 'yelp_997'),
#   ("The whole experience was underwhelming, and I think we'll just go to Ninja Sushi next time.",
#    'yelp_998'),
#   ("Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check.",
#    'yelp_999'),
#   ...])

# %%
import re
sentences = []
sentiments = []
for fname in ["yelp", "amazon_cells", "imdb"]:
    with open("sentiment labelled sentences/%s_labelled.txt" % fname) as f:
        for item_no, line in enumerate(f):
            line_split = line.strip().split('\t')
            sent = line_split[0].lower()
            sent = re.sub(r'\'', '', sent)
            sent = re.sub(r'\W', ' ', sent)
            sent = re.sub(r'\s+', ' ', sent).strip()
            sentences.append(LabeledSentence(sent.split(), ["%s_%d" % (fname, item_no)]))
            sentiments.append(int(line_split[1]))

# %%
sentences
# Out:
# [LabeledSentence(words=['wow', 'loved', 'this', 'place'], tags=['yelp_0']),
#  LabeledSentence(words=['crust', 'is', 'not', 'good'], tags=['yelp_1']),
#  LabeledSentence(words=['not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty'], tags=['yelp_2']),
#  LabeledSentence(words=['stopped', 'by', 'during', 'the', 'late', 'may', 'bank', 'holiday', 'off', 'rick', 'steve', 'recommendation', 'and', 'loved', 'it'], tags=['yelp_3']),
#  LabeledSentence(words=['the', 'selection', 'on', 'the', 'menu', 'was', 'great', 'and', 'so', 'were', 'the', 'prices'], tags=['yelp_4']),
#  LabeledSentence(words=['now', 'i', 'am', 'getting', 'angry', 'and', 'i', 'want', 'my', 'damn', 'pho'], tags=['yelp_5']),
#  LabeledSentence(words=['honeslty', 'it', 'didnt', 'taste', 'that', 'fresh'], tags=['yelp_6']),
#  LabeledSentence(words=['the', 'potatoes', 'were', 'like', 'rubber', 'and', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer'], tags=['yelp_7']),
#  LabeledSentence(words=['the', 'fries', 'were', 'great', 'too'], tags=['yelp_8']),
#  LabeledSentence(words=['a', 'great', 'touch'], tags=['yelp_9']),
#  LabeledSentence(words=['service', 'was', 'very', 'prompt'], tags=['yelp_10']),
#  LabeledSentence(words=['would', 'not', 'go', 'back'], tags=['yelp_11']),
#  LabeledSentence(words=['the', 'cashier', 'had', 'no', 'care', 'what', 'so', 'ever', 'on', 'what', 'i', 'had', 'to', 'say', 'it', 'still', 'ended', 'up', 'being', 'wayyy', 'overpriced'], tags=['yelp_12']),
#  LabeledSentence(words=['i', 'tried', 'the', 'cape', 'cod', 'ravoli', 'chicken', 'with', 'cranberry', 'mmmm'], tags=['yelp_13']),
#  LabeledSentence(words=['i', 'was', 'disgusted', 'because', 'i', 'was', 'pretty', 'sure', 'that', 'was', 'human', 'hair'], tags=['yelp_14']),
#  LabeledSentence(words=['i', 'was', 'shocked', 'because', 'no', 'signs', 'indicate', 'cash', 'only'], tags=['yelp_15']),
#  LabeledSentence(words=['highly', 'recommended'], tags=['yelp_16']),
#  LabeledSentence(words=['waitress', 'was', 'a', 'little', 'slow', 'in', 'service'], tags=['yelp_17']),
#  LabeledSentence(words=['this', 'place', 'is', 'not', 'worth', 'your', 'time', 'let', 'alone', 'vegas'], tags=['yelp_18']),
#  LabeledSentence(words=['did', 'not', 'like', 'at', 'all'], tags=['yelp_19']),
#  LabeledSentence(words=['the', 'burrittos', 'blah'], tags=['yelp_20']),
#  LabeledSentence(words=['the', 'food', 'amazing'], tags=['yelp_21']),
#  LabeledSentence(words=['service', 'is', 'also', 'cute'], tags=['yelp_22']),
#  LabeledSentence(words=['i', 'could', 'care', 'less', 'the', 'interior', 'is', 'just', 'beautiful'], tags=['yelp_23']),
#  LabeledSentence(words=['so', 'they', 'performed'], tags=['yelp_24']),
#  LabeledSentence(words=['thats', 'right', 'the', 'red', 'velvet', 'cake', 'ohhh', 'this', 'stuff', 'is', 'so', 'good'], tags=['yelp_25']),
#  LabeledSentence(words=['they', 'never', 'brought', 'a', 'salad', 'we', 'asked', 'for'], tags=['yelp_26']),
#  LabeledSentence(words=['this', 'hole', 'in', 'the', 'wall', 'has', 'great', 'mexican', 'street', 'tacos', 'and', 'friendly', 'staff'], tags=['yelp_27']),
#  LabeledSentence(words=['took', 'an', 'hour', 'to', 'get', 'our', 'food', 'only', '4', 'tables', 'in', 'restaurant', 'my', 'food', 'was', 'luke', 'warm', 'our', 'sever', 'was', 'running', 'around', 'like', 'he', 'was', 'totally', 'overwhelmed'], tags=['yelp_28']),
#  LabeledSentence(words=['the', 'worst', 'was', 'the', 'salmon', 'sashimi'], tags=['yelp_29']),
#  LabeledSentence(words=['also', 'there', 'are', 'combos', 'like', 'a', 'burger', 'fries', 'and', 'beer', 'for', '23', 'which', 'is', 'a', 'decent', 'deal'], tags=['yelp_30']),
#  LabeledSentence(words=['this', 'was', 'like', 'the', 'final', 'blow'], tags=['yelp_31']),
#  LabeledSentence(words=['i', 'found', 'this', 'place', 'by', 'accident', 'and', 'i', 'could', 'not', 'be', 'happier'], tags=['yelp_32']),
#  LabeledSentence(words=['seems', 'like', 'a', 'good', 'quick', 'place', 'to', 'grab', 'a', 'bite', 'of', 'some', 'familiar', 'pub', 'food', 'but', 'do', 'yourself', 'a', 'favor', 'and', 'look', 'elsewhere'], tags=['yelp_33']),
#  LabeledSentence(words=['overall', 'i', 'like', 'this', 'place', 'a', 'lot'], tags=['yelp_34']),
#  LabeledSentence(words=['the', 'only', 'redeeming', 'quality', 'of', 'the', 'restaurant', 'was', 'that', 'it', 'was', 'very', 'inexpensive'], tags=['yelp_35']),
#  LabeledSentence(words=['ample', 'portions', 'and', 'good', 'prices'], tags=['yelp_36']),
#  LabeledSentence(words=['poor', 'service', 'the', 'waiter', 'made', 'me', 'feel', 'like', 'i', 'was', 'stupid', 'every', 'time', 'he', 'came', 'to', 'the', 'table'], tags=['yelp_37']),
#  LabeledSentence(words=['my', 'first', 'visit', 'to', 'hiro', 'was', 'a', 'delight'], tags=['yelp_38']),
#  LabeledSentence(words=['service', 'sucks'], tags=['yelp_39']),
#  LabeledSentence(words=['the', 'shrimp', 'tender', 'and', 'moist'], tags=['yelp_40']),
#  LabeledSentence(words=['there', 'is', 'not', 'a', 'deal', 'good', 'enough', 'that', 'would', 'drag', 'me', 'into', 'that', 'establishment', 'again'], tags=['yelp_41']),
#  LabeledSentence(words=['hard', 'to', 'judge', 'whether', 'these', 'sides', 'were', 'good', 'because', 'we', 'were', 'grossed', 'out', 'by', 'the', 'melted', 'styrofoam', 'and', 'didnt', 'want', 'to', 'eat', 'it', 'for', 'fear', 'of', 'getting', 'sick'], tags=['yelp_42']),
#  LabeledSentence(words=['on', 'a', 'positive', 'note', 'our', 'server', 'was', 'very', 'attentive', 'and', 'provided', 'great', 'service'], tags=['yelp_43']),
#  LabeledSentence(words=['frozen', 'pucks', 'of', 'disgust', 'with', 'some', 'of', 'the', 'worst', 'people', 'behind', 'the', 'register'], tags=['yelp_44']),
#  LabeledSentence(words=['the', 'only', 'thing', 'i', 'did', 'like', 'was', 'the', 'prime', 'rib', 'and', 'dessert', 'section'], tags=['yelp_45']),
#  LabeledSentence(words=['its', 'too', 'bad', 'the', 'food', 'is', 'so', 'damn', 'generic'], tags=['yelp_46']),
#  LabeledSentence(words=['the', 'burger', 'is', 'good', 'beef', 'cooked', 'just', 'right'], tags=['yelp_47']),
#  LabeledSentence(words=['if', 'you', 'want', 'a', 'sandwich', 'just', 'go', 'to', 'any', 'firehouse'], tags=['yelp_48']),
#  LabeledSentence(words=['my', 'side', 'greek', 'salad', 'with', 'the', 'greek', 'dressing', 'was', 'so', 'tasty', 'and', 'the', 'pita', 'and', 'hummus', 'was', 'very', 'refreshing'], tags=['yelp_49']),
#  LabeledSentence(words=['we', 'ordered', 'the', 'duck', 'rare', 'and', 'it', 'was', 'pink', 'and', 'tender', 'on', 'the', 'inside', 'with', 'a', 'nice', 'char', 'on', 'the', 'outside'], tags=['yelp_50']),
#  LabeledSentence(words=['he', 'came', 'running', 'after', 'us', 'when', 'he', 'realized', 'my', 'husband', 'had', 'left', 'his', 'sunglasses', 'on', 'the', 'table'], tags=['yelp_51']),
#  LabeledSentence(words=['their', 'chow', 'mein', 'is', 'so', 'good'], tags=['yelp_52']),
#  LabeledSentence(words=['they', 'have', 'horrible', 'attitudes', 'towards', 'customers', 'and', 'talk', 'down', 'to', 'each', 'one', 'when', 'customers', 'dont', 'enjoy', 'their', 'food'], tags=['yelp_53']),
#  LabeledSentence(words=['the', 'portion', 'was', 'huge'], tags=['yelp_54']),
#  LabeledSentence(words=['loved', 'it', 'friendly', 'servers', 'great', 'food', 'wonderful', 'and', 'imaginative', 'menu'], tags=['yelp_55']),
#  LabeledSentence(words=['the', 'heart', 'attack', 'grill', 'in', 'downtown', 'vegas', 'is', 'an', 'absolutely', 'flat', 'lined', 'excuse', 'for', 'a', 'restaurant'], tags=['yelp_56']),
#  LabeledSentence(words=['not', 'much', 'seafood', 'and', 'like', '5', 'strings', 'of', 'pasta', 'at', 'the', 'bottom'], tags=['yelp_57']),
#  LabeledSentence(words=['the', 'salad', 'had', 'just', 'the', 'right', 'amount', 'of', 'sauce', 'to', 'not', 'over', 'power', 'the', 'scallop', 'which', 'was', 'perfectly', 'cooked'], tags=['yelp_58']),
#  LabeledSentence(words=['the', 'ripped', 'banana', 'was', 'not', 'only', 'ripped', 'but', 'petrified', 'and', 'tasteless'], tags=['yelp_59']),
#  LabeledSentence(words=['at', 'least', 'think', 'to', 'refill', 'my', 'water', 'before', 'i', 'struggle', 'to', 'wave', 'you', 'over', 'for', '10', 'minutes'], tags=['yelp_60']),
#  LabeledSentence(words=['this', 'place', 'receives', 'stars', 'for', 'their', 'appetizers'], tags=['yelp_61']),
#  LabeledSentence(words=['the', 'cocktails', 'are', 'all', 'handmade', 'and', 'delicious'], tags=['yelp_62']),
#  LabeledSentence(words=['wed', 'definitely', 'go', 'back', 'here', 'again'], tags=['yelp_63']),
#  LabeledSentence(words=['we', 'are', 'so', 'glad', 'we', 'found', 'this', 'place'], tags=['yelp_64']),
#  LabeledSentence(words=['great', 'food', 'and', 'service', 'huge', 'portions', 'and', 'they', 'give', 'a', 'military', 'discount'], tags=['yelp_65']),
#  LabeledSentence(words=['always', 'a', 'great', 'time', 'at', 'dos', 'gringos'], tags=['yelp_66']),
#  LabeledSentence(words=['update', 'went', 'back', 'for', 'a', 'second', 'time', 'and', 'it', 'was', 'still', 'just', 'as', 'amazing'], tags=['yelp_67']),
#  LabeledSentence(words=['we', 'got', 'the', 'food', 'and', 'apparently', 'they', 'have', 'never', 'heard', 'of', 'salt', 'and', 'the', 'batter', 'on', 'the', 'fish', 'was', 'chewy'], tags=['yelp_68']),
#  LabeledSentence(words=['a', 'great', 'way', 'to', 'finish', 'a', 'great'], tags=['yelp_69']),
#  LabeledSentence(words=['the', 'deal', 'included', '5', 'tastings', 'and', '2', 'drinks', 'and', 'jeff', 'went', 'above', 'and', 'beyond', 'what', 'we', 'expected'], tags=['yelp_70']),
#  LabeledSentence(words=['really', 'really', 'good', 'rice', 'all', 'the', 'time'], tags=['yelp_71']),
#  LabeledSentence(words=['the', 'service', 'was', 'meh'], tags=['yelp_72']),
#  LabeledSentence(words=['it', 'took', 'over', '30', 'min', 'to', 'get', 'their', 'milkshake', 'which', 'was', 'nothing', 'more', 'than', 'chocolate', 'milk'], tags=['yelp_73']),
#  LabeledSentence(words=['i', 'guess', 'i', 'should', 'have', 'known', 'that', 'this', 'place', 'would', 'suck', 'because', 'it', 'is', 'inside', 'of', 'the', 'excalibur', 'but', 'i', 'didnt', 'use', 'my', 'common', 'sense'], tags=['yelp_74']),
#  LabeledSentence(words=['the', 'scallop', 'dish', 'is', 'quite', 'appalling', 'for', 'value', 'as', 'well'], tags=['yelp_75']),
#  LabeledSentence(words=['2', 'times', 'very', 'bad', 'customer', 'service'], tags=['yelp_76']),
#  LabeledSentence(words=['the', 'sweet', 'potato', 'fries', 'were', 'very', 'good', 'and', 'seasoned', 'well'], tags=['yelp_77']),
#  LabeledSentence(words=['today', 'is', 'the', 'second', 'time', 'ive', 'been', 'to', 'their', 'lunch', 'buffet', 'and', 'it', 'was', 'pretty', 'good'], tags=['yelp_78']),
#  LabeledSentence(words=['there', 'is', 'so', 'much', 'good', 'food', 'in', 'vegas', 'that', 'i', 'feel', 'cheated', 'for', 'wasting', 'an', 'eating', 'opportunity', 'by', 'going', 'to', 'rice', 'and', 'company'], tags=['yelp_79']),
#  LabeledSentence(words=['coming', 'here', 'is', 'like', 'experiencing', 'an', 'underwhelming', 'relationship', 'where', 'both', 'parties', 'cant', 'wait', 'for', 'the', 'other', 'person', 'to', 'ask', 'to', 'break', 'up'], tags=['yelp_80']),
#  LabeledSentence(words=['walked', 'in', 'and', 'the', 'place', 'smelled', 'like', 'an', 'old', 'grease', 'trap', 'and', 'only', '2', 'others', 'there', 'eating'], tags=['yelp_81']),
#  LabeledSentence(words=['the', 'turkey', 'and', 'roast', 'beef', 'were', 'bland'], tags=['yelp_82']),
#  LabeledSentence(words=['this', 'place', 'has', 'it'], tags=['yelp_83']),
#  LabeledSentence(words=['the', 'pan', 'cakes', 'everyone', 'are', 'raving', 'about', 'taste', 'like', 'a', 'sugary', 'disaster', 'tailored', 'to', 'the', 'palate', 'of', 'a', 'six', 'year', 'old'], tags=['yelp_84']),
#  LabeledSentence(words=['i', 'love', 'the', 'pho', 'and', 'the', 'spring', 'rolls', 'oh', 'so', 'yummy', 'you', 'have', 'to', 'try'], tags=['yelp_85']),
#  LabeledSentence(words=['the', 'poor', 'batter', 'to', 'meat', 'ratio', 'made', 'the', 'chicken', 'tenders', 'very', 'unsatisfying'], tags=['yelp_86']),
#  LabeledSentence(words=['all', 'i', 'have', 'to', 'say', 'is', 'the', 'food', 'was', 'amazing'], tags=['yelp_87']),
#  LabeledSentence(words=['omelets', 'are', 'to', 'die', 'for'], tags=['yelp_88']),
#  LabeledSentence(words=['everything', 'was', 'fresh', 'and', 'delicious'], tags=['yelp_89']),
#  LabeledSentence(words=['in', 'summary', 'this', 'was', 'a', 'largely', 'disappointing', 'dining', 'experience'], tags=['yelp_90']),
#  LabeledSentence(words=['its', 'like', 'a', 'really', 'sexy', 'party', 'in', 'your', 'mouth', 'where', 'youre', 'outrageously', 'flirting', 'with', 'the', 'hottest', 'person', 'at', 'the', 'party'], tags=['yelp_91']),
#  LabeledSentence(words=['never', 'been', 'to', 'hard', 'rock', 'casino', 'before', 'will', 'never', 'ever', 'step', 'forward', 'in', 'it', 'again'], tags=['yelp_92']),
#  LabeledSentence(words=['best', 'breakfast', 'buffet'], tags=['yelp_93']),
#  LabeledSentence(words=['say', 'bye', 'bye', 'to', 'your', 'tip', 'lady'], tags=['yelp_94']),
#  LabeledSentence(words=['well', 'never', 'go', 'again'], tags=['yelp_95']),
#  LabeledSentence(words=['will', 'be', 'back', 'again'], tags=['yelp_96']),
#  LabeledSentence(words=['food', 'arrived', 'quickly'], tags=['yelp_97']),
#  LabeledSentence(words=['it', 'was', 'not', 'good'], tags=['yelp_98']),
#  LabeledSentence(words=['on', 'the', 'up', 'side', 'their', 'cafe', 'serves', 'really', 'good', 'food'], tags=['yelp_99']),
#  LabeledSentence(words=['our', 'server', 'was', 'fantastic', 'and', 'when', 'he', 'found', 'out', 'the', 'wife', 'loves', 'roasted', 'garlic', 'and', 'bone', 'marrow', 'he', 'added', 'extra', 'to', 'our', 'meal', 'and', 'another', 'marrow', 'to', 'go'], tags=['yelp_100']),
#  LabeledSentence(words=['the', 'only', 'good', 'thing', 'was', 'our', 'waiter', 'he', 'was', 'very', 'helpful', 'and', 'kept', 'the', 'bloddy', 'marys', 'coming'], tags=['yelp_101']),
#  LabeledSentence(words=['best', 'buffet', 'in', 'town', 'for', 'the', 'price', 'you', 'cannot', 'beat', 'it'], tags=['yelp_102']),
#  LabeledSentence(words=['i', 'loved', 'their', 'mussels', 'cooked', 'in', 'this', 'wine', 'reduction', 'the', 'duck', 'was', 'tender', 'and', 'their', 'potato', 'dishes', 'were', 'delicious'], tags=['yelp_103']),
#  LabeledSentence(words=['this', 'is', 'one', 'of', 'the', 'better', 'buffets', 'that', 'i', 'have', 'been', 'to'], tags=['yelp_104']),
#  LabeledSentence(words=['so', 'we', 'went', 'to', 'tigerlilly', 'and', 'had', 'a', 'fantastic', 'afternoon'], tags=['yelp_105']),
#  LabeledSentence(words=['the', 'food', 'was', 'delicious', 'our', 'bartender', 'was', 'attentive', 'and', 'personable', 'and', 'we', 'got', 'a', 'great', 'deal'], tags=['yelp_106']),
#  LabeledSentence(words=['the', 'ambience', 'is', 'wonderful', 'and', 'there', 'is', 'music', 'playing'], tags=['yelp_107']),
#  LabeledSentence(words=['will', 'go', 'back', 'next', 'trip', 'out'], tags=['yelp_108']),
#  LabeledSentence(words=['sooooo', 'good'], tags=['yelp_109']),
#  LabeledSentence(words=['real', 'sushi', 'lovers', 'lets', 'be', 'honest', 'yama', 'is', 'not', 'that', 'good'], tags=['yelp_110']),
#  LabeledSentence(words=['at', 'least', '40min', 'passed', 'in', 'between', 'us', 'ordering', 'and', 'the', 'food', 'arriving', 'and', 'it', 'wasnt', 'that', 'busy'], tags=['yelp_111']),
#  LabeledSentence(words=['this', 'is', 'a', 'really', 'fantastic', 'thai', 'restaurant', 'which', 'is', 'definitely', 'worth', 'a', 'visit'], tags=['yelp_112']),
#  LabeledSentence(words=['nice', 'spicy', 'and', 'tender'], tags=['yelp_113']),
#  LabeledSentence(words=['good', 'prices'], tags=['yelp_114']),
#  LabeledSentence(words=['check', 'it', 'out'], tags=['yelp_115']),
#  LabeledSentence(words=['it', 'was', 'pretty', 'gross'], tags=['yelp_116']),
#  LabeledSentence(words=['ive', 'had', 'better', 'atmosphere'], tags=['yelp_117']),
#  LabeledSentence(words=['kind', 'of', 'hard', 'to', 'mess', 'up', 'a', 'steak', 'but', 'they', 'did'], tags=['yelp_118']),
#  LabeledSentence(words=['although', 'i', 'very', 'much', 'liked', 'the', 'look', 'and', 'sound', 'of', 'this', 'place', 'the', 'actual', 'experience', 'was', 'a', 'bit', 'disappointing'], tags=['yelp_119']),
#  LabeledSentence(words=['i', 'just', 'dont', 'know', 'how', 'this', 'place', 'managed', 'to', 'served', 'the', 'blandest', 'food', 'i', 'have', 'ever', 'eaten', 'when', 'they', 'are', 'preparing', 'indian', 'cuisine'], tags=['yelp_120']),
#  LabeledSentence(words=['worst', 'service', 'to', 'boot', 'but', 'that', 'is', 'the', 'least', 'of', 'their', 'worries'], tags=['yelp_121']),
#  LabeledSentence(words=['service', 'was', 'fine', 'and', 'the', 'waitress', 'was', 'friendly'], tags=['yelp_122']),
#  LabeledSentence(words=['the', 'guys', 'all', 'had', 'steaks', 'and', 'our', 'steak', 'loving', 'son', 'who', 'has', 'had', 'steak', 'at', 'the', 'best', 'and', 'worst', 'places', 'said', 'it', 'was', 'the', 'best', 'steak', 'hes', 'ever', 'eaten'], tags=['yelp_123']),
#  LabeledSentence(words=['we', 'thought', 'youd', 'have', 'to', 'venture', 'further', 'away', 'to', 'get', 'good', 'sushi', 'but', 'this', 'place', 'really', 'hit', 'the', 'spot', 'that', 'night'], tags=['yelp_124']),
#  LabeledSentence(words=['host', 'staff', 'were', 'for', 'lack', 'of', 'a', 'better', 'word', 'bitches'], tags=['yelp_125']),
#  LabeledSentence(words=['bland', 'not', 'a', 'liking', 'this', 'place', 'for', 'a', 'number', 'of', 'reasons', 'and', 'i', 'dont', 'want', 'to', 'waste', 'time', 'on', 'bad', 'reviewing', 'ill', 'leave', 'it', 'at', 'that'], tags=['yelp_126']),
#  LabeledSentence(words=['phenomenal', 'food', 'service', 'and', 'ambiance'], tags=['yelp_127']),
#  LabeledSentence(words=['i', 'wouldnt', 'return'], tags=['yelp_128']),
#  LabeledSentence(words=['definitely', 'worth', 'venturing', 'off', 'the', 'strip', 'for', 'the', 'pork', 'belly', 'will', 'return', 'next', 'time', 'im', 'in', 'vegas'], tags=['yelp_129']),
#  LabeledSentence(words=['this', 'place', 'is', 'way', 'too', 'overpriced', 'for', 'mediocre', 'food'], tags=['yelp_130']),
#  LabeledSentence(words=['penne', 'vodka', 'excellent'], tags=['yelp_131']),
#  LabeledSentence(words=['they', 'have', 'a', 'good', 'selection', 'of', 'food', 'including', 'a', 'massive', 'meatloaf', 'sandwich', 'a', 'crispy', 'chicken', 'wrap', 'a', 'delish', 'tuna', 'melt', 'and', 'some', 'tasty', 'burgers'], tags=['yelp_132']),
#  LabeledSentence(words=['the', 'management', 'is', 'rude'], tags=['yelp_133']),
#  LabeledSentence(words=['delicious', 'nyc', 'bagels', 'good', 'selections', 'of', 'cream', 'cheese', 'real', 'lox', 'with', 'capers', 'even'], tags=['yelp_134']),
#  LabeledSentence(words=['great', 'subway', 'in', 'fact', 'its', 'so', 'good', 'when', 'you', 'come', 'here', 'every', 'other', 'subway', 'will', 'not', 'meet', 'your', 'expectations'], tags=['yelp_135']),
#  LabeledSentence(words=['i', 'had', 'a', 'seriously', 'solid', 'breakfast', 'here'], tags=['yelp_136']),
#  LabeledSentence(words=['this', 'is', 'one', 'of', 'the', 'best', 'bars', 'with', 'food', 'in', 'vegas'], tags=['yelp_137']),
#  LabeledSentence(words=['he', 'was', 'extremely', 'rude', 'and', 'really', 'there', 'are', 'so', 'many', 'other', 'restaurants', 'i', 'would', 'love', 'to', 'dine', 'at', 'during', 'a', 'weekend', 'in', 'vegas'], tags=['yelp_138']),
#  LabeledSentence(words=['my', 'drink', 'was', 'never', 'empty', 'and', 'he', 'made', 'some', 'really', 'great', 'menu', 'suggestions'], tags=['yelp_139']),
#  LabeledSentence(words=['dont', 'do', 'it'], tags=['yelp_140']),
#  LabeledSentence(words=['the', 'waiter', 'wasnt', 'helpful', 'or', 'friendly', 'and', 'rarely', 'checked', 'on', 'us'], tags=['yelp_141']),
#  LabeledSentence(words=['my', 'husband', 'and', 'i', 'ate', 'lunch', 'here', 'and', 'were', 'very', 'disappointed', 'with', 'the', 'food', 'and', 'service'], tags=['yelp_142']),
#  LabeledSentence(words=['and', 'the', 'red', 'curry', 'had', 'so', 'much', 'bamboo', 'shoots', 'and', 'wasnt', 'very', 'tasty', 'to', 'me'], tags=['yelp_143']),
#  LabeledSentence(words=['nice', 'blanket', 'of', 'moz', 'over', 'top', 'but', 'i', 'feel', 'like', 'this', 'was', 'done', 'to', 'cover', 'up', 'the', 'subpar', 'food'], tags=['yelp_144']),
#  LabeledSentence(words=['the', 'bathrooms', 'are', 'clean', 'and', 'the', 'place', 'itself', 'is', 'well', 'decorated'], tags=['yelp_145']),
#  LabeledSentence(words=['the', 'menu', 'is', 'always', 'changing', 'food', 'quality', 'is', 'going', 'down', 'service', 'is', 'extremely', 'slow'], tags=['yelp_146']),
#  LabeledSentence(words=['the', 'service', 'was', 'a', 'little', 'slow', 'considering', 'that', 'were', 'served', 'by', '3', 'people', 'servers', 'so', 'the', 'food', 'was', 'coming', 'in', 'a', 'slow', 'pace'], tags=['yelp_147']),
#  LabeledSentence(words=['i', 'give', 'it', '2', 'thumbs', 'down'], tags=['yelp_148']),
#  LabeledSentence(words=['we', 'watched', 'our', 'waiter', 'pay', 'a', 'lot', 'more', 'attention', 'to', 'other', 'tables', 'and', 'ignore', 'us'], tags=['yelp_149']),
#  LabeledSentence(words=['my', 'fiancé', 'and', 'i', 'came', 'in', 'the', 'middle', 'of', 'the', 'day', 'and', 'we', 'were', 'greeted', 'and', 'seated', 'right', 'away'], tags=['yelp_150']),
#  LabeledSentence(words=['this', 'is', 'a', 'great', 'restaurant', 'at', 'the', 'mandalay', 'bay'], tags=['yelp_151']),
#  LabeledSentence(words=['we', 'waited', 'for', 'forty', 'five', 'minutes', 'in', 'vain'], tags=['yelp_152']),
#  LabeledSentence(words=['crostini', 'that', 'came', 'with', 'the', 'salad', 'was', 'stale'], tags=['yelp_153']),
#  LabeledSentence(words=['some', 'highlights', 'great', 'quality', 'nigiri', 'here'], tags=['yelp_154']),
#  LabeledSentence(words=['the', 'staff', 'is', 'friendly', 'and', 'the', 'joint', 'is', 'always', 'clean'], tags=['yelp_155']),
#  LabeledSentence(words=['this', 'was', 'a', 'different', 'cut', 'than', 'the', 'piece', 'the', 'other', 'day', 'but', 'still', 'wonderful', 'and', 'tender', 's', 'well', 'as', 'well', 'flavored'], tags=['yelp_156']),
#  LabeledSentence(words=['i', 'ordered', 'the', 'voodoo', 'pasta', 'and', 'it', 'was', 'the', 'first', 'time', 'id', 'had', 'really', 'excellent', 'pasta', 'since', 'going', 'gluten', 'free', 'several', 'years', 'ago'], tags=['yelp_157']),
#  LabeledSentence(words=['this', 'place', 'is', 'good'], tags=['yelp_158']),
#  LabeledSentence(words=['unfortunately', 'we', 'must', 'have', 'hit', 'the', 'bakery', 'on', 'leftover', 'day', 'because', 'everything', 'we', 'ordered', 'was', 'stale'], tags=['yelp_159']),
#  LabeledSentence(words=['i', 'came', 'back', 'today', 'since', 'they', 'relocated', 'and', 'still', 'not', 'impressed'], tags=['yelp_160']),
#  LabeledSentence(words=['i', 'was', 'seated', 'immediately'], tags=['yelp_161']),
#  LabeledSentence(words=['their', 'menu', 'is', 'diverse', 'and', 'reasonably', 'priced'], tags=['yelp_162']),
#  LabeledSentence(words=['avoid', 'at', 'all', 'cost'], tags=['yelp_163']),
#  LabeledSentence(words=['restaurant', 'is', 'always', 'full', 'but', 'never', 'a', 'wait'], tags=['yelp_164']),
#  LabeledSentence(words=['delicious'], tags=['yelp_165']),
#  LabeledSentence(words=['this', 'place', 'is', 'hands', 'down', 'one', 'of', 'the', 'best', 'places', 'to', 'eat', 'in', 'the', 'phoenix', 'metro', 'area'], tags=['yelp_166']),
#  LabeledSentence(words=['so', 'dont', 'go', 'there', 'if', 'you', 'are', 'looking', 'for', 'good', 'food'], tags=['yelp_167']),
#  LabeledSentence(words=['ive', 'never', 'been', 'treated', 'so', 'bad'], tags=['yelp_168']),
#  LabeledSentence(words=['bacon', 'is', 'hella', 'salty'], tags=['yelp_169']),
#  LabeledSentence(words=['we', 'also', 'ordered', 'the', 'spinach', 'and', 'avocado', 'salad', 'the', 'ingredients', 'were', 'sad', 'and', 'the', 'dressing', 'literally', 'had', 'zero', 'taste'], tags=['yelp_170']),
#  LabeledSentence(words=['this', 'really', 'is', 'how', 'vegas', 'fine', 'dining', 'used', 'to', 'be', 'right', 'down', 'to', 'the', 'menus', 'handed', 'to', 'the', 'ladies', 'that', 'have', 'no', 'prices', 'listed'], tags=['yelp_171']),
#  LabeledSentence(words=['the', 'waitresses', 'are', 'very', 'friendly'], tags=['yelp_172']),
#  LabeledSentence(words=['lordy', 'the', 'khao', 'soi', 'is', 'a', 'dish', 'that', 'is', 'not', 'to', 'be', 'missed', 'for', 'curry', 'lovers'], tags=['yelp_173']),
#  LabeledSentence(words=['everything', 'on', 'the', 'menu', 'is', 'terrific', 'and', 'we', 'were', 'also', 'thrilled', 'that', 'they', 'made', 'amazing', 'accommodations', 'for', 'our', 'vegetarian', 'daughter'], tags=['yelp_174']),
#  LabeledSentence(words=['perhaps', 'i', 'caught', 'them', 'on', 'an', 'off', 'night', 'judging', 'by', 'the', 'other', 'reviews', 'but', 'im', 'not', 'inspired', 'to', 'go', 'back'], tags=['yelp_175']),
#  LabeledSentence(words=['the', 'service', 'here', 'leaves', 'a', 'lot', 'to', 'be', 'desired'], tags=['yelp_176']),
#  LabeledSentence(words=['the', 'atmosphere', 'is', 'modern', 'and', 'hip', 'while', 'maintaining', 'a', 'touch', 'of', 'coziness'], tags=['yelp_177']),
#  LabeledSentence(words=['not', 'a', 'weekly', 'haunt', 'but', 'definitely', 'a', 'place', 'to', 'come', 'back', 'to', 'every', 'once', 'in', 'a', 'while'], tags=['yelp_178']),
#  LabeledSentence(words=['we', 'literally', 'sat', 'there', 'for', '20', 'minutes', 'with', 'no', 'one', 'asking', 'to', 'take', 'our', 'order'], tags=['yelp_179']),
#  LabeledSentence(words=['the', 'burger', 'had', 'absolutely', 'no', 'flavor', 'the', 'meat', 'itself', 'was', 'totally', 'bland', 'the', 'burger', 'was', 'overcooked', 'and', 'there', 'was', 'no', 'charcoal', 'flavor'], tags=['yelp_180']),
#  LabeledSentence(words=['i', 'also', 'decided', 'not', 'to', 'send', 'it', 'back', 'because', 'our', 'waitress', 'looked', 'like', 'she', 'was', 'on', 'the', 'verge', 'of', 'having', 'a', 'heart', 'attack'], tags=['yelp_181']),
#  LabeledSentence(words=['i', 'dressed', 'up', 'to', 'be', 'treated', 'so', 'rudely'], tags=['yelp_182']),
#  LabeledSentence(words=['it', 'was', 'probably', 'dirt'], tags=['yelp_183']),
#  LabeledSentence(words=['love', 'this', 'place', 'hits', 'the', 'spot', 'when', 'i', 'want', 'something', 'healthy', 'but', 'not', 'lacking', 'in', 'quantity', 'or', 'flavor'], tags=['yelp_184']),
#  LabeledSentence(words=['i', 'ordered', 'the', 'lemon', 'raspberry', 'ice', 'cocktail', 'which', 'was', 'also', 'incredible'], tags=['yelp_185']),
#  LabeledSentence(words=['the', 'food', 'sucked', 'which', 'we', 'expected', 'but', 'it', 'sucked', 'more', 'than', 'we', 'could', 'have', 'imagined'], tags=['yelp_186']),
#  LabeledSentence(words=['interesting', 'decor'], tags=['yelp_187']),
#  LabeledSentence(words=['what', 'i', 'really', 'like', 'there', 'is', 'the', 'crepe', 'station'], tags=['yelp_188']),
#  LabeledSentence(words=['also', 'were', 'served', 'hot', 'bread', 'and', 'butter', 'and', 'home', 'made', 'potato', 'chips', 'with', 'bacon', 'bits', 'on', 'top', 'very', 'original', 'and', 'very', 'good'], tags=['yelp_189']),
#  LabeledSentence(words=['you', 'can', 'watch', 'them', 'preparing', 'the', 'delicious', 'food'], tags=['yelp_190']),
#  LabeledSentence(words=['both', 'of', 'the', 'egg', 'rolls', 'were', 'fantastic'], tags=['yelp_191']),
#  LabeledSentence(words=['when', 'my', 'order', 'arrived', 'one', 'of', 'the', 'gyros', 'was', 'missing'], tags=['yelp_192']),
#  LabeledSentence(words=['i', 'had', 'a', 'salad', 'with', 'the', 'wings', 'and', 'some', 'ice', 'cream', 'for', 'dessert', 'and', 'left', 'feeling', 'quite', 'satisfied'], tags=['yelp_193']),
#  LabeledSentence(words=['im', 'not', 'really', 'sure', 'how', 'joeys', 'was', 'voted', 'best', 'hot', 'dog', 'in', 'the', 'valley', 'by', 'readers', 'of', 'phoenix', 'magazine'], tags=['yelp_194']),
#  LabeledSentence(words=['the', 'best', 'place', 'to', 'go', 'for', 'a', 'tasty', 'bowl', 'of', 'pho'], tags=['yelp_195']),
#  LabeledSentence(words=['the', 'live', 'music', 'on', 'fridays', 'totally', 'blows'], tags=['yelp_196']),
#  LabeledSentence(words=['ive', 'never', 'been', 'more', 'insulted', 'or', 'felt', 'disrespected'], tags=['yelp_197']),
#  LabeledSentence(words=['very', 'friendly', 'staff'], tags=['yelp_198']),
#  LabeledSentence(words=['it', 'is', 'worth', 'the', 'drive'], tags=['yelp_199']),
#  LabeledSentence(words=['i', 'had', 'heard', 'good', 'things', 'about', 'this', 'place', 'but', 'it', 'exceeding', 'every', 'hope', 'i', 'could', 'have', 'dreamed', 'of'], tags=['yelp_200']),
#  LabeledSentence(words=['food', 'was', 'great', 'and', 'so', 'was', 'the', 'serivce'], tags=['yelp_201']),
#  LabeledSentence(words=['the', 'warm', 'beer', 'didnt', 'help'], tags=['yelp_202']),
#  LabeledSentence(words=['great', 'brunch', 'spot'], tags=['yelp_203']),
#  LabeledSentence(words=['service', 'is', 'friendly', 'and', 'inviting'], tags=['yelp_204']),
#  LabeledSentence(words=['very', 'good', 'lunch', 'spot'], tags=['yelp_205']),
#  LabeledSentence(words=['ive', 'lived', 'here', 'since', '1979', 'and', 'this', 'was', 'the', 'first', 'and', 'last', 'time', 'ive', 'stepped', 'foot', 'into', 'this', 'place'], tags=['yelp_206']),
#  LabeledSentence(words=['the', 'worst', 'experience', 'ever'], tags=['yelp_207']),
#  LabeledSentence(words=['must', 'have', 'been', 'an', 'off', 'night', 'at', 'this', 'place'], tags=['yelp_208']),
#  LabeledSentence(words=['the', 'sides', 'are', 'delish', 'mixed', 'mushrooms', 'yukon', 'gold', 'puree', 'white', 'corn', 'beateous'], tags=['yelp_209']),
#  LabeledSentence(words=['if', 'that', 'bug', 'never', 'showed', 'up', 'i', 'would', 'have', 'given', 'a', '4', 'for', 'sure', 'but', 'on', 'the', 'other', 'side', 'of', 'the', 'wall', 'where', 'this', 'bug', 'was', 'climbing', 'was', 'the', 'kitchen'], tags=['yelp_210']),
#  LabeledSentence(words=['for', 'about', '10', 'minutes', 'we', 'were', 'waiting', 'for', 'her', 'salad', 'when', 'we', 'realized', 'that', 'it', 'wasnt', 'coming', 'any', 'time', 'soon'], tags=['yelp_211']),
#  LabeledSentence(words=['my', 'friend', 'loved', 'the', 'salmon', 'tartar'], tags=['yelp_212']),
#  LabeledSentence(words=['wont', 'go', 'back'], tags=['yelp_213']),
#  LabeledSentence(words=['extremely', 'tasty'], tags=['yelp_214']),
#  LabeledSentence(words=['waitress', 'was', 'good', 'though'], tags=['yelp_215']),
#  LabeledSentence(words=['soggy', 'and', 'not', 'good'], tags=['yelp_216']),
#  LabeledSentence(words=['the', 'jamaican', 'mojitos', 'are', 'delicious'], tags=['yelp_217']),
#  LabeledSentence(words=['which', 'are', 'small', 'and', 'not', 'worth', 'the', 'price'], tags=['yelp_218']),
#  LabeledSentence(words=['the', 'food', 'is', 'rich', 'so', 'order', 'accordingly'], tags=['yelp_219']),
#  LabeledSentence(words=['the', 'shower', 'area', 'is', 'outside', 'so', 'you', 'can', 'only', 'rinse', 'not', 'take', 'a', 'full', 'shower', 'unless', 'you', 'dont', 'mind', 'being', 'nude', 'for', 'everyone', 'to', 'see'], tags=['yelp_220']),
#  LabeledSentence(words=['the', 'service', 'was', 'a', 'bit', 'lacking'], tags=['yelp_221']),
#  LabeledSentence(words=['lobster', 'bisque', 'bussell', 'sprouts', 'risotto', 'filet', 'all', 'needed', 'salt', 'and', 'pepper', 'and', 'of', 'course', 'there', 'is', 'none', 'at', 'the', 'tables'], tags=['yelp_222']),
#  LabeledSentence(words=['hopefully', 'this', 'bodes', 'for', 'them', 'going', 'out', 'of', 'business', 'and', 'someone', 'who', 'can', 'cook', 'can', 'come', 'in'], tags=['yelp_223']),
#  LabeledSentence(words=['it', 'was', 'either', 'too', 'cold', 'not', 'enough', 'flavor', 'or', 'just', 'bad'], tags=['yelp_224']),
#  LabeledSentence(words=['i', 'loved', 'the', 'bacon', 'wrapped', 'dates'], tags=['yelp_225']),
#  LabeledSentence(words=['this', 'is', 'an', 'unbelievable', 'bargain'], tags=['yelp_226']),
#  LabeledSentence(words=['the', 'folks', 'at', 'otto', 'always', 'make', 'us', 'feel', 'so', 'welcome', 'and', 'special'], tags=['yelp_227']),
#  LabeledSentence(words=['as', 'for', 'the', 'mains', 'also', 'uninspired'], tags=['yelp_228']),
#  LabeledSentence(words=['this', 'is', 'the', 'place', 'where', 'i', 'first', 'had', 'pho', 'and', 'it', 'was', 'amazing'], tags=['yelp_229']),
#  LabeledSentence(words=['this', 'wonderful', 'experience', 'made', 'this', 'place', 'a', 'must', 'stop', 'whenever', 'we', 'are', 'in', 'town', 'again'], tags=['yelp_230']),
#  LabeledSentence(words=['if', 'the', 'food', 'isnt', 'bad', 'enough', 'for', 'you', 'then', 'enjoy', 'dealing', 'with', 'the', 'worlds', 'worst', 'annoying', 'drunk', 'people'], tags=['yelp_231']),
#  LabeledSentence(words=['very', 'very', 'fun', 'chef'], tags=['yelp_232']),
#  LabeledSentence(words=['ordered', 'a', 'double', 'cheeseburger', 'got', 'a', 'single', 'patty', 'that', 'was', 'falling', 'apart', 'picture', 'uploaded', 'yeah', 'still', 'sucks'], tags=['yelp_233']),
#  LabeledSentence(words=['great', 'place', 'to', 'have', 'a', 'couple', 'drinks', 'and', 'watch', 'any', 'and', 'all', 'sporting', 'events', 'as', 'the', 'walls', 'are', 'covered', 'with', 'tvs'], tags=['yelp_234']),
#  LabeledSentence(words=['if', 'it', 'were', 'possible', 'to', 'give', 'them', 'zero', 'stars', 'theyd', 'have', 'it'], tags=['yelp_235']),
#  LabeledSentence(words=['the', 'descriptions', 'said', 'yum', 'yum', 'sauce', 'and', 'another', 'said', 'eel', 'sauce', 'yet', 'another', 'said', 'spicy', 'mayo', 'well', 'none', 'of', 'the', 'rolls', 'had', 'sauces', 'on', 'them'], tags=['yelp_236']),
#  LabeledSentence(words=['id', 'say', 'that', 'would', 'be', 'the', 'hardest', 'decision', 'honestly', 'all', 'of', 'ms', 'dishes', 'taste', 'how', 'they', 'are', 'supposed', 'to', 'taste', 'amazing'], tags=['yelp_237']),
#  LabeledSentence(words=['if', 'she', 'had', 'not', 'rolled', 'the', 'eyes', 'we', 'may', 'have', 'stayed', 'not', 'sure', 'if', 'we', 'will', 'go', 'back', 'and', 'try', 'it', 'again'], tags=['yelp_238']),
#  LabeledSentence(words=['everyone', 'is', 'very', 'attentive', 'providing', 'excellent', 'customer', 'service'], tags=['yelp_239']),
#  LabeledSentence(words=['horrible', 'dont', 'waste', 'your', 'time', 'and', 'money'], tags=['yelp_240']),
#  LabeledSentence(words=['now', 'this', 'dish', 'was', 'quite', 'flavourful'], tags=['yelp_241']),
#  LabeledSentence(words=['by', 'this', 'time', 'our', 'side', 'of', 'the', 'restaurant', 'was', 'almost', 'empty', 'so', 'there', 'was', 'no', 'excuse'], tags=['yelp_242']),
#  LabeledSentence(words=['it', 'wasnt', 'busy', 'either', 'also', 'the', 'building', 'was', 'freezing', 'cold'], tags=['yelp_243']),
#  LabeledSentence(words=['like', 'the', 'other', 'reviewer', 'said', 'you', 'couldnt', 'pay', 'me', 'to', 'eat', 'at', 'this', 'place', 'again'], tags=['yelp_244']),
#  LabeledSentence(words=['drinks', 'took', 'close', 'to', '30', 'minutes', 'to', 'come', 'out', 'at', 'one', 'point'], tags=['yelp_245']),
#  LabeledSentence(words=['seriously', 'flavorful', 'delights', 'folks'], tags=['yelp_246']),
#  LabeledSentence(words=['much', 'better', 'than', 'the', 'other', 'ayce', 'sushi', 'place', 'i', 'went', 'to', 'in', 'vegas'], tags=['yelp_247']),
#  LabeledSentence(words=['the', 'lighting', 'is', 'just', 'dark', 'enough', 'to', 'set', 'the', 'mood'], tags=['yelp_248']),
#  LabeledSentence(words=['based', 'on', 'the', 'sub', 'par', 'service', 'i', 'received', 'and', 'no', 'effort', 'to', 'show', 'their', 'gratitude', 'for', 'my', 'business', 'i', 'wont', 'be', 'going', 'back'], tags=['yelp_249']),
#  LabeledSentence(words=['owners', 'are', 'really', 'great', 'people'], tags=['yelp_250']),
#  LabeledSentence(words=['there', 'is', 'nothing', 'privileged', 'about', 'working', 'eating', 'there'], tags=['yelp_251']),
#  LabeledSentence(words=['the', 'greek', 'dressing', 'was', 'very', 'creamy', 'and', 'flavorful'], tags=['yelp_252']),
#  LabeledSentence(words=['overall', 'i', 'dont', 'think', 'that', 'i', 'would', 'take', 'my', 'parents', 'to', 'this', 'place', 'again', 'because', 'they', 'made', 'most', 'of', 'the', 'similar', 'complaints', 'that', 'i', 'silently', 'felt', 'too'], tags=['yelp_253']),
#  LabeledSentence(words=['now', 'the', 'pizza', 'itself', 'was', 'good', 'the', 'peanut', 'sauce', 'was', 'very', 'tasty'], tags=['yelp_254']),
#  LabeledSentence(words=['we', 'had', '7', 'at', 'our', 'table', 'and', 'the', 'service', 'was', 'pretty', 'fast'], tags=['yelp_255']),
#  LabeledSentence(words=['fantastic', 'service', 'here'], tags=['yelp_256']),
#  LabeledSentence(words=['i', 'as', 'well', 'wouldve', 'given', 'godfathers', 'zero', 'stars', 'if', 'possible'], tags=['yelp_257']),
#  LabeledSentence(words=['they', 'know', 'how', 'to', 'make', 'them', 'here'], tags=['yelp_258']),
#  LabeledSentence(words=['very', 'tough', 'and', 'very', 'short', 'on', 'flavor'], tags=['yelp_259']),
#  LabeledSentence(words=['i', 'hope', 'this', 'place', 'sticks', 'around'], tags=['yelp_260']),
#  LabeledSentence(words=['i', 'have', 'been', 'in', 'more', 'than', 'a', 'few', 'bars', 'in', 'vegas', 'and', 'do', 'not', 'ever', 'recall', 'being', 'charged', 'for', 'tap', 'water'], tags=['yelp_261']),
#  LabeledSentence(words=['the', 'restaurant', 'atmosphere', 'was', 'exquisite'], tags=['yelp_262']),
#  LabeledSentence(words=['good', 'service', 'very', 'clean', 'and', 'inexpensive', 'to', 'boot'], tags=['yelp_263']),
#  LabeledSentence(words=['the', 'seafood', 'was', 'fresh', 'and', 'generous', 'in', 'portion'], tags=['yelp_264']),
#  LabeledSentence(words=['plus', 'its', 'only', '8', 'bucks'], tags=['yelp_265']),
#  LabeledSentence(words=['the', 'service', 'was', 'not', 'up', 'to', 'par', 'either'], tags=['yelp_266']),
#  LabeledSentence(words=['thus', 'far', 'have', 'only', 'visited', 'twice', 'and', 'the', 'food', 'was', 'absolutely', 'delicious', 'each', 'time'], tags=['yelp_267']),
#  LabeledSentence(words=['just', 'as', 'good', 'as', 'when', 'i', 'had', 'it', 'more', 'than', 'a', 'year', 'ago'], tags=['yelp_268']),
#  LabeledSentence(words=['for', 'a', 'self', 'proclaimed', 'coffee', 'cafe', 'i', 'was', 'wildly', 'disappointed'], tags=['yelp_269']),
#  LabeledSentence(words=['the', 'veggitarian', 'platter', 'is', 'out', 'of', 'this', 'world'], tags=['yelp_270']),
#  LabeledSentence(words=['you', 'cant', 'go', 'wrong', 'with', 'any', 'of', 'the', 'food', 'here'], tags=['yelp_271']),
#  LabeledSentence(words=['you', 'cant', 'beat', 'that'], tags=['yelp_272']),
#  LabeledSentence(words=['stopped', 'by', 'this', 'place', 'while', 'in', 'madison', 'for', 'the', 'ironman', 'very', 'friendly', 'kind', 'staff'], tags=['yelp_273']),
#  LabeledSentence(words=['the', 'chefs', 'were', 'friendly', 'and', 'did', 'a', 'good', 'job'], tags=['yelp_274']),
#  LabeledSentence(words=['ive', 'had', 'better', 'not', 'only', 'from', 'dedicated', 'boba', 'tea', 'spots', 'but', 'even', 'from', 'jenni', 'pho'], tags=['yelp_275']),
#  LabeledSentence(words=['i', 'liked', 'the', 'patio', 'and', 'the', 'service', 'was', 'outstanding'], tags=['yelp_276']),
#  LabeledSentence(words=['the', 'goat', 'taco', 'didnt', 'skimp', 'on', 'the', 'meat', 'and', 'wow', 'what', 'flavor'], tags=['yelp_277']),
#  LabeledSentence(words=['i', 'think', 'not', 'again'], tags=['yelp_278']),
#  LabeledSentence(words=['i', 'had', 'the', 'mac', 'salad', 'and', 'it', 'was', 'pretty', 'bland', 'so', 'i', 'will', 'not', 'be', 'getting', 'that', 'again'], tags=['yelp_279']),
#  LabeledSentence(words=['i', 'went', 'to', 'bachi', 'burger', 'on', 'a', 'friends', 'recommendation', 'and', 'was', 'not', 'disappointed'], tags=['yelp_280']),
#  LabeledSentence(words=['service', 'stinks', 'here'], tags=['yelp_281']),
#  LabeledSentence(words=['i', 'waited', 'and', 'waited'], tags=['yelp_282']),
#  LabeledSentence(words=['this', 'place', 'is', 'not', 'quality', 'sushi', 'it', 'is', 'not', 'a', 'quality', 'restaurant'], tags=['yelp_283']),
#  LabeledSentence(words=['i', 'would', 'definitely', 'recommend', 'the', 'wings', 'as', 'well', 'as', 'the', 'pizza'], tags=['yelp_284']),
#  LabeledSentence(words=['great', 'pizza', 'and', 'salads'], tags=['yelp_285']),
#  LabeledSentence(words=['things', 'that', 'went', 'wrong', 'they', 'burned', 'the', 'saganaki'], tags=['yelp_286']),
#  LabeledSentence(words=['we', 'waited', 'an', 'hour', 'for', 'what', 'was', 'a', 'breakfast', 'i', 'could', 'have', 'done', '100', 'times', 'better', 'at', 'home'], tags=['yelp_287']),
#  LabeledSentence(words=['this', 'place', 'is', 'amazing'], tags=['yelp_288']),
#  LabeledSentence(words=['i', 'hate', 'to', 'disagree', 'with', 'my', 'fellow', 'yelpers', 'but', 'my', 'husband', 'and', 'i', 'were', 'so', 'disappointed', 'with', 'this', 'place'], tags=['yelp_289']),
#  LabeledSentence(words=['waited', '2', 'hours', 'never', 'got', 'either', 'of', 'our', 'pizzas', 'as', 'many', 'other', 'around', 'us', 'who', 'came', 'in', 'later', 'did'], tags=['yelp_290']),
#  LabeledSentence(words=['just', 'dont', 'know', 'why', 'they', 'were', 'so', 'slow'], tags=['yelp_291']),
#  LabeledSentence(words=['the', 'staff', 'is', 'great', 'the', 'food', 'is', 'delish', 'and', 'they', 'have', 'an', 'incredible', 'beer', 'selection'], tags=['yelp_292']),
#  LabeledSentence(words=['i', 'live', 'in', 'the', 'neighborhood', 'so', 'i', 'am', 'disappointed', 'i', 'wont', 'be', 'back', 'here', 'because', 'it', 'is', 'a', 'convenient', 'location'], tags=['yelp_293']),
#  LabeledSentence(words=['i', 'didnt', 'know', 'pulled', 'pork', 'could', 'be', 'soooo', 'delicious'], tags=['yelp_294']),
#  LabeledSentence(words=['you', 'get', 'incredibly', 'fresh', 'fish', 'prepared', 'with', 'care'], tags=['yelp_295']),
#  LabeledSentence(words=['before', 'i', 'go', 'in', 'to', 'why', 'i', 'gave', 'a', '1', 'star', 'rating', 'please', 'know', 'that', 'this', 'was', 'my', 'third', 'time', 'eating', 'at', 'bachi', 'burger', 'before', 'writing', 'a', 'review'], tags=['yelp_296']),
#  LabeledSentence(words=['i', 'love', 'the', 'fact', 'that', 'everything', 'on', 'their', 'menu', 'is', 'worth', 'it'], tags=['yelp_297']),
#  LabeledSentence(words=['never', 'again', 'will', 'i', 'be', 'dining', 'at', 'this', 'place'], tags=['yelp_298']),
#  LabeledSentence(words=['the', 'food', 'was', 'excellent', 'and', 'service', 'was', 'very', 'good'], tags=['yelp_299']),
#  LabeledSentence(words=['good', 'beer', 'drink', 'selection', 'and', 'good', 'food', 'selection'], tags=['yelp_300']),
#  LabeledSentence(words=['please', 'stay', 'away', 'from', 'the', 'shrimp', 'stir', 'fried', 'noodles'], tags=['yelp_301']),
#  LabeledSentence(words=['the', 'potato', 'chip', 'order', 'was', 'sad', 'i', 'could', 'probably', 'count', 'how', 'many', 'chips', 'were', 'in', 'that', 'box', 'and', 'it', 'was', 'probably', 'around', '12'], tags=['yelp_302']),
#  LabeledSentence(words=['food', 'was', 'really', 'boring'], tags=['yelp_303']),
#  LabeledSentence(words=['good', 'service', 'check'], tags=['yelp_304']),
#  LabeledSentence(words=['this', 'greedy', 'corporation', 'will', 'never', 'see', 'another', 'dime', 'from', 'me'], tags=['yelp_305']),
#  LabeledSentence(words=['will', 'never', 'ever', 'go', 'back'], tags=['yelp_306']),
#  LabeledSentence(words=['as', 'much', 'as', 'id', 'like', 'to', 'go', 'back', 'i', 'cant', 'get', 'passed', 'the', 'atrocious', 'service', 'and', 'will', 'never', 'return'], tags=['yelp_307']),
#  LabeledSentence(words=['in', 'the', 'summer', 'you', 'can', 'dine', 'in', 'a', 'charming', 'outdoor', 'patio', 'so', 'very', 'delightful'], tags=['yelp_308']),
#  LabeledSentence(words=['i', 'did', 'not', 'expect', 'this', 'to', 'be', 'so', 'good'], tags=['yelp_309']),
#  LabeledSentence(words=['fantastic', 'food'], tags=['yelp_310']),
#  LabeledSentence(words=['she', 'ordered', 'a', 'toasted', 'english', 'muffin', 'that', 'came', 'out', 'untoasted'], tags=['yelp_311']),
#  LabeledSentence(words=['the', 'food', 'was', 'very', 'good'], tags=['yelp_312']),
#  LabeledSentence(words=['never', 'going', 'back'], tags=['yelp_313']),
#  LabeledSentence(words=['great', 'food', 'for', 'the', 'price', 'which', 'is', 'very', 'high', 'quality', 'and', 'house', 'made'], tags=['yelp_314']),
#  LabeledSentence(words=['the', 'bus', 'boy', 'on', 'the', 'other', 'hand', 'was', 'so', 'rude'], tags=['yelp_315']),
#  LabeledSentence(words=['by', 'this', 'point', 'my', 'friends', 'and', 'i', 'had', 'basically', 'figured', 'out', 'this', 'place', 'was', 'a', 'joke', 'and', 'didnt', 'mind', 'making', 'it', 'publicly', 'and', 'loudly', 'known'], tags=['yelp_316']),
#  LabeledSentence(words=['back', 'to', 'good', 'bbq', 'lighter', 'fare', 'reasonable', 'pricing', 'and', 'tell', 'the', 'public', 'they', 'are', 'back', 'to', 'the', 'old', 'ways'], tags=['yelp_317']),
#  LabeledSentence(words=['and', 'considering', 'the', 'two', 'of', 'us', 'left', 'there', 'very', 'full', 'and', 'happy', 'for', 'about', '20', 'you', 'just', 'cant', 'go', 'wrong'], tags=['yelp_318']),
#  LabeledSentence(words=['all', 'the', 'bread', 'is', 'made', 'in', 'house'], tags=['yelp_319']),
#  LabeledSentence(words=['the', 'only', 'downside', 'is', 'the', 'service'], tags=['yelp_320']),
#  LabeledSentence(words=['also', 'the', 'fries', 'are', 'without', 'a', 'doubt', 'the', 'worst', 'fries', 'ive', 'ever', 'had'], tags=['yelp_321']),
#  LabeledSentence(words=['service', 'was', 'exceptional', 'and', 'food', 'was', 'a', 'good', 'as', 'all', 'the', 'reviews'], tags=['yelp_322']),
#  LabeledSentence(words=['a', 'couple', 'of', 'months', 'later', 'i', 'returned', 'and', 'had', 'an', 'amazing', 'meal'], tags=['yelp_323']),
#  LabeledSentence(words=['favorite', 'place', 'in', 'town', 'for', 'shawarrrrrrma'], tags=['yelp_324']),
#  LabeledSentence(words=['the', 'black', 'eyed', 'peas', 'and', 'sweet', 'potatoes', 'unreal'], tags=['yelp_325']),
#  LabeledSentence(words=['you', 'wont', 'be', 'disappointed'], tags=['yelp_326']),
#  LabeledSentence(words=['they', 'could', 'serve', 'it', 'with', 'just', 'the', 'vinaigrette', 'and', 'it', 'may', 'make', 'for', 'a', 'better', 'overall', 'dish', 'but', 'it', 'was', 'still', 'very', 'good'], tags=['yelp_327']),
#  LabeledSentence(words=['i', 'go', 'to', 'far', 'too', 'many', 'places', 'and', 'ive', 'never', 'seen', 'any', 'restaurant', 'that', 'serves', 'a', '1', 'egg', 'breakfast', 'especially', 'for', '4', '00'], tags=['yelp_328']),
#  LabeledSentence(words=['when', 'my', 'mom', 'and', 'i', 'got', 'home', 'she', 'immediately', 'got', 'sick', 'and', 'she', 'only', 'had', 'a', 'few', 'bites', 'of', 'salad'], tags=['yelp_329']),
#  LabeledSentence(words=['the', 'servers', 'are', 'not', 'pleasant', 'to', 'deal', 'with', 'and', 'they', 'dont', 'always', 'honor', 'pizza', 'hut', 'coupons'], tags=['yelp_330']),
#  LabeledSentence(words=['both', 'of', 'them', 'were', 'truly', 'unbelievably', 'good', 'and', 'i', 'am', 'so', 'glad', 'we', 'went', 'back'], tags=['yelp_331']),
#  LabeledSentence(words=['we', 'had', 'fantastic', 'service', 'and', 'were', 'pleased', 'by', 'the', 'atmosphere'], tags=['yelp_332']),
#  LabeledSentence(words=['everything', 'was', 'gross'], tags=['yelp_333']),
#  LabeledSentence(words=['i', 'love', 'this', 'place'], tags=['yelp_334']),
#  LabeledSentence(words=['great', 'service', 'and', 'food'], tags=['yelp_335']),
#  LabeledSentence(words=['first', 'the', 'bathrooms', 'at', 'this', 'location', 'were', 'dirty', 'seat', 'covers', 'were', 'not', 'replenished', 'just', 'plain', 'yucky'], tags=['yelp_336']),
#  LabeledSentence(words=['the', 'burger', 'i', 'got', 'the', 'gold', 'standard', 'a', '17', 'burger', 'and', 'was', 'kind', 'of', 'disappointed'], tags=['yelp_337']),
#  LabeledSentence(words=['omg', 'the', 'food', 'was', 'delicioso'], tags=['yelp_338']),
#  LabeledSentence(words=['there', 'is', 'nothing', 'authentic', 'about', 'this', 'place'], tags=['yelp_339']),
#  LabeledSentence(words=['the', 'spaghetti', 'is', 'nothing', 'special', 'whatsoever'], tags=['yelp_340']),
#  LabeledSentence(words=['of', 'all', 'the', 'dishes', 'the', 'salmon', 'was', 'the', 'best', 'but', 'all', 'were', 'great'], tags=['yelp_341']),
#  LabeledSentence(words=['the', 'vegetables', 'are', 'so', 'fresh', 'and', 'the', 'sauce', 'feels', 'like', 'authentic', 'thai'], tags=['yelp_342']),
#  LabeledSentence(words=['its', 'worth', 'driving', 'up', 'from', 'tucson'], tags=['yelp_343']),
#  LabeledSentence(words=['the', 'selection', 'was', 'probably', 'the', 'worst', 'ive', 'seen', 'in', 'vegas', 'there', 'was', 'none'], tags=['yelp_344']),
#  LabeledSentence(words=['pretty', 'good', 'beer', 'selection', 'too'], tags=['yelp_345']),
#  LabeledSentence(words=['this', 'place', 'is', 'like', 'chipotle', 'but', 'better'], tags=['yelp_346']),
#  LabeledSentence(words=['classy', 'warm', 'atmosphere', 'fun', 'and', 'fresh', 'appetizers', 'succulent', 'steaks', 'baseball', 'steak'], tags=['yelp_347']),
# ...
#  LabeledSentence(words=['after', '20', 'minutes', 'wait', 'i', 'got', 'a', 'table'], tags=['yelp_887']),
#  LabeledSentence(words=['seriously', 'killer', 'hot', 'chai', 'latte'], tags=['yelp_888']),
#  LabeledSentence(words=['no', 'allergy', 'warnings', 'on', 'the', 'menu', 'and', 'the', 'waitress', 'had', 'absolutely', 'no', 'clue', 'as', 'to', 'which', 'meals', 'did', 'or', 'did', 'not', 'contain', 'peanuts'], tags=['yelp_889']),
#  LabeledSentence(words=['my', 'boyfriend', 'tried', 'the', 'mediterranean', 'chicken', 'salad', 'and', 'fell', 'in', 'love'], tags=['yelp_890']),
#  LabeledSentence(words=['their', 'rotating', 'beers', 'on', 'tap', 'is', 'also', 'a', 'highlight', 'of', 'this', 'place'], tags=['yelp_891']),
#  LabeledSentence(words=['pricing', 'is', 'a', 'bit', 'of', 'a', 'concern', 'at', 'mellow', 'mushroom'], tags=['yelp_892']),
#  LabeledSentence(words=['worst', 'thai', 'ever'], tags=['yelp_893']),
#  LabeledSentence(words=['if', 'you', 'stay', 'in', 'vegas', 'you', 'must', 'get', 'breakfast', 'here', 'at', 'least', 'once'], tags=['yelp_894']),
#  LabeledSentence(words=['i', 'want', 'to', 'first', 'say', 'our', 'server', 'was', 'great', 'and', 'we', 'had', 'perfect', 'service'], tags=['yelp_895']),
#  LabeledSentence(words=['the', 'pizza', 'selections', 'are', 'good'], tags=['yelp_896']),
#  LabeledSentence(words=['i', 'had', 'strawberry', 'tea', 'which', 'was', 'good'], tags=['yelp_897']),
#  LabeledSentence(words=['highly', 'unprofessional', 'and', 'rude', 'to', 'a', 'loyal', 'patron'], tags=['yelp_898']),
#  LabeledSentence(words=['overall', 'a', 'great', 'experience'], tags=['yelp_899']),
#  LabeledSentence(words=['spend', 'your', 'money', 'elsewhere'], tags=['yelp_900']),
#  LabeledSentence(words=['their', 'regular', 'toasted', 'bread', 'was', 'equally', 'satisfying', 'with', 'the', 'occasional', 'pats', 'of', 'butter', 'mmmm'], tags=['yelp_901']),
#  LabeledSentence(words=['the', 'buffet', 'at', 'bellagio', 'was', 'far', 'from', 'what', 'i', 'anticipated'], tags=['yelp_902']),
#  LabeledSentence(words=['and', 'the', 'drinks', 'are', 'weak', 'people'], tags=['yelp_903']),
#  LabeledSentence(words=['my', 'order', 'was', 'not', 'correct'], tags=['yelp_904']),
#  LabeledSentence(words=['also', 'i', 'feel', 'like', 'the', 'chips', 'are', 'bought', 'not', 'made', 'in', 'house'], tags=['yelp_905']),
#  LabeledSentence(words=['after', 'the', 'disappointing', 'dinner', 'we', 'went', 'elsewhere', 'for', 'dessert'], tags=['yelp_906']),
#  LabeledSentence(words=['the', 'chips', 'and', 'sals', 'a', 'here', 'is', 'amazing'], tags=['yelp_907']),
#  LabeledSentence(words=['we', 'wont', 'be', 'returning'], tags=['yelp_908']),
#  LabeledSentence(words=['this', 'is', 'my', 'new', 'fav', 'vegas', 'buffet', 'spot'], tags=['yelp_909']),
#  LabeledSentence(words=['i', 'seriously', 'cannot', 'believe', 'that', 'the', 'owner', 'has', 'so', 'many', 'unexperienced', 'employees', 'that', 'all', 'are', 'running', 'around', 'like', 'chickens', 'with', 'their', 'heads', 'cut', 'off'], tags=['yelp_910']),
#  LabeledSentence(words=['very', 'very', 'sad'], tags=['yelp_911']),
#  LabeledSentence(words=['i', 'felt', 'insulted', 'and', 'disrespected', 'how', 'could', 'you', 'talk', 'and', 'judge', 'another', 'human', 'being', 'like', 'that'], tags=['yelp_912']),
#  LabeledSentence(words=['how', 'can', 'you', 'call', 'yourself', 'a', 'steakhouse', 'if', 'you', 'cant', 'properly', 'cook', 'a', 'steak', 'i', 'dont', 'understand'], tags=['yelp_913']),
#  LabeledSentence(words=['im', 'not', 'impressed', 'with', 'the', 'concept', 'or', 'the', 'food'], tags=['yelp_914']),
#  LabeledSentence(words=['the', 'only', 'thing', 'i', 'wasnt', 'too', 'crazy', 'about', 'was', 'their', 'guacamole', 'as', 'i', 'dont', 'like', 'it', 'puréed'], tags=['yelp_915']),
#  LabeledSentence(words=['there', 'is', 'really', 'nothing', 'for', 'me', 'at', 'postinos', 'hope', 'your', 'experience', 'is', 'better'], tags=['yelp_916']),
#  LabeledSentence(words=['i', 'got', 'food', 'poisoning', 'here', 'at', 'the', 'buffet'], tags=['yelp_917']),
#  LabeledSentence(words=['they', 'brought', 'a', 'fresh', 'batch', 'of', 'fries', 'and', 'i', 'was', 'thinking', 'yay', 'something', 'warm', 'but', 'no'], tags=['yelp_918']),
#  LabeledSentence(words=['what', 'should', 'have', 'been', 'a', 'hilarious', 'yummy', 'christmas', 'eve', 'dinner', 'to', 'remember', 'was', 'the', 'biggest', 'fail', 'of', 'the', 'entire', 'trip', 'for', 'us'], tags=['yelp_919']),
#  LabeledSentence(words=['needless', 'to', 'say', 'i', 'wont', 'be', 'going', 'back', 'anytime', 'soon'], tags=['yelp_920']),
#  LabeledSentence(words=['this', 'place', 'is', 'disgusting'], tags=['yelp_921']),
#  LabeledSentence(words=['every', 'time', 'i', 'eat', 'here', 'i', 'see', 'caring', 'teamwork', 'to', 'a', 'professional', 'degree'], tags=['yelp_922']),
#  LabeledSentence(words=['the', 'ri', 'style', 'calamari', 'was', 'a', 'joke'], tags=['yelp_923']),
#  LabeledSentence(words=['however', 'there', 'was', 'so', 'much', 'garlic', 'in', 'the', 'fondue', 'it', 'was', 'barely', 'edible'], tags=['yelp_924']),
#  LabeledSentence(words=['i', 'could', 'barely', 'stomach', 'the', 'meal', 'but', 'didnt', 'complain', 'because', 'it', 'was', 'a', 'business', 'lunch'], tags=['yelp_925']),
#  LabeledSentence(words=['it', 'was', 'so', 'bad', 'i', 'had', 'lost', 'the', 'heart', 'to', 'finish', 'it'], tags=['yelp_926']),
#  LabeledSentence(words=['it', 'also', 'took', 'her', 'forever', 'to', 'bring', 'us', 'the', 'check', 'when', 'we', 'asked', 'for', 'it'], tags=['yelp_927']),
#  LabeledSentence(words=['we', 'arent', 'ones', 'to', 'make', 'a', 'scene', 'at', 'restaurants', 'but', 'i', 'just', 'dont', 'get', 'it', 'definitely', 'lost', 'the', 'love', 'after', 'this', 'one'], tags=['yelp_928']),
#  LabeledSentence(words=['disappointing', 'experience'], tags=['yelp_929']),
#  LabeledSentence(words=['the', 'food', 'is', 'about', 'on', 'par', 'with', 'dennys', 'which', 'is', 'to', 'say', 'not', 'good', 'at', 'all'], tags=['yelp_930']),
#  LabeledSentence(words=['if', 'you', 'want', 'to', 'wait', 'for', 'mediocre', 'food', 'and', 'downright', 'terrible', 'service', 'then', 'this', 'is', 'the', 'place', 'for', 'you'], tags=['yelp_931']),
#  LabeledSentence(words=['waaaaaayyyyyyyyyy', 'over', 'rated', 'is', 'all', 'i', 'am', 'saying'], tags=['yelp_932']),
#  LabeledSentence(words=['we', 'wont', 'be', 'going', 'back'], tags=['yelp_933']),
#  LabeledSentence(words=['the', 'place', 'was', 'fairly', 'clean', 'but', 'the', 'food', 'simply', 'wasnt', 'worth', 'it'], tags=['yelp_934']),
#  LabeledSentence(words=['this', 'place', 'lacked', 'style'], tags=['yelp_935']),
#  LabeledSentence(words=['the', 'sangria', 'was', 'about', 'half', 'of', 'a', 'glass', 'wine', 'full', 'and', 'was', '12', 'ridiculous'], tags=['yelp_936']),
#  LabeledSentence(words=['dont', 'bother', 'coming', 'here'], tags=['yelp_937']),
#  LabeledSentence(words=['the', 'meat', 'was', 'pretty', 'dry', 'i', 'had', 'the', 'sliced', 'brisket', 'and', 'pulled', 'pork'], tags=['yelp_938']),
#  LabeledSentence(words=['the', 'building', 'itself', 'seems', 'pretty', 'neat', 'the', 'bathroom', 'is', 'pretty', 'trippy', 'but', 'i', 'wouldnt', 'eat', 'here', 'again'], tags=['yelp_939']),
#  LabeledSentence(words=['it', 'was', 'equally', 'awful'], tags=['yelp_940']),
#  LabeledSentence(words=['probably', 'not', 'in', 'a', 'hurry', 'to', 'go', 'back'], tags=['yelp_941']),
#  LabeledSentence(words=['very', 'slow', 'at', 'seating', 'even', 'with', 'reservation'], tags=['yelp_942']),
#  LabeledSentence(words=['not', 'good', 'by', 'any', 'stretch', 'of', 'the', 'imagination'], tags=['yelp_943']),
#  LabeledSentence(words=['the', 'cashew', 'cream', 'sauce', 'was', 'bland', 'and', 'the', 'vegetables', 'were', 'undercooked'], tags=['yelp_944']),
#  LabeledSentence(words=['the', 'chipolte', 'ranch', 'dipping', 'sause', 'was', 'tasteless', 'seemed', 'thin', 'and', 'watered', 'down', 'with', 'no', 'heat'], tags=['yelp_945']),
#  LabeledSentence(words=['it', 'was', 'a', 'bit', 'too', 'sweet', 'not', 'really', 'spicy', 'enough', 'and', 'lacked', 'flavor'], tags=['yelp_946']),
#  LabeledSentence(words=['i', 'was', 'very', 'disappointed'], tags=['yelp_947']),
#  LabeledSentence(words=['this', 'place', 'is', 'horrible', 'and', 'way', 'overpriced'], tags=['yelp_948']),
#  LabeledSentence(words=['maybe', 'its', 'just', 'their', 'vegetarian', 'fare', 'but', 'ive', 'been', 'twice', 'and', 'i', 'thought', 'it', 'was', 'average', 'at', 'best'], tags=['yelp_949']),
#  LabeledSentence(words=['it', 'wasnt', 'busy', 'at', 'all', 'and', 'now', 'we', 'know', 'why'], tags=['yelp_950']),
#  LabeledSentence(words=['the', 'tables', 'outside', 'are', 'also', 'dirty', 'a', 'lot', 'of', 'the', 'time', 'and', 'the', 'workers', 'are', 'not', 'always', 'friendly', 'and', 'helpful', 'with', 'the', 'menu'], tags=['yelp_951']),
#  LabeledSentence(words=['the', 'ambiance', 'here', 'did', 'not', 'feel', 'like', 'a', 'buffet', 'setting', 'but', 'more', 'of', 'a', 'douchey', 'indoor', 'garden', 'for', 'tea', 'and', 'biscuits'], tags=['yelp_952']),
#  LabeledSentence(words=['con', 'spotty', 'service'], tags=['yelp_953']),
#  LabeledSentence(words=['the', 'fries', 'were', 'not', 'hot', 'and', 'neither', 'was', 'my', 'burger'], tags=['yelp_954']),
#  LabeledSentence(words=['but', 'then', 'they', 'came', 'back', 'cold'], tags=['yelp_955']),
#  LabeledSentence(words=['then', 'our', 'food', 'came', 'out', 'disappointment', 'ensued'], tags=['yelp_956']),
#  LabeledSentence(words=['the', 'real', 'disappointment', 'was', 'our', 'waiter'], tags=['yelp_957']),
#  LabeledSentence(words=['my', 'husband', 'said', 'she', 'was', 'very', 'rude', 'did', 'not', 'even', 'apologize', 'for', 'the', 'bad', 'food', 'or', 'anything'], tags=['yelp_958']),
#  LabeledSentence(words=['the', 'only', 'reason', 'to', 'eat', 'here', 'would', 'be', 'to', 'fill', 'up', 'before', 'a', 'night', 'of', 'binge', 'drinking', 'just', 'to', 'get', 'some', 'carbs', 'in', 'your', 'stomach'], tags=['yelp_959']),
#  LabeledSentence(words=['insults', 'profound', 'deuchebaggery', 'and', 'had', 'to', 'go', 'outside', 'for', 'a', 'smoke', 'break', 'while', 'serving', 'just', 'to', 'solidify', 'it'], tags=['yelp_960']),
#  LabeledSentence(words=['if', 'someone', 'orders', 'two', 'tacos', 'dont', 'you', 'think', 'it', 'may', 'be', 'part', 'of', 'customer', 'service', 'to', 'ask', 'if', 'it', 'is', 'combo', 'or', 'ala', 'cart'], tags=['yelp_961']),
#  LabeledSentence(words=['she', 'was', 'quite', 'disappointed', 'although', 'some', 'blame', 'needs', 'to', 'be', 'placed', 'at', 'her', 'door'], tags=['yelp_962']),
#  LabeledSentence(words=['after', 'all', 'the', 'rave', 'reviews', 'i', 'couldnt', 'wait', 'to', 'eat', 'here', 'what', 'a', 'disappointment'], tags=['yelp_963']),
#  LabeledSentence(words=['del', 'taco', 'is', 'pretty', 'nasty', 'and', 'should', 'be', 'avoided', 'if', 'possible'], tags=['yelp_964']),
#  LabeledSentence(words=['its', 'not', 'hard', 'to', 'make', 'a', 'decent', 'hamburger'], tags=['yelp_965']),
#  LabeledSentence(words=['but', 'i', 'dont', 'like', 'it'], tags=['yelp_966']),
#  LabeledSentence(words=['hell', 'no', 'will', 'i', 'go', 'back'], tags=['yelp_967']),
#  LabeledSentence(words=['weve', 'have', 'gotten', 'a', 'much', 'better', 'service', 'from', 'the', 'pizza', 'place', 'next', 'door', 'than', 'the', 'services', 'we', 'received', 'from', 'this', 'restaurant'], tags=['yelp_968']),
#  LabeledSentence(words=['i', 'dont', 'know', 'what', 'the', 'big', 'deal', 'is', 'about', 'this', 'place', 'but', 'i', 'wont', 'be', 'back', 'yaall'], tags=['yelp_969']),
#  LabeledSentence(words=['i', 'immediately', 'said', 'i', 'wanted', 'to', 'talk', 'to', 'the', 'manager', 'but', 'i', 'did', 'not', 'want', 'to', 'talk', 'to', 'the', 'guy', 'who', 'was', 'doing', 'shots', 'of', 'fireball', 'behind', 'the', 'bar'], tags=['yelp_970']),
#  LabeledSentence(words=['the', 'ambiance', 'isnt', 'much', 'better'], tags=['yelp_971']),
#  LabeledSentence(words=['unfortunately', 'it', 'only', 'set', 'us', 'up', 'for', 'disapppointment', 'with', 'our', 'entrees'], tags=['yelp_972']),
#  LabeledSentence(words=['the', 'food', 'wasnt', 'good'], tags=['yelp_973']),
#  LabeledSentence(words=['your', 'servers', 'suck', 'wait', 'correction', 'our', 'server', 'heimer', 'sucked'], tags=['yelp_974']),
#  LabeledSentence(words=['what', 'happened', 'next', 'was', 'pretty', 'off', 'putting'], tags=['yelp_975']),
#  LabeledSentence(words=['too', 'bad', 'cause', 'i', 'know', 'its', 'family', 'owned', 'i', 'really', 'wanted', 'to', 'like', 'this', 'place'], tags=['yelp_976']),
#  LabeledSentence(words=['overpriced', 'for', 'what', 'you', 'are', 'getting'], tags=['yelp_977']),
#  LabeledSentence(words=['i', 'vomited', 'in', 'the', 'bathroom', 'mid', 'lunch'], tags=['yelp_978']),
#  LabeledSentence(words=['i', 'kept', 'looking', 'at', 'the', 'time', 'and', 'it', 'had', 'soon', 'become', '35', 'minutes', 'yet', 'still', 'no', 'food'], tags=['yelp_979']),
#  LabeledSentence(words=['i', 'have', 'been', 'to', 'very', 'few', 'places', 'to', 'eat', 'that', 'under', 'no', 'circumstances', 'would', 'i', 'ever', 'return', 'to', 'and', 'this', 'tops', 'the', 'list'], tags=['yelp_980']),
#  LabeledSentence(words=['we', 'started', 'with', 'the', 'tuna', 'sashimi', 'which', 'was', 'brownish', 'in', 'color', 'and', 'obviously', 'wasnt', 'fresh'], tags=['yelp_981']),
#  LabeledSentence(words=['food', 'was', 'below', 'average'], tags=['yelp_982']),
#  LabeledSentence(words=['it', 'sure', 'does', 'beat', 'the', 'nachos', 'at', 'the', 'movies', 'but', 'i', 'would', 'expect', 'a', 'little', 'bit', 'more', 'coming', 'from', 'a', 'restaurant'], tags=['yelp_983']),
#  LabeledSentence(words=['all', 'in', 'all', 'ha', 'long', 'bay', 'was', 'a', 'bit', 'of', 'a', 'flop'], tags=['yelp_984']),
#  LabeledSentence(words=['the', 'problem', 'i', 'have', 'is', 'that', 'they', 'charge', '11', '99', 'for', 'a', 'sandwich', 'that', 'is', 'no', 'bigger', 'than', 'a', 'subway', 'sub', 'which', 'offers', 'better', 'and', 'more', 'amount', 'of', 'vegetables'], tags=['yelp_985']),
#  LabeledSentence(words=['shrimp', 'when', 'i', 'unwrapped', 'it', 'i', 'live', 'only', '1', '2', 'a', 'mile', 'from', 'brushfire', 'it', 'was', 'literally', 'ice', 'cold'], tags=['yelp_986']),
#  LabeledSentence(words=['it', 'lacked', 'flavor', 'seemed', 'undercooked', 'and', 'dry'], tags=['yelp_987']),
#  LabeledSentence(words=['it', 'really', 'is', 'impressive', 'that', 'the', 'place', 'hasnt', 'closed', 'down'], tags=['yelp_988']),
#  LabeledSentence(words=['i', 'would', 'avoid', 'this', 'place', 'if', 'you', 'are', 'staying', 'in', 'the', 'mirage'], tags=['yelp_989']),
#  LabeledSentence(words=['the', 'refried', 'beans', 'that', 'came', 'with', 'my', 'meal', 'were', 'dried', 'out', 'and', 'crusty', 'and', 'the', 'food', 'was', 'bland'], tags=['yelp_990']),
#  LabeledSentence(words=['spend', 'your', 'money', 'and', 'time', 'some', 'place', 'else'], tags=['yelp_991']),
#  LabeledSentence(words=['a', 'lady', 'at', 'the', 'table', 'next', 'to', 'us', 'found', 'a', 'live', 'green', 'caterpillar', 'in', 'her', 'salad'], tags=['yelp_992']),
#  LabeledSentence(words=['the', 'presentation', 'of', 'the', 'food', 'was', 'awful'], tags=['yelp_993']),
#  LabeledSentence(words=['i', 'cant', 'tell', 'you', 'how', 'disappointed', 'i', 'was'], tags=['yelp_994']),
#  LabeledSentence(words=['i', 'think', 'food', 'should', 'have', 'flavor', 'and', 'texture', 'and', 'both', 'were', 'lacking'], tags=['yelp_995']),
#  LabeledSentence(words=['appetite', 'instantly', 'gone'], tags=['yelp_996']),
#  LabeledSentence(words=['overall', 'i', 'was', 'not', 'impressed', 'and', 'would', 'not', 'go', 'back'], tags=['yelp_997']),
#  LabeledSentence(words=['the', 'whole', 'experience', 'was', 'underwhelming', 'and', 'i', 'think', 'well', 'just', 'go', 'to', 'ninja', 'sushi', 'next', 'time'], tags=['yelp_998']),
#  LabeledSentence(words=['then', 'as', 'if', 'i', 'hadnt', 'wasted', 'enough', 'of', 'my', 'life', 'there', 'they', 'poured', 'salt', 'in', 'the', 'wound', 'by', 'drawing', 'out', 'the', 'time', 'it', 'took', 'to', 'bring', 'the', 'check'], tags=['yelp_999']),
#  ...]

# %%
import random
class PermuteSentences(object):
    def __iter__(self):
        shuffled = list(sentences)
        random.shuffle(shuffled)
        for sent in shuffled:
            yield sent
permuter = PermuteSentences()
        
model = Doc2Vec(permuter, min_count=1)
# Out:
# 2017-10-23 09:20:27,835 : INFO : collecting all words and their counts
# 2017-10-23 09:20:27,841 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-10-23 09:20:27,944 : INFO : collected 5227 word types and 3000 unique tags from a corpus of 3000 examples and 35674 words
# 2017-10-23 09:20:27,945 : INFO : Loading a fresh vocabulary
# 2017-10-23 09:20:27,976 : INFO : min_count=1 retains 5227 unique words (100% of original 5227, drops 0)
# 2017-10-23 09:20:27,979 : INFO : min_count=1 leaves 35674 word corpus (100% of original 35674, drops 0)
# 2017-10-23 09:20:28,020 : INFO : deleting the raw counts dictionary of 5227 items
# 2017-10-23 09:20:28,028 : INFO : sample=0.001 downsamples 51 most-common words
# 2017-10-23 09:20:28,036 : INFO : downsampling leaves estimated 26558 word corpus (74.4% of prior 35674)
# 2017-10-23 09:20:28,040 : INFO : estimated required memory for 5227 words and 100 dimensions: 8595100 bytes
# 2017-10-23 09:20:28,073 : INFO : resetting layer weights
# 2017-10-23 09:20:28,253 : INFO : training model with 3 workers on 5227 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2017-10-23 09:20:28,989 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-10-23 09:20:28,999 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-10-23 09:20:29,001 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-10-23 09:20:29,002 : INFO : training on 178370 raw words (147745 effective words) took 0.7s, 201012 effective words/s
# 2017-10-23 09:20:29,004 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model.most_similar('tasty')
# Out:
# 2017-10-23 09:20:31,017 : INFO : precomputing L2-norms of word weight vectors
# [('ever', 0.9983017444610596),
#  ('any', 0.9982807040214539),
#  ('he', 0.9982761144638062),
#  ('im', 0.9982563257217407),
#  ('would', 0.9982472658157349),
#  ('from', 0.9982465505599976),
#  ('one', 0.9982447624206543),
#  ('of', 0.9982373118400574),
#  ('his', 0.9982360601425171),
#  ('my', 0.998227596282959)]
